# %% [markdown]
# # Excess Mortality And Vaccines In Europe (v2)
#
# **Author:** Justin Garza
#
# **Date:** See below
#
# **Description:**
# This notebook explores excess mortality across Europe, analyzing statistical trends and investigating potential causes through data visualization and interpretation.
#
# **Content Warning:**
# If you find discussions of death or its underlying factors distressing, please proceed with caution or consider whether this content is right for you.

# %%
from datetime import datetime
from IPython.display import display
from IPython.display import Markdown as MD
current_date = datetime.now().strftime('%Y-%m-%d')
version = datetime.now().strftime('%Y%m%d.%H%M')
display(MD(f"**Date:** {current_date}"))
display(MD(f"**version:** {version}"))
# Out:
# **Date:** 2025-03-07
# **version:** 20250307.1507

# %% [markdown]
# ## Table of Contents

# %%
import os
import json5 as json
from IPython.display import display, HTML
from IPython.display import Markdown as MD

nb_path = os.path.join(os.getcwd(),'main.ipynb')

# Read the notebook
with open(nb_path, 'r', encoding='utf-8') as f:
    nb_data = json.load(f)

# Extract headers from markdown cells
outline = []
for cell in nb_data.get("cells", []):
    if cell["cell_type"] == "markdown":
        for line in cell["source"]:
            if line.startswith("#"):  # Markdown header
                level = line.count("#")  # Determine header level
                title = line.lstrip("#").strip()
                outline.append({
                        'text':title,
                        'level':level-1,
                        'link': f"index.html#{title.replace(' ','-')}"
                        })

for i in outline:
    display(HTML(f'<a href=\'{i["link"]}\'>{"____" * i["level"]}{i["text"]}</a>'))
# Out:
# <a href='index.html#Excess-Mortality-And-Vaccines-In-Europe-(v2)'>Excess Mortality And Vaccines In Europe (v2)</a>
# <a href='index.html#Table-of-Contents'>____Table of Contents</a>
# <a href='index.html#Prerequisites'>____Prerequisites</a>
# <a href='index.html#Scientific-Method'>________Scientific Method</a>
# <a href='index.html#Logical-Fallacies'>________Logical Fallacies</a>
# <a href='index.html#Observation'>____Observation</a>
# <a href='index.html#News-Articles-&-Headlines'>________News Articles & Headlines</a>
# <a href='index.html#Ad-Hominem-Attacks'>____________Ad Hominem Attacks</a>
# <a href='index.html#Appeals-to-Authority'>____________Appeals to Authority</a>
# <a href='index.html#Appeal-to-Emotions'>____________Appeal to Emotions</a>
# <a href='index.html#Hypothesis'>____Hypothesis</a>
# <a href='index.html#Diving-into-the-data.'>____Diving into the data.</a>
# <a href='index.html#Setup'>____Setup</a>
# <a href='index.html#Helping-Functions'>____Helping Functions</a>
# <a href='index.html#Import-and-Clean-Data'>____Import and Clean Data</a>
# <a href='index.html#death-data'>________death data</a>
# <a href='index.html#Getting-the-Data'>____________Getting the Data</a>
# <a href='index.html#variables'>____________variables</a>
# <a href='index.html#cause-of-death'>________cause of death</a>
# <a href='index.html#Getting-the-Data'>____________Getting the Data</a>
# <a href='index.html#variables'>____________variables</a>
# <a href='index.html#vaccine-data'>________vaccine data</a>
# <a href='index.html#Getting-the-Data'>____________Getting the Data</a>
# <a href='index.html#variables'>____________variables</a>
# <a href='index.html#combine-all-data'>____combine all data</a>
# <a href='index.html#variables'>________variables</a>
# <a href='index.html#Lets-Visualize-the-Data'>____Lets Visualize the Data</a>
# <a href='index.html#Line-Charts---normalized-deaths'>________Line Charts - normalized deaths</a>
# <a href='index.html#HeatMaps-of-deaths-by-AgeGroups'>________HeatMaps of deaths by AgeGroups</a>
# <a href='index.html#Spearman-and-Kendall'>________Spearman and Kendall</a>
# <a href='index.html#Other-death-x-vaccine-charts'>________Other death x vaccine charts</a>
# <a href='index.html#Bad-Batch-Theory'>________Bad-Batch Theory</a>
# <a href='index.html#There-seems-to-be-to-be-an-unusual-grouping/cluster'>____________There seems to be to be an unusual grouping/cluster</a>
# <a href='index.html#Bad-Batch-Theory-(by-Dr-Vibeke-Manniche)'>____________Bad-Batch Theory (by Dr Vibeke Manniche)</a>
# <a href='index.html#my-2-cents'>____________my 2 cents</a>
# <a href='index.html#Lets-look-at-some-of-the-Causes-of-Death'>____Lets look at some of the Causes of Death</a>
# <a href='index.html#Spearman-and-Kendall-...-(again)'>____________Spearman and Kendall ... (again)</a>
# <a href='index.html#BookMark'>BookMark</a>
# <a href='index.html#Specific-Examples'>________Specific Examples</a>
# <a href='index.html#bookmark'>bookmark</a>
# <a href='index.html#Conclusion'>____Conclusion</a>

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ### Scientific Method
# The **scientific method** is a systematic approach to investigating natural phenomena, acquiring knowledge, and testing hypotheses. It consists of the following key steps:
#
# 1. **Observation**
#    - Identify a problem or phenomenon that needs explanation.
#    - Gather initial data through direct observation or research.
#
# 2. **Hypothesis**
#    - Propose a testable and falsifiable explanation (a hypothesis).
#    - Example: "If plants receive more sunlight, then they will grow taller."
#
# 3. **Experimentation**
#    - Design and conduct controlled experiments to test the hypothesis.
#    - Include independent and dependent variables, control groups, and repeatable procedures.
#
# 4. **Conclusion**
#    - Determine whether the data supports or refutes the hypothesis.
#    - Modify or refine the hypothesis if necessary.
#
# 5. **Replication**
#    - Repeat experiments to verify results.
#    - Publish findings for scrutiny by the scientific community.
#
#    **Rant!: Peer Review is Flawed**
#
#    Imagine a mechanic repairs my car and then writes a paper about it.
#    Other mechanics review and approve the paper.
#    But when I get my car back, it still won’t start.
#    The mechanic insists, *"But my paper was peer-reviewed!"*
#    No matter how many experts approved the paper, what really matters is whether the experiment—getting the car to run—actually worked.
#
#
# The scientific method ensures **objectivity, reliability, and accuracy** in scientific inquiry. It is an iterative process, meaning that conclusions can lead to new questions and further investigations.

# %% [markdown]
# ### Logical Fallacies
# Logical fallacies are errors in reasoning that weaken arguments. They can be categorized into **formal** (structural errors) and **informal** (content errors).
#
#
# | **Type**                 | **Fallacy**                    | **Description** |
# |--------------------------|--------------------------------|----------------|
# | Formal                   | Affirming the Consequent      | Assuming that if *P → Q* and *Q is true*, then *P must be true*. |
# |                          | Denying the Antecedent        | Assuming that if *P → Q* and *P is false*, then *Q must be false*. |
# |                          | Non-Sequitur                  | The conclusion does not logically follow from the premises. |
# | Informal – Relevance     | **Ad Hominem**                    | Attacking the person instead of the argument. |
# |                          | **Straw Man**                     | Misrepresenting an argument to make it easier to attack. |
# |                          | **Red Herring**                   | Diverting attention with an irrelevant point. |
# |                          | **Appeal to Authority**           | Claiming something is true because an authority said so. |
# |                          | **Appeal to Emotion**             | Using emotions instead of logic to argue a point. |
# | Informal – Causation & Presumption | Post Hoc Ergo Propter Hoc | Assuming that correlation implies causation. |
# |                          | Slippery Slope                | Claiming one action will lead to extreme consequences. |
# |                          | False Dilemma                 | Presenting only two options when more exist. |
# |                          | Begging the Question          | Using circular reasoning. |
# |                          | False Equivalence             | Treating two things as equal when they are not. |
# |                          | Hasty Generalization          | Drawing a conclusion from insufficient evidence. |
# |                          | No True Scotsman              | Excluding counterexamples by redefining a group. |
#
# Logical fallacies can make arguments misleading or invalid. Identifying them helps improve critical thinking and debate skills.

# %% [markdown]
# ## Observation
# There were two sides when it comes to the vaccines
# * The covid-19 vaccines were bad, and cause side effects (including death)
# * The covid-19 vaccines were good and saved lives.
#
# ### News Articles & Headlines
# The One side of this can easily be seen in the news headlines, using logical fallacies
#
# #### Ad Hominem Attacks
# - [CDC Warns of 'Pandemic of the Unvaccinated'](https://www.cnn.com/videos/health/2021/07/21/delta-variant-coronavirus-vaccines-cohen-newday-vpx.cnn)
# - [Covid: French uproar as Macron vows to 'piss off' unvaccinated](https://www.bbc.com/news/world-europe-59873833?utm_source=chatgpt.com)
# - [Don Lemon Unloads on Unvaxxed: We Have to ‘Do Things For The Greater Good Of Society, Not For Idiots’](https://www.mediaite.com/tv/don-lemon-unloads-on-unvaxxed-we-have-to-do-things-for-the-greater-good-of-society-not-for-idiots/?utm_source=chatgpt.com)
# - [People Who Skip Vaccinations 'Incredibly Selfish' Experts Say](https://www.yahoo.com/lifestyle/people-who-skip-vaccinations-incredibly-selfish-108914416747.html?utm_source=chatgpt.com)
# - plague rats
# - selfish
# - anti-science
# - ignorant
# - irresponsible.
#
# #### Appeals to Authority
# - [Pope Francis urges people to get vaccinated against Covid-19](https://www.vaticannews.va/en/pope/news/2021-08/pope-francis-appeal-covid-19-vaccines-act-of-love.html)
# - [Former Presidents Obama, Bush and Clinton volunteer to get coronavirus vaccine publicly to prove it’s safe](https://www.cnn.com/2020/12/02/politics/obama-vaccine/index.html)
# - [FDA Approves First COVID-19 Vaccine](https://www.fda.gov/news-events/press-announcements/fda-approves-first-covid-19-vaccine?utm_source=chatgpt.com)
#
# #### Appeal to Emotions
# - [Getting Vaccinated to Help Protect Yourself, Your Family and Your Community](https://www.aha.org/news/perspective/2023-09-29-getting-vaccinated-help-protect-yourself-your-family-and-your-community?utm_source=chatgpt.com)
# - [COVID-19 Vaccines Protect the Family, Too](https://www.nih.gov/covid-19-vaccines-protect-family-too?utm_source=chatgpt.com)
# - [Concern about loved ones might motivate people to mask up, get vaccine](https://news.umich.edu/concern-about-loved-ones-might-motivate-people-to-mask-up-get-vaccine/?utm_source=chatgpt.com)

# %% [markdown]
# ## Hypothesis
# Given the time elapsed since the COVID-19 pandemic, can we assess the long-term effectiveness of COVID-19 vaccines through available data ?
#
# **Note:**
# This might not be a binary result (even though there are pretty binary sides),
# 1. `1.0` The vaccine could have a `possitive effect` in saving lives and getting society back to normal.
# 2. `0.5` The Vaccine could have a `slightly positive effect`
# 3. `0.0` The Vaccine could have a `null/no effect`
# 4. `-0.5` The Vaccine could have a `slightly negative effect`
# 5. `-1.0` The Vaccine could have a `negative effect`
# ... and of course we might dissagree on the results, and/or further research might need to be done.

# %% [markdown]
# ## Diving into the data.
#
# below we will be
# 1. **Experimentation** obtaining data, and producing some charts/graphs.
#     * this can't be a real experiment with a control group, since we are limited to the data,but i hope there is enough data to come to some conclusion.
# 2. **Conclusion** drawing the best conclusion we can from the data
# 3. **Replication** challening you (the audience) to do approve or disprove the conclusion with your own data science approach.

# %% [markdown]
# ## Setup
# In this section, we prepare the notebook by importing necessary libraries, configuring settings, and setting up directories for data and outputs. The setup ensures the environment is ready for data analysis and visualization.

# %%
# this code to will import all the things i need for this notebook

import os
import re
import math

import numpy as np
import pandas as pd

# for the notebook rendering 
from IPython.display import display, HTML
from IPython.display import Markdown as MD


# Graphs and Charts
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
# use to export plotly graphs
import plotly.io as pio 

#misc
from scipy.stats import spearmanr, kendalltau
import pycountry

# pandas Settings/Options
pd.set_option("display.max_rows", None) 
pd.set_option("display.max_columns", None)
pd.set_option('display.width', 9000)
pd.set_option('max_colwidth', 400)
pd.set_option('display.float_format', '{:.3f}'.format)

# colormap 
heatmapCM = sns.color_palette('Spectral_r', as_cmap=True)
heatmapCM1 = sns.color_palette('Spectral_r', as_cmap=True)
heatmapCM2 = sns.color_palette('coolwarm', as_cmap=True)
heatmapCM3 = sns.color_palette('viridis_r', as_cmap=True)


## directories 
DIR = os.getcwd()
print(f'{DIR=}')

DataDIR = os.path.join(DIR,'data')
OutDIR = os.path.join(DIR,'docs')

if not os.path.exists(DataDIR):
    print('***DATA FOLDER IS MISSING***')

if not os.path.exists(OutDIR):
    os.makedirs(OutDIR)
# Out:
# DIR='c:\\Users\\JGarza\\GitHub\\Excess_Mortality_And_Vaccines_In_Europe'

# %% [markdown]
# ## Helping Functions
# This section defines utility functions that streamline repetitive tasks and improve code readability. These functions will be used throughout the notebook to simplify operations, enhance modularity, and reduce redundancy.

# %%
def df_column_uniquify(df):
    '''
    renames columns that are the same
    '''
    df_columns = df.columns
    new_columns = []
    for item in df_columns:
        counter = 0
        newitem = item
        while newitem in new_columns:
            counter += 1
            newitem = "{}_{}".format(item, counter)
        new_columns.append(newitem)
    df.columns = new_columns
    return df

# %%
def abbr_to_isoalpha3(abbr):
    """
    Convert a European country ISO Alpha-2 code to ISO Alpha-3 code.

    Parameters:
        abbreviation (str): ISO Alpha-2 country code (e.g., 'DE' for Germany).

    Returns:
        str: ISO Alpha-3 country code (e.g., 'DEU'), or None if not found.
    """
    try:
        country = pycountry.countries.get(alpha_2=abbr.upper())
        if country:
            return country.alpha_3
        else:
            return None
    except KeyError:
        return None

# %%
# this if for converting between the abbreviation andand the names of the countries

country_dict = {
    "BE": "Belgium",
    "BG": "Bulgaria",
    "CZ": "Czechia",
    "DK": "Denmark",
    "DE": "Germany",
    "EE": "Estonia",
    "IE": "Ireland",
    "EL": "Greece",
    "ES": "Spain",
    "FR": "France",
    "HR": "Croatia",
    "IT": "Italy",
    "CY": "Cyprus",
    "LV": "Latvia",
    "LT": "Lithuania",
    "LU": "Luxembourg",
    "HU": "Hungary",
    "MT": "Malta",
    "NL": "Netherlands",
    "AT": "Austria",
    "PL": "Poland",
    "PT": "Portugal",
    "RO": "Romania",
    "SI": "Slovenia",
    "SK": "Slovakia",
    "FI": "Finland",
    "SE": "Sweden",
    "IS": "Iceland",
    "LI": "Liechtenstein",
    "NO": "Norway",
    "CH": "Switzerland",
    "UK": "United Kingdom",
    "ME": "Montenegro",
    "GE": "Georgia",
    "AL": "Albania",
    "RS": "Serbia",
    "AD": "Andorra",
    "AM": "Armenia"
}

def abbr_to_name(abbreviation):
    return country_dict.get(abbreviation.upper(), "Abbreviation not found")

def name_to_abbr(name):
    reverse_dict = {v: k for k, v in country_dict.items()}
    return reverse_dict.get(name, "Unknown")

# testing
print( abbr_to_name("BE") )  # Output: 'Belgium'
print( name_to_abbr("Belgium") )  # Output: 'BE'
# Out:
# Belgium
# BE

# %%
def bar(num,denom=100.0,length=25,fillchar='#',emptychar='_'):
    fillnum = ((int)( (num/denom) * length))
    return '[' + ( fillnum * fillchar ).ljust(length,emptychar)  + ']' # + f" {(num/denom)*100.0:.2f}%     "

# %% [markdown]
# ## Import and Clean Data

# %% [markdown]
# ### death data
#
# #### Getting the Data
# 1. go to [Europa.eu - Database](https://ec.europa.eu/eurostat/databrowser/explore/all/popul)
# 2. choose
#     * Population and social conditions
#     * Demography, population stock and balance
#     * Deaths by week – special data collection
#     * Deaths by week, sex and 20-year age group
# 3. Click the little table 󰓫
# 4. customize the data
#     * Customize your dataset -> Time -> From - to
#         * From: 2015-W01
#         * To: [Current or Max]
#     * Move the `Age Class` under `Geopolitical entity (reporting)`
# 5. Click `download` (as a spreadsheet) and place the file in the `.\data` folder

# %% [markdown]
# <img src='./docs/chrome_rZTvtL3J2L.png' height=400/>

# %% [markdown]
# #### variables
# * dd = death data (by year and week)
# * ddy = death data (by year)
# * ddn = normalized deaths (by year)

# %%
# getting the data 
dd = pd.read_excel(os.path.join(DataDIR,"demo_r_mwk_20__custom_15613355_page_spreadsheet.xlsx"),sheet_name = "Sheet 1")

# remove the headers
dd = dd.iloc[7::]

# drop the bad columns
for c in dd.columns:
    if pd.isnull(dd.at[7,c]):
        dd = dd.drop(columns=[c])

# rename time columns
for c in dd.columns:
    name = dd.at[7,c]
    dd = dd.rename(columns={c: name})

# make the duplicate column names unique
dd = df_column_uniquify(dd)

# # rename the first two columns
dd = dd.rename(columns={'TIME': 'abbr'})
dd = dd.rename(columns={'TIME_1':'name'})
dd = dd.rename(columns={'TIME_2':'agegrp'})
dd = dd.rename(columns={'TIME_3':'agegrp_desc'})
           
# drop, replace, reset index,
dd = dd.drop([7,8,9])
dd = dd.replace(to_replace=':', value=None)
dd = dd.reset_index(drop=True)

# display(dd.head(3))
display(dd.tail(10))
# Out:
# c:\Users\JGarza\pythons\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                    abbr           name  agegrp          agegrp_desc 2015-W01 2015-W02 2015-W03 2015-W04 2015-W05 2015-W06 2015-W07 2015-W08 2015-W09 2015-W10 2015-W11 2015-W12 2015-W13 2015-W14 2015-W15 2015-W16 2015-W17 2015-W18 2015-W19 2015-W20 2015-W21 2015-W22 2015-W23 2015-W24 2015-W25 2015-W26 2015-W27 2015-W28 2015-W29 2015-W30 2015-W31 2015-W32 2015-W33 2015-W34 2015-W35 2015-W36 2015-W37 2015-W38 2015-W39 2015-W40 2015-W41 2015-W42 2015-W43 2015-W44 2015-W45 2015-W46 2015-W47 2015-W48 2015-W49 2015-W50 2015-W51 2015-W52 2015-W53 2016-W01 2016-W02 2016-W03 2016-W04 2016-W05 2016-W06 2016-W07 2016-W08 2016-W09 2016-W10 2016-W11 2016-W12 2016-W13 2016-W14 2016-W15 2016-W16 2016-W17 2016-W18 2016-W19 2016-W20 2016-W21 2016-W22 2016-W23 2016-W24 2016-W25 2016-W26 2016-W27 2016-W28 2016-W29 2016-W30 2016-W31 2016-W32 2016-W33 2016-W34 2016-W35 2016-W36 2016-W37 2016-W38 2016-W39 2016-W40 2016-W41 2016-W42 2016-W43 2016-W44 2016-W45 2016-W46 2016-W47 2016-W48 2016-W49 2016-W50 2016-W51 2016-W52 2017-W01 2017-W02 2017-W03 2017-W04 2017-W05 2017-W06 2017-W07 2017-W08 2017-W09 2017-W10 2017-W11 2017-W12 2017-W13 2017-W14 2017-W15 2017-W16 2017-W17 2017-W18 2017-W19 2017-W20 2017-W21 2017-W22 2017-W23 2017-W24 2017-W25 2017-W26 2017-W27 2017-W28 2017-W29 2017-W30 2017-W31 2017-W32 2017-W33 2017-W34 2017-W35 2017-W36 2017-W37 2017-W38 2017-W39 2017-W40 2017-W41 2017-W42 2017-W43 2017-W44 2017-W45 2017-W46 2017-W47 2017-W48 2017-W49 2017-W50 2017-W51 2017-W52 2018-W01 2018-W02 2018-W03 2018-W04 2018-W05 2018-W06 2018-W07 2018-W08 2018-W09 2018-W10 2018-W11 2018-W12 2018-W13 2018-W14 2018-W15 2018-W16 2018-W17 2018-W18 2018-W19 2018-W20 2018-W21 2018-W22 2018-W23 2018-W24 2018-W25 2018-W26 2018-W27 2018-W28 2018-W29 2018-W30 2018-W31 2018-W32 2018-W33 2018-W34 2018-W35 2018-W36 2018-W37 2018-W38 2018-W39 2018-W40 2018-W41 2018-W42 2018-W43 2018-W44 2018-W45 2018-W46 2018-W47 2018-W48 2018-W49 2018-W50 2018-W51 2018-W52 2019-W01 2019-W02 2019-W03 2019-W04 2019-W05 2019-W06 2019-W07 2019-W08 2019-W09 2019-W10 2019-W11 2019-W12 2019-W13 2019-W14 2019-W15 2019-W16 2019-W17 2019-W18 2019-W19 2019-W20 2019-W21 2019-W22 2019-W23 2019-W24 2019-W25 2019-W26 2019-W27 2019-W28 2019-W29 2019-W30 2019-W31 2019-W32 2019-W33 2019-W34 2019-W35 2019-W36 2019-W37 2019-W38 2019-W39 2019-W40 2019-W41 2019-W42 2019-W43 2019-W44 2019-W45 2019-W46 2019-W47 2019-W48 2019-W49 2019-W50 2019-W51 2019-W52 2020-W01 2020-W02 2020-W03 2020-W04 2020-W05 2020-W06 2020-W07 2020-W08 2020-W09 2020-W10 2020-W11 2020-W12 2020-W13 2020-W14 2020-W15 2020-W16 2020-W17 2020-W18 2020-W19 2020-W20 2020-W21 2020-W22 2020-W23 2020-W24 2020-W25 2020-W26 2020-W27 2020-W28 2020-W29 2020-W30 2020-W31 2020-W32 2020-W33 2020-W34 2020-W35 2020-W36 2020-W37 2020-W38 2020-W39 2020-W40 2020-W41 2020-W42 2020-W43 2020-W44 2020-W45 2020-W46 2020-W47 2020-W48 2020-W49 2020-W50 2020-W51 2020-W52 2020-W53 2021-W01 2021-W02 2021-W03 2021-W04 2021-W05 2021-W06 2021-W07 2021-W08 2021-W09 2021-W10 2021-W11 2021-W12 2021-W13 2021-W14 2021-W15 2021-W16 2021-W17 2021-W18 2021-W19 2021-W20 2021-W21 2021-W22 2021-W23 2021-W24 2021-W25 2021-W26 2021-W27 2021-W28 2021-W29 2021-W30 2021-W31 2021-W32 2021-W33 2021-W34 2021-W35 2021-W36 2021-W37 2021-W38 2021-W39 2021-W40 2021-W41 2021-W42 2021-W43 2021-W44 2021-W45 2021-W46 2021-W47 2021-W48 2021-W49 2021-W50 2021-W51 2021-W52 2022-W01 2022-W02 2022-W03 2022-W04 2022-W05 2022-W06 2022-W07 2022-W08 2022-W09 2022-W10 2022-W11 2022-W12 2022-W13 2022-W14 2022-W15 2022-W16 2022-W17 2022-W18 2022-W19 2022-W20 2022-W21 2022-W22 2022-W23 2022-W24 2022-W25 2022-W26 2022-W27 2022-W28 2022-W29 2022-W30 2022-W31 2022-W32 2022-W33 2022-W34 2022-W35 2022-W36 2022-W37 2022-W38 2022-W39 2022-W40 2022-W41 2022-W42 2022-W43 2022-W44 2022-W45 2022-W46 2022-W47 2022-W48 2022-W49 2022-W50 2022-W51 2022-W52 2023-W01 2023-W02 2023-W03 2023-W04 2023-W05 2023-W06 2023-W07 2023-W08 2023-W09 2023-W10 2023-W11 2023-W12 2023-W13 2023-W14 2023-W15 2023-W16 2023-W17 2023-W18 2023-W19 ...
# 228                  AM        Armenia  Y_LT20   Less than 20 years       10        1       18        5       15       21       11        8        9       14       11        7       11       13        5        8        9       13       14       13       10        8       13       11       13       10       17       17       12        4       12       13       15       14       11       16       19       16       11        7       13        6        9        6       17        9       10       14        9        8       14       14       11        6       12       12       12       14       17       12        9       10        6        9       11       13       20       26       22        7       10       12       13       15       13       19       11        8       11       10       16       15       17        8        7       13        6        8       13       13        8        8       10        8        7       15       18        8       13       20       10       17        9        8       10        0       18       12       10        9        7       12       10       10        5       11        7       12       11       12        9       10       13       11       14        5        5        6       12       12       13       11       10       11        7       12        4       12       11       11       11       13       11       14       11       10        7       11        9        2       12        7       15        9        4        8        8        1       11        5        7       12        8       13       11       11        3       13        8        8       11        8       14       11        3        7       16        8        8       11       12        3       10        9       13       17        2        4        8        9        5        7       11       14       10       12        8        3        8       11       10        6       13        4        9        5        5       11        6        0        7        4        8        8       14        3        7       17       10       12        5        5        6        6        3        8        7        7        8        8        9       11        7        9        9        4       13        7       10        6       16        8        9        9        7        4        7        7        9        8        9        7        7        5        7        8        9        6        9        6        6        1        7        9        7       12       11       12       14       10       10        5       11        6       10        6        6       10       12       14       16        8        7       13        6       10        6        8        8        6       11        9        9        6        3        8       10        8        5        4       10       13       20      121      101      124       85       87       86       72       32       30       32       20       28       52       54       51       38       41       33       29       12        7        9        8        7       18       17       11       16       13       11        8       11       16        7        9       12       12       15       17        9       18       12        7        6       14       22       11       11        6       10        5       10       11        6       24       10        4       14       11       18        6        6        8       10        8       11        8        6        8       12        8       15        8        9        6        8        8       12        5        6        5        9        6       10       12       13        7        9        7        6        5        9        8        9        8        6        7       13        3       16       23       19       31       31       14       18       16        7       14        9       14       10       14        8       11        2        9       10       10       11        6        9        8       11        7       14        6       13       15       11        7        9        5        2 ...
# 229                  AM        Armenia  Y20-39  From 20 to 39 years        3        3       28       12       18       13       13       18       12       20       15       13       18       14        9       13       15       20        7       11       17       11       14       16       22        8       12       22       20       14       15       17       20       12       22       15       14       12       11       20       17       11       12        9       16       18       15       22        8       22       11       19        9        4       24       17       13       17       20       17       10        6        8       12       17       19       23       26       18       13       10        9       18       15       13       15       12       15       12       17        8       14       15       12       21       10        9        9       19       12       14       13       15       11       18       12       18       25        7       15       14       20       18       11        9        4       22       16       17       13       12       14       16       13       11       16       14        8        9       15       11       11       16       15       15        9       12       18       14       14       14       11       10       11       15       16       12       22       14       13       13       10        4       12        8        7       12       10       11       11       15       13       11       27        7        8        9        1       21       17       12       11       13       10        6       16        3       16       13       19       12       15       16       15       17       13       12       12       10       16       15       12       12       10       12       19        9       10       24        8       20       17       14       14        9       13       16        5       15       17       17        8       14       15       13       16       22       10       16        0        4       10        6       16        7        9       14       16       12        7       14       13       10       13       15        8       11       16       15       11       20        9        4       11       18       10        9       17        9       17       13        5       14       13       14       13       13       11        9       16       11       11        9       11       17       12       10       10       15       11       11        7       12        9       15       15       19       13       10        7       13       16        6        8        7       12       17        6        8       13       14        9        5       15       19       15       15       11        9       17       15       12       16       11       11       17       20       13       17        6       18       23       38      248      233      187      128      150       94       76       42       44       42       35       35       78       58       47       48       51       35       34       21       10       10       20       19       22       26       33       16       24       11       11       13       21        9       13       14       17       16       14       23       21       18       14       19       14       18       20       14       14       13       11       19       16       15       20       21       22       23       12       16       15       16        5        7       17       13        7       10       13       12       10       14       18        9        8        6       11       19        9        9       17        9       17       12       15       10       11       12       13       15       16       11       15        8       13       17       10       20       13       14       30       28       28       28       22       18       15        7       22       13       28       15       17       10        8        9        9       19       23       10       16       18       11       13       11       11        8       16       13       15       14       15        7        8 ...
# 230                  AM        Armenia  Y40-59  From 40 to 59 years       34       38      168      108       92       89       82       98       95       99       91      102       97       71       84       85       56       86       92      113       74       56       87       86       91       72       64       75       94       62       75       66       77       65       84       88       60       77       66       72       76       83       74       91       64       90       93       88       82       87       93       90       61       55      146      125       74      103       72       83       97       70       70       86       90       77       78       86       79       78       67       59       73       85       77       69       61       77       77       82       82       73       76       78       80       66       64       76       72       77       87       64       54       84       72       64       75       76       92       96       81       82       90       88       81       30      154       98       65       90       88       83      103       87       77       89       73       54       78       84       78       78       69       49       70       68       60       64       73       62       76       50       71       57       61       65       72       73       62       61       51       58       62       78       76       87       66       66       70       77       75       59       73       75       78       83       57       17       97       92       69       69       94       72       74       79       55       93       66       70       71       81       79       71       70       78       75       72       57       77       67       71       48       62       66       70       63       66       63       74       69       68       68       70       55       73       49       47       73       67       73       66       84       82       76       76       56       81       72       10       47       62       75       83       65       84       99       72       62       83       82       85       72       77       79       60       54       60       86       69       54       61       57       63       67       45       63       70       62       54       60       46       70       76       59       45       55       53       56       64       62       47       63       69       73       76       92       84       75       80       80       37       92       77       95       77       59       79       68       72       71       51       53       63       49       58       58       53       69       62       68       82       52       87       94       83       85       79       78       75       72       77       66       61       55       68       74       72       69       72       54       64       72      138      166      161      143      153      139      124      119      131      110       65       50      161       96       92       81      102       69       65       75       68       72       76       92       72       72      104       87       73       76       80       73       80       56       64       58       78       66       68       67       43       64       57       62       61       66       72       65       80       78       73       93      105      134      124      117      124       90       91       92       86       76       58       59       94       82       68       91       73       87       77       73       54       73       62       62       55       46       49       63       71       58       61       64       55       54       48       50       46       59       50       58       50       54       69       56       59       50       47       56       75       58       62       64       49       62       57       51       55       52       64       59       78       42       50       55       79       63       76       60       61       57       58       66       43       52       58       42       68       59       63       61       51       42 ...
# 231                  AM        Armenia  Y60-79  From 60 to 79 years      119       77      491      270      221      273      215      266      268      244      271      263      297      260      245      279      183      255      242      252      217      198      246      227      211      211      185      198      234      180      197      201      243      219      194      156      195      215      189      172      193      205      242      221      236      247      251      247      214      271      211      279      163      151      423      326      254      278      292      235      236      214      212      228      231      227      210      198      198      232      209      212      216      203      220      218      200      206      212      201      197      220      193      187      186      202      205      191      177      191      188      169      268      215      253      223      221      228      231      245      256      276      288      347      235       97      456      306      295      251      237      253      247      243      254      273      242      232      243      200      234      223      229      191      251      196      206      210      195      199      194      200      215      194      211      216      223      200      195      145      180      184      170      175      175      219      210      190      222      229      193      226      222      222      242      225      255       88      351      221      248      228      224      228      223      202      161      276      199      211      206      203      227      219      191      209      199      178      161      202      199      177      162      217      264      234      171      193      196      187      178      175      169      184      134      183      193      160      236      192      186      202      232      232      226      191      224      205      238       52      224      228      243      229      232      218      237      223      195      227      239      222      210      198      204      180      198      183      216      215      225      194      188      189      166      155      191      183      186      210      178      199      194      168      152      180      184      228      184      183      163      179      184      221      217      197      217      220      228      222      274      117      291      284      231      256      238      246      240      240      221      225      227      144      179      202      221      189      212      194      237      216      153      249      256      281      283      273      282      246      260      203      217      201      200      203      204      199      209      203      165      209      233      339      407      512      533      556      552      478      428      372      382      254      212      482      307      290      269      257      257      217      257      221      283      310      338      320      360      333      378      285      261      239      221      210      234      206      219      245      211      211      203      213      186      227      231      226      235      235      264      289      270      289      373      396      459      550      495      492      388      341      332      321      285      192      235      340      265      243      289      276      337      316      288      233      246      198      213      193      202      178      233      214      183      205      221      179      192      217      190      146      147      189      191      214      173      182      179      199      200      217      195      175      209      183      172      171      207      212      205      223      208      202      217      234      231      200      220      291      255      250      213      224      233      239      206      189      212      214      235      211      197      210      206      209      198 ...
# 232                  AM        Armenia  Y_GE80     80 years or over       83       66      389      266      214      219      190      226      244      201      215      233      260      218      242      213      144      219      211      209      184      196      198      177      186      203      190      186      184      156      175      182      174      203      178      125      153      164      164      177      145      146      202      184      172      184      190      226      179      220      238      241      146      124      376      291      211      251      236      237      204      164      215      195      199      195      187      223      209      193      206      193      190      187      213      194      186      198      189      174      162      212      195      148      179      204      155      170      160      142      163      163      177      172      196      202      178      205      242      222      236      283      285      330      278       84      464      304      277      255      275      236      262      230      202      230      252      223      229      272      213      193      247      168      212      186      195      207      197      187      179      183      183      175      196      188      230      214      180      165      147      153      137      153      147      173      191      223      217      221      214      187      214      211      215      222      223       64      356      278      256      222      253      243      248      192      182      260      207      200      157      158      173      188      203      196      179      179      180      177      178      180      198      244      253      236      160      167      187      159      160      147      177      153      141      167      179      122      205      211      199      185      223      222      227      216      204      189      205       52      215      273      265      244      237      243      210      220      227      261      231      242      199      236      190      197      212      237      253      211      175      211      185      190      237      147      223      196      197      186      176      172      195      184      142      149      167      195      184      193      172      205      192      210      192      211      241      209      265      191      262       90      291      256      263      219      263      245      243      280      275      251      227      172      203      218      219      200      206      232      224      249      181      299      259      242      263      264      280      209      290      259      199      198      217      172      185      198      164      194      177      200      228      275      366      501      483      540      515      450      401      388      384      270      194      503      290      268      265      281      260      215      247      209      241      254      279      292      301      328      318      267      265      239      217      237      212      211      216      277      213      195      190      178      162      202      198      221      231      210      228      239      243      269      313      341      369      433      445      425      384      334      297      290      272      227      270      352      284      241      315      352      433      493      396      301      269      243      218      235      176      163      206      186      162      203      184      173      190      184      171      138      146      196      201      211      159      181      174      188      171      178      161      165      210      159      174      164      154      183      177      176      182      173      172      203      184      222      183      261      219      227      220      195      201      203      213      216      227      214      200      176      190      183      171      168      176 ...
# 233                 NaN            NaN     NaN                  NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN ...
# 234       Special value            NaN     NaN                  NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN ...
# 235                None  not available     NaN                  NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN ...
# 236  Observation flags:            NaN     NaN                  NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN ...
# 237                   p    provisional     NaN                  NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN ...

# %%
# This code processes the raw death data (dd) by restructuring it into a long-form dataframe. 
# Each row in the new dataframe represents a single country's deaths for a specific year and week, 
# along with additional metadata such as country abbreviations and derived values.

temp = dd.melt(id_vars=['name','abbr','agegrp','agegrp_desc'],var_name='year-week',value_name='deaths')
temp['year'] = pd.to_numeric(temp['year-week'].str[0:4])
temp['week'] = pd.to_numeric(temp['year-week'].str[6:8])
temp['year.week'] = temp['year'] + temp['week']/100
temp['year.p'] = temp['year'] + (temp['week']/53.001)
dd = temp

# %%
# lets remove some data we don't need

# this is a combination of 27 countries
dd = dd[dd['abbr']!= 'EU27_2020'] 


dd = dd[dd['abbr']!= 'not available']
dd = dd[dd['abbr']!= 'Special value']
dd = dd[dd['abbr']!= 'None']
dd = dd[dd['abbr']!= 'Observation flags:']
dd = dd[dd['abbr']!= 'p']

# too early for 2025
dd = dd[dd['year']!= 2025]

dd = dd[~dd['name'].isna()]
dd = dd[~dd['agegrp'].isna()]

# we don't need these columns 
dd.drop(columns=['agegrp_desc'], inplace=True)
dd.drop(columns=['year-week'], inplace=True)

# converting columns 
dd['deaths'] = pd.to_numeric(dd['deaths'])

# %%
# there are quite a few NAN (not a number) values
# here we get rid of them 

# Get counts of NA values for each 'abbr' group
na_counts = dd[dd.deaths.isna()].groupby(['abbr','agegrp']).size()

# Filter for 'abbr' groups with more than 12 NA values
filtered_abbrs = na_counts[na_counts > 12*5].index

for abbr, agegrp in filtered_abbrs:
    print(f'removing -- {abbr} {abbr_to_name(abbr)} {agegrp} NACount={na_counts[(abbr, agegrp)]}')
    # Corrected filtering condition: remove rows where abbr and agegrp match separately
    dd = dd[~((dd.abbr == abbr) & (dd.agegrp == agegrp))]  # Use bitwise AND & inside the negation
    # print(len(dd))
# Out:
# removing -- AD Andorra TOTAL NACount=261
# removing -- AD Andorra Y20-39 NACount=261
# removing -- AD Andorra Y40-59 NACount=261
# removing -- AD Andorra Y60-79 NACount=261
# removing -- AD Andorra Y_GE80 NACount=261
# removing -- AD Andorra Y_LT20 NACount=261
# removing -- AL Albania TOTAL NACount=171
# removing -- AL Albania Y20-39 NACount=171
# removing -- AL Albania Y40-59 NACount=171
# removing -- AL Albania Y60-79 NACount=171
# removing -- AL Albania Y_GE80 NACount=171
# removing -- AL Albania Y_LT20 NACount=171
# removing -- GE Georgia TOTAL NACount=208
# removing -- GE Georgia Y20-39 NACount=208
# removing -- GE Georgia Y40-59 NACount=208
# removing -- GE Georgia Y60-79 NACount=208
# removing -- GE Georgia Y_GE80 NACount=208
# removing -- GE Georgia Y_LT20 NACount=208
# removing -- IE Ireland Y20-39 NACount=522
# removing -- IE Ireland Y40-59 NACount=522
# removing -- IE Ireland Y60-79 NACount=522
# removing -- IE Ireland Y_GE80 NACount=522
# removing -- IE Ireland Y_LT20 NACount=522
# removing -- UK United Kingdom TOTAL NACount=210
# removing -- UK United Kingdom Y20-39 NACount=210
# removing -- UK United Kingdom Y40-59 NACount=211
# removing -- UK United Kingdom Y60-79 NACount=210
# removing -- UK United Kingdom Y_GE80 NACount=210
# removing -- UK United Kingdom Y_LT20 NACount=210

# %%
# Fill missing values (NaNs) in the 2024 data with the mean deaths for 2024 by country

# Filter data for the year 2024
df_2024 = dd[dd.year == 2024]

# Group the 2024 data by country abbreviation ('abbr') and calculate summary statistics
grouped = df_2024.groupby(['abbr','agegrp'])

# Compute statistics: mean, total count, number of NaNs, total deaths, and mean deaths per week
stats = grouped['deaths'].agg(
    Mean='mean',                        # Average deaths for each country in 2024
    Count='size',                       # Total number of records for each country in 2024
    NACount=lambda x: x.isna().sum(),   # Count of missing (NaN) values
    SumFor2024='sum'                    # Total deaths for each country in 2024
).reset_index()

# Replace missing death values in 2024 with the calculated mean for each country
for _, row in stats.iterrows():
    dd.loc[
        (dd.abbr == row['abbr']) & (dd.agegrp == row['agegrp']) & (dd.year == 2024) & (dd.deaths.isna()), 
        'deaths'
    ] = row['Mean']

# %%
# we are going to create a new age group, everyone less than 80
# LT80 is less than 80 years old

# exclude where the age is greater than 80
temp = dd.copy()
temp = temp[temp['agegrp'] != 'TOTAL']
temp = temp[temp['agegrp'] != 'Y_GE80']

temp = pd.pivot_table(
    temp, 
    values='deaths', 
    index=['name', 'abbr','year','week','year.week','year.p'], 
    aggfunc='sum'
)
temp = temp.reset_index()

temp['agegrp'] = 'LT80'

dd = pd.concat([dd,temp])

# %%
# checking the data
display(dd.head(5))
display(dd.tail(5))
# Out:
#       name abbr  agegrp   deaths  year  week  year.week   year.p
# 5  Belgium   BE   TOTAL 2461.000  2015     1   2015.010 2015.019
# 6  Belgium   BE  Y_LT20   19.000  2015     1   2015.010 2015.019
# 7  Belgium   BE  Y20-39   34.000  2015     1   2015.010 2015.019
# 8  Belgium   BE  Y40-59  191.000  2015     1   2015.010 2015.019
# 9  Belgium   BE  Y60-79  756.000  2015     1   2015.010 2015.019
#               name abbr agegrp  deaths  year  week  year.week   year.p
# 17221  Switzerland   CH   LT80 420.000  2024    48   2024.480 2024.906
# 17222  Switzerland   CH   LT80 414.000  2024    49   2024.490 2024.925
# 17223  Switzerland   CH   LT80 466.000  2024    50   2024.500 2024.943
# 17224  Switzerland   CH   LT80 472.000  2024    51   2024.510 2024.962
# 17225  Switzerland   CH   LT80 501.000  2024    52   2024.520 2024.981

# %%
# save to out folder
dd.to_csv(r'out\death_data.csv',index=False)

# %%
ddy = pd.pivot_table(
    dd,
    values='deaths',
    index=['name', 'abbr','agegrp','year'], 
    aggfunc='sum'
)
ddy = ddy.reset_index()

display(ddy.head(5))
display(ddy.tail(5))

# save to out folder
ddy.to_csv(r'out\death_data_year.csv',index=False)
# Out:
#       name abbr agegrp  year    deaths
# 0  Armenia   AM   LT80  2015 17785.000
# 1  Armenia   AM   LT80  2016 17334.000
# 2  Armenia   AM   LT80  2017 16426.000
# 3  Armenia   AM   LT80  2018 15379.000
# 4  Armenia   AM   LT80  2019 14880.000
#              name abbr  agegrp  year  deaths
# 2315  Switzerland   CH  Y_LT20  2020 491.000
# 2316  Switzerland   CH  Y_LT20  2021 468.000
# 2317  Switzerland   CH  Y_LT20  2022 511.000
# 2318  Switzerland   CH  Y_LT20  2023 451.000
# 2319  Switzerland   CH  Y_LT20  2024 399.000

# %%
# here we normalize the death values

ddn = ddy.copy()
ddn['deaths_norm'] = 0.0

## baseline years are 2015,2016,2017 before the pandemic 
blyears = ddn[ddn.year.isin([2015,2016,2017])]
grouped = blyears.groupby(['abbr','agegrp'])

# Compute baseline mean
temp = grouped['deaths'].agg(
    baseline='mean',
).reset_index()

# Merge baseline means with the original DataFrame
ddn = ddn.merge(temp, on=['abbr', 'agegrp'], how='left')

# Normalize deaths column
ddn['deaths_norm'] = ddn['deaths'] / ddn['baseline']

# Drop the intermediate baseline column if not needed
ddn.drop(columns=['baseline'], inplace=True)

# save to out folder
ddn.to_csv(r'out\death_data_norm.csv',index=False)

# %% [markdown]
# ### cause of death
#
# #### Getting the Data
# 1. go to [Europa.eu - Database](https://ec.europa.eu/eurostat/databrowser/explore/all/popul)
# 2. choose
#     * Population and social conditions
#     * Health
#     * Causes of death
#     * General mortality
#     * Causes of death - deaths by country of residence and occurrence
# 3. Click the little table 󰓫
# 4. customize the data
#     * Customize your dataset -> Time -> From - to
#         * From: 2015
#         * To: [Current or Max]
#     * Customize your dataset -> `International Statistical Classification of Diseases and Related Health Problems (ICD-10 2010)`
#         * All
#             * UnCheck All
#         * Aggregates
#             * All Checked
#     * Move the ``International Statistical Classification...` under `Geopolitical entity (reporting)`
# 5. Click `download` (as a spreadsheet) and place the file in the `.\data` folder

# %% [markdown]
# <img src='./docs/chrome_Gmc2itqQye.png' height=200/>

# %% [markdown]
# #### variables
# * cod = cause of death data
# * codn = cod, normalized

# %%
# getting the data 
cod = pd.read_excel(os.path.join(DataDIR,"hlth_cd_aro__custom_15613373_page_spreadsheet.xlsx"),sheet_name = "Sheet 1")

# remove the headers
cod = cod.iloc[9::]

# drop the bad columns
for c in cod.columns:
    if pd.isnull(cod.at[9,c]):
        cod = cod.drop(columns=[c])

# rename time columns
for c in cod.columns:
    name = cod.at[9,c]
    cod = cod.rename(columns={c: name})

# make the duplicate column names unique
cod = df_column_uniquify(cod)

# # rename the first two columns
cod = cod.rename(columns={'TIME': 'name'})
cod = cod.rename(columns={'TIME_1':'cod'})
           
# drop, replace, reset index,
cod = cod.drop([9,10])
cod = cod.replace(to_replace=':', value=None)
cod = cod.reset_index(drop=True)

cod['abbr'] = cod['name'].apply(name_to_abbr)

# display(cod.head(5))
# Out:
# c:\Users\JGarza\pythons\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
# This code processes the raw cod data (cod) by restructuring it into a long-form dataframe. 
# along with additional metadata such as country abbreviations and derived values.

temp = cod.melt(id_vars=['name','abbr','cod'],var_name='year',value_name='deaths')
temp['year'] = pd.to_numeric(temp['year'])
cod = temp

# display(cod.head(10))

# %%
# lets remove some data we don't need

# this is a combination of 27 countries
cod.loc[cod['name']== 'European Union - 27 countries (from 2020)','abbr'] = 'Euro27'


cod = cod[cod['name']!= 'not available']
cod = cod[cod['name']!= 'Special value']
cod = cod[cod['name']!= 'None']
cod = cod[cod['name']!= 'Observation flags:']
cod = cod[cod['name']!= 'p']
cod = cod[cod['name']!= 'Nan']
cod = cod[cod['name']!= 'd']

cod = cod[~cod['name'].isna()]

# display(cod.tail(10))

# %%
# if a cause of death is null, we'll fill it with 0
cod['deaths'].fillna(0, inplace=True)
# Out:
# C:\Users\JGarza\AppData\Local\Temp\ipykernel_9444\2938650696.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cod['deaths'].fillna(0, inplace=True)
# C:\Users\JGarza\AppData\Local\Temp\ipykernel_9444\2938650696.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   cod['deaths'].fillna(0, inplace=True)

# %%
# save to out folder
cod.to_csv(r'out\cod_data.csv',index=False)

# %%
# here we normalize the cod data 

codn = cod.copy()
codn['deaths_norm'] = np.nan

## baseline years are 2015,2016,2017 before the pandemic 
blyears = codn[codn.year.isin([2015,2016,2017])]
grouped = blyears.groupby(['name','cod'])

# Compute baseline mean
temp = grouped['deaths'].agg(
    baseline='mean',
).reset_index()

# Merge baseline means with the original DataFrame
codn = codn.merge(temp, on=['name', 'cod'], how='left')

codn['baseline'] = codn['baseline'].replace(0, np.nan)

# set the death_norm to deaths/balseline
# * if the baseline is not NA
# * if the deaths is not NA
codn.loc[(~codn['baseline'].isna()) & (~codn['deaths'].isna()), 'deaths_norm'] = codn['deaths'] / codn['baseline']

# Drop the intermediate baseline column if not needed
codn.drop(columns=['baseline'], inplace=True)

# # save to out folder
codn.to_csv(r'out\cod_data_norm.csv',index=False)

# display(codn.head(1000))

# %% [markdown]
# ### vaccine data
#
# #### Getting the Data
# 1. Go to [https://www.ecdc.europa.eu/](https://www.ecdc.europa.eu/en/publications-data/data-covid-19-vaccination-eu-eea)
# 2. Click the `Download in CSV`.
#
#
# #### variables
# * vd = vaccine data

# %%
# import Vaccine Data 
vd = pd.read_csv(os.path.join(DataDIR,'data.csv'))

# create a year column
vd['year'] = pd.to_numeric(vd['YearWeekISO'].str[0:4])

# renaming columns for shorter names
vd = vd.rename(columns={'ReportingCountry':'abbr'})
vd = vd.rename(columns={'Vaccine':'vacc'})
vd = vd.rename(columns={'FirstDose':'dose1'})
vd = vd.rename(columns={'SecondDose':'dose2'})
vd = vd.rename(columns={'DoseAdditional1':'doesA1'})
vd = vd.rename(columns={'DoseAdditional2':'doesA2'})
vd = vd.rename(columns={'DoseAdditional3':'doesA3'})
vd = vd.rename(columns={'DoseAdditional4':'doesA4'})
vd = vd.rename(columns={'DoseAdditional5':'doesA5'})
vd = vd.rename(columns={'UnknownDose':'doseUNK'})

doseCol = ['dose1','dose2','doesA1','doesA2','doesA3','doesA4','doesA5','doseUNK']
# calculate the sum of all the Doses
vd = pd.pivot_table(
    data = vd,
    values = doseCol,
    index = ['abbr','year','Population','vacc'],
    aggfunc="sum"
    )
vd = vd.reset_index()

# gets get the total doses given 
vd['total_dose'] = vd[doseCol].sum(axis=1)
doseCol.append('total_dose')

# lets make a new record for all vaccines
temp = pd.pivot_table(
    data = vd,
    values = doseCol,
    index = ['abbr','year','Population'],
    aggfunc="sum"
    )
temp = temp.reset_index()
temp['vacc'] = 'All'

# and add it to all the vaccine data
vd = pd.concat([vd,temp])


# gets get the total dose1 (first dose) given 
vd['total_dose1'] = vd['dose1']

# dose1 ... cumulative sum, dose1/pop. , dose1/pop. normalize 
vd['td1_sum'] = vd.groupby(['abbr','vacc'])['total_dose1'].cumsum()
vd['dose1_pop_ratio'] = vd['td1_sum']/vd['Population']
## normalizsed version
vd['dpr1_norm'] = (vd['dose1_pop_ratio'] - vd['dose1_pop_ratio'].min()) / (vd['dose1_pop_ratio'].max() - vd['dose1_pop_ratio'].min())

vd['td_sum'] = vd.groupby(['abbr','vacc'])['total_dose'].cumsum()
vd['dose_pop_ratio'] = vd['td_sum']/vd['Population']
## normalizsed version
vd['dpr_norm'] = (vd['dose_pop_ratio'] - vd['dose_pop_ratio'].min()) / (vd['dose_pop_ratio'].max() - vd['dose_pop_ratio'].min())

vd['name'] = vd.abbr.apply(abbr_to_name)

# display(vd.head(5))
# display(vd.tail(5))

# save to out folder
vd.to_csv(r'out\vacc_data.csv',index=False)

# display(vd.head(100))

# an example of a few 
display(vd[(vd['abbr']=='FI') & (vd['vacc']=='All')])
display(vd[(vd['abbr']=='SK') & (vd['vacc']=='All')])
display(vd[(vd['abbr']=='RO') & (vd['vacc']=='All')])
# Out:
#    abbr  year  Population vacc    doesA1   doesA2   doesA3  doesA4  doesA5     dose1     dose2  doseUNK  total_dose  total_dose1   td1_sum  dose1_pop_ratio  dpr1_norm    td_sum  dose_pop_ratio  dpr_norm     name
# 40   FI  2020     5525292  All         0        0        0       0       0     34302         0        0       34302        34302     34302            0.006      0.001     34302           0.006     0.000  Finland
# 41   FI  2021     5533793  All   7677764     5430        0       0       0  26074546  24837830        0    58595570     26074546  26108848            4.718      0.963  58629872          10.595     0.711  Finland
# 42   FI  2022     5548241  All  10775614  7285662  2852542       0       0   1070686   1267740        0    23252244      1070686  27179534            4.899      1.000  81882116          14.758     0.991  Finland
# 43   FI  2023     5548241  All     46016   287352   419144       0       0      8336     11466        0      772314         8336  27187870            4.900      1.000  82654430          14.897     1.000  Finland
#     abbr  year  Population vacc   doesA1  doesA2  doesA3  doesA4  doesA5    dose1    dose2  doseUNK  total_dose  total_dose1  td1_sum  dose1_pop_ratio  dpr1_norm    td_sum  dose_pop_ratio  dpr_norm      name
# 114   SK  2020     5457873  All        0       0       0       0       0     9074       10        0        9084         9074     9074            0.002      0.000      9084           0.002     0.000  Slovakia
# 115   SK  2021     5459781  All  2207200      10       0       0       0  5417526  4894039        0    12518775      5417526  5426600            0.994      0.203  12527859           2.295     0.154  Slovakia
# 116   SK  2022     5434712  All  1155790  147247    1339       0       0   117886   215301        0     1637563       117886  5544486            1.020      0.208  14165422           2.606     0.175  Slovakia
# 117   SK  2023     5434712  All     1331    9468     973       0       0      798      648        0       13218          798  5545284            1.020      0.208  14178640           2.609     0.175  Slovakia
#     abbr  year  Population vacc   doesA1  doesA2  doesA3  doesA4  doesA5     dose1     dose2  doseUNK  total_dose  total_dose1   td1_sum  dose1_pop_ratio  dpr1_norm    td_sum  dose_pop_ratio  dpr_norm     name
# 103   RO  2021    19201662  All  3476669       0       0       0       0  24218464  17822935        0    45518068     24218464  24218464            1.261      0.257  45518068           2.371     0.159  Romania
# 104   RO  2022    19042455  All  1870277   79412       0       0       0    592941    606281        0     3148911       592941  24811405            1.303      0.266  48666979           2.556     0.172  Romania
# 105   RO  2023    19042455  All     8614   22476       0       0       0      6675      5265        0       43030         6675  24818080            1.303      0.266  48710009           2.558     0.172  Romania

# %% [markdown]
# ## combine all data
#
# ### variables
# cd = combined data

# %%
cols = ['name','abbr', 'year','source', 'filter','value_type','value']

cd = pd.DataFrame(columns=cols)


# deaths data 
temp = ddy.copy()

temp['source'] = 'deaths'
temp['filter'] = temp['agegrp']
temp['value_type'] = 'value'
temp['value'] = temp['deaths']

for c in temp.columns:
    if c not in cols:
        temp = temp.drop(columns=[c])

cd = pd.concat([cd,temp])

# deaths data normalized 

temp = ddn.copy()

temp['source'] = 'deaths'
temp['filter'] = temp['agegrp']
temp['value_type'] = 'normalized'
temp['value'] = temp['deaths_norm']

for c in temp.columns:
    if c not in cols:
        temp = temp.drop(columns=[c])

cd = pd.concat([cd,temp])

# cause of death data

temp = cod.copy()

temp['source'] = 'cause_of_death'
temp['filter'] = temp['cod']
temp['value_type'] = 'value'
temp['value'] = temp['deaths']

for c in temp.columns:
    if c not in cols:
        temp = temp.drop(columns=[c])

cd = pd.concat([cd,temp])


# cause of death data normalized

temp = codn.copy()

temp['source'] = 'cause_of_death'
temp['filter'] = temp['cod']
temp['value_type'] = 'normalized'
temp['value'] = temp['deaths_norm']

for c in temp.columns:
    if c not in cols:
        temp = temp.drop(columns=[c])

cd = pd.concat([cd,temp])


# Vaccine Data - total_dose1

temp = vd.copy()

temp['source'] = 'vaccine'
temp['filter'] = temp['vacc']
temp['value_type'] = 'value (first dose)'
temp['value'] = temp['total_dose1']

for c in temp.columns:
    if c not in cols:
        temp = temp.drop(columns=[c])

cd = pd.concat([cd,temp])

# Vaccine Data - total_dose1/pop

temp = vd.copy()

temp['source'] = 'vaccine'
temp['filter'] = temp['vacc']
temp['value_type'] = 'ratio (first dose/pop.)'
temp['value'] = temp['dose1_pop_ratio']

for c in temp.columns:
    if c not in cols:
        temp = temp.drop(columns=[c])

cd = pd.concat([cd,temp])


# Vaccine Data - total_dose1/pop normalizsed

temp = vd.copy()

temp['source'] = 'vaccine'
temp['filter'] = temp['vacc']
temp['value_type'] = 'normalized (first dose/pop.)'
temp['value'] = temp['dpr1_norm']

for c in temp.columns:
    if c not in cols:
        temp = temp.drop(columns=[c])

cd = pd.concat([cd,temp])


# Vaccine Data - total_dose

temp = vd.copy()

temp['source'] = 'vaccine'
temp['filter'] = temp['vacc']
temp['value_type'] = 'value (total_dose)'
temp['value'] = temp['total_dose']

for c in temp.columns:
    if c not in cols:
        temp = temp.drop(columns=[c])

cd = pd.concat([cd,temp])

# Vaccine Data - dose_pop_ratio
temp = vd.copy()

temp['source'] = 'vaccine'
temp['filter'] = temp['vacc']
temp['value_type'] = 'ratio (total_dose/pop.)'
temp['value'] = temp['dose_pop_ratio']

for c in temp.columns:
    if c not in cols:
        temp = temp.drop(columns=[c])

cd = pd.concat([cd,temp])

# Vaccine Data - dpr_norm
temp = vd.copy()

temp['source'] = 'vaccine'
temp['filter'] = temp['vacc']
temp['value_type'] = 'normalized (total_dose/pop.)'
temp['value'] = temp['dpr_norm']

for c in temp.columns:
    if c not in cols:
        temp = temp.drop(columns=[c])

cd = pd.concat([cd,temp])


display(cd.tail(5))
display(cd[(cd['source'] == 'deaths') & (cd['value_type'] == 'normalized')].tail(5))

# save to out folder
cd.to_csv(r'out\combined_data.csv',index=False)
# Out:
# C:\Users\JGarza\AppData\Local\Temp\ipykernel_9444\3464685614.py:18: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   cd = pd.concat([cd,temp])
#          name abbr  year   source filter                    value_type  value
# 113  Slovenia   SI  2023  vaccine    All  normalized (total_dose/pop.)  0.190
# 114  Slovakia   SK  2020  vaccine    All  normalized (total_dose/pop.)  0.000
# 115  Slovakia   SK  2021  vaccine    All  normalized (total_dose/pop.)  0.154
# 116  Slovakia   SK  2022  vaccine    All  normalized (total_dose/pop.)  0.175
# 117  Slovakia   SK  2023  vaccine    All  normalized (total_dose/pop.)  0.175
#              name abbr  year  source  filter  value_type  value
# 2315  Switzerland   CH  2020  deaths  Y_LT20  normalized  0.974
# 2316  Switzerland   CH  2021  deaths  Y_LT20  normalized  0.929
# 2317  Switzerland   CH  2022  deaths  Y_LT20  normalized  1.014
# 2318  Switzerland   CH  2023  deaths  Y_LT20  normalized  0.895
# 2319  Switzerland   CH  2024  deaths  Y_LT20  normalized  0.792

# %%
sources = cd['source'].drop_duplicates().to_list()

for s in sources:
    print('sources',s)
    filters = cd[cd['source']==s]['filter'].drop_duplicates().to_list()
    print('filters')
    print('\t',filters)
    value_types = cd[cd['source']==s]['value_type'].drop_duplicates().to_list()
    print('value_types')
    print('\t',value_types)
    print('---')
# Out:
# sources deaths
# filters
# 	 ['LT80', 'TOTAL', 'Y20-39', 'Y40-59', 'Y60-79', 'Y_GE80', 'Y_LT20']
# value_types
# 	 ['value', 'normalized']
# ---
# sources cause_of_death
# filters
# 	 ['Total', 'Certain infectious and parasitic diseases (A00-B99)', 'Tuberculosis', 'Viral hepatitis and sequelae of viral hepatitis', 'Chronic viral hepatitis B and C', 'Human immunodeficiency virus [HIV] disease', 'Other infectious and parasitic diseases (remainder of A00-B99)', 'Neoplasms', 'Malignant neoplasm of lip, oral cavity, pharynx', 'Malignant neoplasm of colon, rectosigmoid junction, rectum, anus and anal canal', 'Malignant neoplasm of trachea, bronchus and lung', 'Malignant neoplasm of other parts of uterus', 'Malignant neoplasm of brain and central nervous system', 'Hodgkin disease and lymphomas', 'Other malignant neoplasm of lymphoid, haematopoietic and related tissue', 'Leukaemia', 'Other malignant neoplasms (remainder of C00-C97)', 'Non-malignant neoplasms (benign and uncertain)', 'Diseases of the blood and blood-forming organs and certain disorders involving the immune mechanism', 'Diabetes mellitus', 'Other endocrine, nutritional and metabolic diseases (remainder of E00-E90)', 'Dementia', 'Drug dependence, toxicomania (F11-F16, F18-F19)', 'Other mental and behavioural disorders (remainder of F00-F99)', 'Diseases of the nervous system and the sense organs (G00-H95)', 'Other diseases of the nervous system and the sense organs (remainder of G00-H95)', 'Ischaemic heart diseases', 'Acute myocardial infarction including subsequent myocardial infarction', 'Other ischaemic heart diseases', 'Other heart diseases', 'Cerebrovascular diseases', 'Other diseases of the circulatory system (remainder of I00-I99)', 'Influenza (including swine flu)', 'Pneumonia', 'Chronic lower respiratory diseases', 'Asthma and status asthmaticus', 'Other lower respiratory diseases', 'Other diseases of the respiratory system (remainder of J00-J99)', 'Ulcer of stomach, duodenum and jejunum', 'Chronic liver disease', 'Chronic liver disease (excluding alcoholic and toxic liver disease)', 'Other diseases of the digestive system (remainder of K00-K93)', 'Rheumatoid arthritis and arthrosis (M05-M06,M15-M19)', 'Other diseases of the musculoskeletal system and connective tissue (remainder of M00-M99)', 'Diseases of kidney and ureter', 'Other diseases of the genitourinary system (remainder of N00-N99)', 'Ill-defined and unknown causes of mortality', 'Other symptoms, signs and abnormal clinical and laboratory findings (remainder of R00-R99)', 'COVID-19, other', 'External causes of morbidity and mortality (V01-Y89)', 'Accidents (V01-X59, Y85, Y86)', 'Transport accidents (V01-V99, Y85)', 'Other accidents (W20-W64, W75-X39, X50-X59, Y86)', 'Falls', 'Accidental drowning and submersion', 'Intentional self-harm', 'Accidental poisoning by and exposure to noxious substances', 'Assault', 'Event of undetermined intent', 'Other external causes of morbidity and mortality (remainder of V01-Y89)']
# value_types
# 	 ['value', 'normalized']
# ---
# sources vaccine
# filters
# 	 ['AZ', 'COM', 'COMBA.1', 'COMBA.4-5', 'JANSS', 'MOD', 'MODBA.1', 'NVXD', 'SGSK', 'UNK', 'VLA', 'MODBA.4-5', 'COMXBB', 'COMBIV', 'MODBIV', 'BECNBG', 'SPU', 'SIN', 'BHACOV', 'All']
# value_types
# 	 ['value (first dose)', 'ratio (first dose/pop.)', 'normalized (first dose/pop.)', 'value (total_dose)', 'ratio (total_dose/pop.)', 'normalized (total_dose/pop.)']
# ---

# %% [markdown]
# ## Lets Visualize the Data

# %% [markdown]
# ### Line Charts - normalized deaths

# %% [markdown]
# * Note
# the chart below shows that all the countries went through the pandemic 2020-2021,
# however some countries recovered (1.0 or less), and other countries still have higher than normal death rates (over 1.0).

# %%
title = 'Line Chart - normalized deaths in Europe 2015-2024 (by year)'
display(MD(f'### {title}'))

temp = cd[(cd['source']=='deaths') & (cd['filter']=='TOTAL') & (cd['value_type']=='normalized')]
temp = temp.sort_values(by='value', ascending=True)
temp = temp.sort_values(by='year', ascending=True)

fig = px.line(
    temp,
    x='year',
    y='value',
    color='name',
    height=750 ,
    hover_data={
        'name', 'abbr', 'value'
    },
    title=title
    )
fig.update_layout(template="plotly_dark")
# Out:
# ### Line Chart - normalized deaths in Europe 2015-2024 (by year)

# %%
title = 'Line Chart - normalized deaths in Europe 2015-2024 (by year)'
display(MD(f'### {title}'))

subtitle = 'Only the top 5 values in 2024, and the bottom 5 values in 2024'
display(MD(f'#### {subtitle}'))

temp = cd[(cd['source']=='deaths') & (cd['filter']=='TOTAL') & (cd['value_type']=='normalized')]

head2024 = temp[(temp['year']==2024)].sort_values(by='value', ascending=False).head(5)
tail2024 = temp[(temp['year']==2024)].sort_values(by='value', ascending=False).tail(5)


temp = temp[
    (temp['name'].isin(head2024.name))
    | (temp['name'].isin(tail2024.name))
    ]


temp = temp.sort_values(by='value', ascending=True)
temp = temp.sort_values(by='year', ascending=True)

fig = px.line(
    temp,
    x='year',
    y='value',
    color='name',
    height=750 ,
    hover_data={
        'name', 'abbr', 'value'
    },
    title=title
    )
fig.update_layout(template="plotly_dark")
# Out:
# ### Line Chart - normalized deaths in Europe 2015-2024 (by year)
# #### Only the top 5 values in 2024, and the bottom 5 values in 2024

# %% [markdown]
# * Note
# here we can see some data might not be trust-worthy.
# see `Liechtenstein`

# %%
title = 'Line Chart - normalized deaths in Europe 2015-2024 (by year)'
display(MD(f'### {title}'))

display(MD(f'#### Only the top 5 values in 2024, and the bottom 5 values in 2024'))
display(MD(f'#### Only where the deaths are from people who are less than 80 years old'))

temp = cd[(cd['source']=='deaths') & (cd['filter']=='LT80') & (cd['value_type']=='normalized')]

head2024 = temp[(temp['year']==2024)].sort_values(by='value', ascending=False).head(5)
tail2024 = temp[(temp['year']==2024)].sort_values(by='value', ascending=False).tail(5)


temp = temp[
    (temp['name'].isin(head2024.name))
    | (temp['name'].isin(tail2024.name))
    ]

temp = temp.sort_values(by='value', ascending=True)
temp = temp.sort_values(by='year', ascending=True)


fig = px.line(
    temp,
    x='year',
    y='value',
    color='name',
    height=750 ,
    hover_data={
        'name', 'abbr', 'value'
    },
    title=title
    )
fig.update_layout(template="plotly_dark")
# Out:
# ### Line Chart - normalized deaths in Europe 2015-2024 (by year)
# #### Only the top 5 values in 2024, and the bottom 5 values in 2024
# #### Only where the deaths are from people who are less than 80 years old

# %% [markdown]
# ### HeatMaps of deaths by AgeGroups

# %% [markdown]
# * Note
# we can see it a pattern where the older the agegroup is the more they experience higher the death rates in the post-pandemic years.
# however look at `Iceland` and `Netherlands` with the `Y20-39` agegroup ... they still experience a higher death rate even though this is a pretty young age group.
#
# * Note
# Something to note is that not all the agegroups where recommended the vaccine in the same way.
#
# Me:
# <p style="color: white; background-color: blue; padding: 10px; border-radius: 10px;">
# is there a source that shows european countries recommended the vaccine to older people ?
# </p>
#
# ChatGPT:
# <p style="color: white; background-color:rgb(70, 70, 70); padding: 10px; border-radius: 10px;">
# Yes, European countries have strongly recommended COVID-19 vaccination for older adults due to their increased risk of severe illness. The European Centre for Disease Prevention and Control (ECDC) has emphasized the importance of vaccinating high-risk groups, including the elderly. In October 2024, the ECDC reported that vaccination uptake among these groups was suboptimal in several EU/EEA Member States during the 2023–2024 season, underscoring the need for increased efforts to protect older populations.
# <a href='https://www.ecdc.europa.eu/en/news-events/increased-flu-and-covid-19-vaccination-coverage-recommended-risk-groups-eueea-ahead?utm_source=chatgpt.com'>ecdc.europa.eu</a>
# <br />
# <br />
# Additionally, the World Health Organization's Regional Office for Europe conducted a study published in October 2024, highlighting that COVID-19 vaccines prevented over half of COVID-19-related hospitalizations and severe outcomes, including death, particularly among older adults and those with underlying conditions. This finding reinforces the critical role of vaccination in safeguarding the health of the elderly population in Europe.
# <a href='https://www.who.int/europe/news-room/23-10-2024-vaccines-for-the-vulnerable--new-who-europe-study-shows-the-impact-of-covid-19-vaccines-in-safeguarding-health-and-saving-lives?utm_source=chatgpt.com'>who.int/europe</a>
# <br />
# <br />
# These recommendations and findings reflect a concerted effort across European health authorities to prioritize COVID-19 vaccination for older adults to mitigate severe health outcomes associated with the virus.
# </p>

# %%
display(MD('### HeatMap (of deaths based on age groups)'))

agegrps = cd[(cd['source']=='deaths')]['filter'].drop_duplicates().to_list()

for ag in agegrps:
    display(MD(f'#### {ag}'))
    temp = cd[(cd['source']=='deaths') & (cd['filter']==ag) & (cd['value_type']=='normalized')]

    temp = pd.pivot_table(
        data = temp,
        values = 'value',
        index = ['abbr','name','filter','value_type'],
        columns=['year'],
        aggfunc='mean',
    )
    temp.columns.name = 'index' 
    temp = temp.reset_index()

    ## sum of post pandemic deaths
    sppd = pd.pivot_table(
        cd[(cd['source']=='deaths') & (cd['filter']==ag) & (cd['value_type']=='normalized') & (cd['year'] > 2023)], # totals only 
        values = 'value',
        index = ['abbr','name'],
        aggfunc='sum',
    )
    sppd = sppd.reset_index()
    sppd = sppd.sort_values(by='value',ascending=False)
    
    temp = temp.set_index('name').reindex(sppd['name']).reset_index()

    display(temp.style.background_gradient(cmap=heatmapCM,axis=1))
# Out:
# ### HeatMap (of deaths based on age groups)
# #### LT80
# <style type="text/css">
# #T_09648_row0_col4, #T_09648_row1_col5, #T_09648_row2_col6, #T_09648_row3_col5, #T_09648_row3_col6, #T_09648_row4_col11, #T_09648_row5_col5, #T_09648_row6_col5, #T_09648_row7_col5, #T_09648_row8_col8, #T_09648_row9_col5, #T_09648_row10_col5, #T_09648_row11_col8, #T_09648_row12_col5, #T_09648_row13_col5, #T_09648_row14_col8, #T_09648_row15_col5, #T_09648_row16_col7, #T_09648_row17_col13, #T_09648_row18_col5, #T_09648_row18_col13, #T_09648_row19_col13, #T_09648_row20_col8, #T_09648_row21_col12, #T_09648_row22_col13, #T_09648_row23_col13, #T_09648_row24_col12, #T_09648_row25_col8, #T_09648_row26_col13, #T_09648_row27_col13, #T_09648_row28_col13, #T_09648_row29_col13, #T_09648_row30_col12, #T_09648_row31_col13, #T_09648_row32_col13 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_09648_row0_col5, #T_09648_row14_col13 {
#   background-color: #7ecca5;
#   color: #000000;
# }
# #T_09648_row0_col6, #T_09648_row13_col12, #T_09648_row15_col12, #T_09648_row20_col13 {
#   background-color: #3b92b9;
#   color: #f1f1f1;
# }
# #T_09648_row0_col7, #T_09648_row14_col7, #T_09648_row32_col12 {
#   background-color: #5cb7aa;
#   color: #f1f1f1;
# }
# #T_09648_row0_col8, #T_09648_row22_col7, #T_09648_row25_col13 {
#   background-color: #50a9af;
#   color: #f1f1f1;
# }
# #T_09648_row0_col9 {
#   background-color: #f5fbaf;
#   color: #000000;
# }
# #T_09648_row0_col10, #T_09648_row24_col11 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_09648_row0_col11, #T_09648_row1_col11, #T_09648_row2_col10, #T_09648_row3_col11, #T_09648_row4_col9, #T_09648_row5_col11, #T_09648_row6_col10, #T_09648_row7_col9, #T_09648_row8_col12, #T_09648_row9_col9, #T_09648_row10_col10, #T_09648_row11_col9, #T_09648_row12_col9, #T_09648_row13_col10, #T_09648_row14_col10, #T_09648_row15_col10, #T_09648_row16_col10, #T_09648_row17_col11, #T_09648_row18_col9, #T_09648_row19_col10, #T_09648_row20_col10, #T_09648_row21_col10, #T_09648_row22_col10, #T_09648_row23_col10, #T_09648_row24_col10, #T_09648_row25_col9, #T_09648_row26_col9, #T_09648_row27_col4, #T_09648_row28_col9, #T_09648_row29_col10, #T_09648_row30_col10, #T_09648_row31_col10, #T_09648_row32_col10 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_09648_row0_col12 {
#   background-color: #f36b43;
#   color: #f1f1f1;
# }
# #T_09648_row0_col13, #T_09648_row4_col10 {
#   background-color: #dc484c;
#   color: #f1f1f1;
# }
# #T_09648_row1_col4, #T_09648_row12_col13, #T_09648_row31_col12 {
#   background-color: #6bc4a5;
#   color: #000000;
# }
# #T_09648_row1_col6, #T_09648_row20_col6 {
#   background-color: #66c2a5;
#   color: #000000;
# }
# #T_09648_row1_col7 {
#   background-color: #d8ef9b;
#   color: #000000;
# }
# #T_09648_row1_col8, #T_09648_row6_col8 {
#   background-color: #a4daa4;
#   color: #000000;
# }
# #T_09648_row1_col9 {
#   background-color: #ea5e47;
#   color: #f1f1f1;
# }
# #T_09648_row1_col10 {
#   background-color: #b61b48;
#   color: #f1f1f1;
# }
# #T_09648_row1_col12 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_09648_row1_col13 {
#   background-color: #ef6645;
#   color: #f1f1f1;
# }
# #T_09648_row2_col4, #T_09648_row3_col7, #T_09648_row5_col8, #T_09648_row8_col4, #T_09648_row13_col4, #T_09648_row15_col4, #T_09648_row22_col8 {
#   background-color: #358bbc;
#   color: #f1f1f1;
# }
# #T_09648_row2_col5 {
#   background-color: #5061aa;
#   color: #f1f1f1;
# }
# #T_09648_row2_col7, #T_09648_row10_col13, #T_09648_row15_col7, #T_09648_row21_col5 {
#   background-color: #459eb4;
#   color: #f1f1f1;
# }
# #T_09648_row2_col8, #T_09648_row12_col6, #T_09648_row21_col8, #T_09648_row22_col12, #T_09648_row25_col7 {
#   background-color: #3d79b6;
#   color: #f1f1f1;
# }
# #T_09648_row2_col9 {
#   background-color: #f06744;
#   color: #f1f1f1;
# }
# #T_09648_row2_col11 {
#   background-color: #df4e4b;
#   color: #f1f1f1;
# }
# #T_09648_row2_col12, #T_09648_row30_col4 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_09648_row2_col13, #T_09648_row3_col12, #T_09648_row27_col11 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_09648_row3_col4, #T_09648_row30_col13 {
#   background-color: #4d65ad;
#   color: #f1f1f1;
# }
# #T_09648_row3_col8, #T_09648_row5_col7, #T_09648_row10_col7, #T_09648_row15_col8, #T_09648_row29_col12 {
#   background-color: #3f97b7;
#   color: #f1f1f1;
# }
# #T_09648_row3_col9, #T_09648_row7_col4 {
#   background-color: #8cd1a4;
#   color: #000000;
# }
# #T_09648_row3_col10, #T_09648_row14_col4, #T_09648_row16_col9, #T_09648_row32_col11 {
#   background-color: #d6ee9b;
#   color: #000000;
# }
# #T_09648_row3_col13, #T_09648_row14_col11, #T_09648_row28_col4 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_09648_row4_col4, #T_09648_row12_col11 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_09648_row4_col5 {
#   background-color: #a00343;
#   color: #f1f1f1;
# }
# #T_09648_row4_col6 {
#   background-color: #cd364d;
#   color: #f1f1f1;
# }
# #T_09648_row4_col7 {
#   background-color: #d23a4e;
#   color: #f1f1f1;
# }
# #T_09648_row4_col8 {
#   background-color: #e45549;
#   color: #f1f1f1;
# }
# #T_09648_row4_col12 {
#   background-color: #e3534a;
#   color: #f1f1f1;
# }
# #T_09648_row4_col13, #T_09648_row9_col6 {
#   background-color: #a90d45;
#   color: #f1f1f1;
# }
# #T_09648_row5_col4, #T_09648_row6_col6, #T_09648_row11_col5, #T_09648_row16_col13, #T_09648_row22_col6 {
#   background-color: #58b2ac;
#   color: #f1f1f1;
# }
# #T_09648_row5_col6, #T_09648_row21_col7 {
#   background-color: #4273b3;
#   color: #f1f1f1;
# }
# #T_09648_row5_col9 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_09648_row5_col10 {
#   background-color: #d0384e;
#   color: #f1f1f1;
# }
# #T_09648_row5_col12, #T_09648_row7_col11 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_09648_row5_col13, #T_09648_row18_col4 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_09648_row6_col4, #T_09648_row19_col8 {
#   background-color: #6ec5a5;
#   color: #000000;
# }
# #T_09648_row6_col7 {
#   background-color: #60bba8;
#   color: #000000;
# }
# #T_09648_row6_col9, #T_09648_row15_col9, #T_09648_row17_col12 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_09648_row6_col11 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_09648_row6_col12, #T_09648_row28_col11 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_09648_row6_col13, #T_09648_row11_col13, #T_09648_row12_col12, #T_09648_row20_col5, #T_09648_row20_col11, #T_09648_row32_col5 {
#   background-color: #c8e99e;
#   color: #000000;
# }
# #T_09648_row7_col6 {
#   background-color: #5956a5;
#   color: #f1f1f1;
# }
# #T_09648_row7_col7 {
#   background-color: #3b7cb7;
#   color: #f1f1f1;
# }
# #T_09648_row7_col8 {
#   background-color: #4471b2;
#   color: #f1f1f1;
# }
# #T_09648_row7_col10 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_09648_row7_col12 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_09648_row7_col13, #T_09648_row23_col9, #T_09648_row31_col7 {
#   background-color: #f7fcb2;
#   color: #000000;
# }
# #T_09648_row8_col5, #T_09648_row10_col4, #T_09648_row10_col8 {
#   background-color: #378ebb;
#   color: #f1f1f1;
# }
# #T_09648_row8_col6, #T_09648_row30_col8 {
#   background-color: #3387bc;
#   color: #f1f1f1;
# }
# #T_09648_row8_col7, #T_09648_row13_col7 {
#   background-color: #3682ba;
#   color: #f1f1f1;
# }
# #T_09648_row8_col9 {
#   background-color: #c3e79f;
#   color: #000000;
# }
# #T_09648_row8_col10, #T_09648_row24_col8, #T_09648_row28_col12 {
#   background-color: #f8fcb4;
#   color: #000000;
# }
# #T_09648_row8_col11 {
#   background-color: #cb334d;
#   color: #f1f1f1;
# }
# #T_09648_row8_col13 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_09648_row9_col4 {
#   background-color: #8fd2a4;
#   color: #000000;
# }
# #T_09648_row9_col7 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_09648_row9_col8, #T_09648_row17_col9, #T_09648_row24_col7 {
#   background-color: #f6fbb0;
#   color: #000000;
# }
# #T_09648_row9_col10 {
#   background-color: #d9444d;
#   color: #f1f1f1;
# }
# #T_09648_row9_col11, #T_09648_row27_col9, #T_09648_row30_col5 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_09648_row9_col12, #T_09648_row11_col11 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_09648_row9_col13 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_09648_row10_col6, #T_09648_row13_col13, #T_09648_row21_col6 {
#   background-color: #466eb1;
#   color: #f1f1f1;
# }
# #### TOTAL
# <style type="text/css">
# #T_d706c_row0_col4, #T_d706c_row13_col8, #T_d706c_row15_col4, #T_d706c_row18_col6, #T_d706c_row19_col4 {
#   background-color: #7ccaa5;
#   color: #000000;
# }
# #T_d706c_row0_col5, #T_d706c_row1_col4, #T_d706c_row2_col5, #T_d706c_row3_col5, #T_d706c_row4_col6, #T_d706c_row5_col6, #T_d706c_row6_col5, #T_d706c_row7_col5, #T_d706c_row8_col4, #T_d706c_row9_col5, #T_d706c_row10_col6, #T_d706c_row11_col5, #T_d706c_row12_col5, #T_d706c_row13_col5, #T_d706c_row14_col5, #T_d706c_row15_col5, #T_d706c_row16_col5, #T_d706c_row17_col5, #T_d706c_row18_col5, #T_d706c_row19_col5, #T_d706c_row20_col5, #T_d706c_row21_col5, #T_d706c_row22_col5, #T_d706c_row23_col5, #T_d706c_row24_col13, #T_d706c_row25_col8, #T_d706c_row26_col5, #T_d706c_row26_col13, #T_d706c_row27_col13, #T_d706c_row28_col12, #T_d706c_row29_col12, #T_d706c_row30_col13, #T_d706c_row31_col13, #T_d706c_row32_col13, #T_d706c_row33_col13 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_d706c_row0_col6, #T_d706c_row18_col13, #T_d706c_row29_col6, #T_d706c_row31_col5 {
#   background-color: #97d5a4;
#   color: #000000;
# }
# #T_d706c_row0_col7, #T_d706c_row25_col12 {
#   background-color: #e6f598;
#   color: #000000;
# }
# #T_d706c_row0_col8, #T_d706c_row19_col11 {
#   background-color: #e9f69d;
#   color: #000000;
# }
# #T_d706c_row0_col9, #T_d706c_row4_col13, #T_d706c_row8_col12, #T_d706c_row10_col10 {
#   background-color: #c72e4c;
#   color: #f1f1f1;
# }
# #T_d706c_row0_col10, #T_d706c_row10_col11 {
#   background-color: #cd364d;
#   color: #f1f1f1;
# }
# #T_d706c_row0_col11, #T_d706c_row1_col11, #T_d706c_row2_col9, #T_d706c_row3_col10, #T_d706c_row4_col11, #T_d706c_row5_col9, #T_d706c_row6_col9, #T_d706c_row7_col11, #T_d706c_row8_col11, #T_d706c_row9_col11, #T_d706c_row10_col9, #T_d706c_row11_col11, #T_d706c_row12_col11, #T_d706c_row13_col9, #T_d706c_row14_col9, #T_d706c_row15_col9, #T_d706c_row16_col9, #T_d706c_row17_col10, #T_d706c_row18_col10, #T_d706c_row19_col9, #T_d706c_row20_col10, #T_d706c_row21_col10, #T_d706c_row22_col10, #T_d706c_row23_col9, #T_d706c_row24_col10, #T_d706c_row25_col9, #T_d706c_row26_col10, #T_d706c_row27_col10, #T_d706c_row28_col10, #T_d706c_row29_col9, #T_d706c_row30_col10, #T_d706c_row31_col10, #T_d706c_row32_col10, #T_d706c_row33_col10 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_d706c_row0_col12 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_d706c_row0_col13 {
#   background-color: #df4e4b;
#   color: #f1f1f1;
# }
# #T_d706c_row1_col5, #T_d706c_row5_col8, #T_d706c_row13_col4, #T_d706c_row15_col6, #T_d706c_row28_col8 {
#   background-color: #4ea7b0;
#   color: #f1f1f1;
# }
# #T_d706c_row1_col6, #T_d706c_row9_col8, #T_d706c_row30_col12, #T_d706c_row32_col12 {
#   background-color: #5758a6;
#   color: #f1f1f1;
# }
# #T_d706c_row1_col7, #T_d706c_row4_col8, #T_d706c_row9_col7, #T_d706c_row22_col13, #T_d706c_row24_col4, #T_d706c_row27_col12, #T_d706c_row30_col8 {
#   background-color: #466eb1;
#   color: #f1f1f1;
# }
# #T_d706c_row1_col8, #T_d706c_row10_col4, #T_d706c_row19_col6 {
#   background-color: #3a7eb8;
#   color: #f1f1f1;
# }
# #T_d706c_row1_col9, #T_d706c_row23_col12, #T_d706c_row24_col11 {
#   background-color: #8fd2a4;
#   color: #000000;
# }
# #T_d706c_row1_col10, #T_d706c_row5_col10, #T_d706c_row23_col6 {
#   background-color: #86cfa5;
#   color: #000000;
# }
# #T_d706c_row1_col12 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_d706c_row1_col13 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_d706c_row2_col4, #T_d706c_row24_col7 {
#   background-color: #4273b3;
#   color: #f1f1f1;
# }
# #T_d706c_row2_col6 {
#   background-color: #4175b4;
#   color: #f1f1f1;
# }
# #T_d706c_row2_col7, #T_d706c_row17_col12, #T_d706c_row18_col4 {
#   background-color: #69c3a5;
#   color: #000000;
# }
# #T_d706c_row2_col8, #T_d706c_row4_col7, #T_d706c_row23_col8, #T_d706c_row28_col5 {
#   background-color: #47a0b3;
#   color: #f1f1f1;
# }
# #T_d706c_row2_col10 {
#   background-color: #b81e48;
#   color: #f1f1f1;
# }
# #T_d706c_row2_col11 {
#   background-color: #d0384e;
#   color: #f1f1f1;
# }
# #T_d706c_row2_col12 {
#   background-color: #d7414e;
#   color: #f1f1f1;
# }
# #T_d706c_row2_col13, #T_d706c_row11_col9, #T_d706c_row29_col10 {
#   background-color: #ad1246;
#   color: #f1f1f1;
# }
# #T_d706c_row3_col4 {
#   background-color: #acdda4;
#   color: #000000;
# }
# #T_d706c_row3_col6, #T_d706c_row15_col13 {
#   background-color: #b5e1a2;
#   color: #000000;
# }
# #T_d706c_row3_col7 {
#   background-color: #64c0a6;
#   color: #000000;
# }
# #T_d706c_row3_col8 {
#   background-color: #eff9a6;
#   color: #000000;
# }
# #T_d706c_row3_col9 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_d706c_row3_col11 {
#   background-color: #a00343;
#   color: #f1f1f1;
# }
# #T_d706c_row3_col12 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_d706c_row3_col13 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_d706c_row4_col4 {
#   background-color: #3682ba;
#   color: #f1f1f1;
# }
# #T_d706c_row4_col5 {
#   background-color: #525fa9;
#   color: #f1f1f1;
# }
# #T_d706c_row4_col9, #T_d706c_row8_col9, #T_d706c_row22_col11 {
#   background-color: #c8e99e;
#   color: #000000;
# }
# #T_d706c_row4_col10, #T_d706c_row13_col10 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_d706c_row4_col12 {
#   background-color: #a70b44;
#   color: #f1f1f1;
# }
# #T_d706c_row5_col4, #T_d706c_row8_col7 {
#   background-color: #4199b6;
#   color: #f1f1f1;
# }
# #T_d706c_row5_col5 {
#   background-color: #a2d9a4;
#   color: #000000;
# }
# #T_d706c_row5_col7 {
#   background-color: #bae3a1;
#   color: #000000;
# }
# #T_d706c_row5_col11 {
#   background-color: #e7f59a;
#   color: #000000;
# }
# #T_d706c_row5_col12, #T_d706c_row28_col6 {
#   background-color: #6bc4a5;
#   color: #000000;
# }
# #T_d706c_row5_col13, #T_d706c_row10_col12, #T_d706c_row32_col9 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_d706c_row6_col4, #T_d706c_row7_col6, #T_d706c_row32_col5 {
#   background-color: #49a2b2;
#   color: #f1f1f1;
# }
# #T_d706c_row6_col6 {
#   background-color: #edf8a3;
#   color: #000000;
# }
# #T_d706c_row6_col7, #T_d706c_row31_col11 {
#   background-color: #fefebd;
#   color: #000000;
# }
# #T_d706c_row6_col8 {
#   background-color: #fafdb7;
#   color: #000000;
# }
# #T_d706c_row6_col10 {
#   background-color: #f88950;
#   color: #f1f1f1;
# }
# #T_d706c_row6_col11, #T_d706c_row11_col12 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_d706c_row6_col12 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_d706c_row6_col13, #T_d706c_row14_col10 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_d706c_row7_col4 {
#   background-color: #71c6a5;
#   color: #000000;
# }
# #T_d706c_row7_col7, #T_d706c_row9_col10 {
#   background-color: #a4daa4;
#   color: #000000;
# }
# #T_d706c_row7_col8, #T_d706c_row11_col6, #T_d706c_row13_col7, #T_d706c_row15_col7, #T_d706c_row32_col6 {
#   background-color: #62bda7;
#   color: #000000;
# }
# #T_d706c_row7_col9, #T_d706c_row9_col12, #T_d706c_row11_col13 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_d706c_row7_col10 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_d706c_row7_col12, #T_d706c_row20_col9 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_d706c_row7_col13, #T_d706c_row12_col13 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_d706c_row8_col5, #T_d706c_row10_col5, #T_d706c_row19_col8, #T_d706c_row24_col5 {
#   background-color: #4b68ae;
#   color: #f1f1f1;
# }
# #T_d706c_row8_col6 {
#   background-color: #545ca8;
#   color: #f1f1f1;
# }
# #T_d706c_row8_col8, #T_d706c_row17_col4, #T_d706c_row17_col6 {
#   background-color: #486cb0;
#   color: #f1f1f1;
# }
# #T_d706c_row8_col10, #T_d706c_row10_col13 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_d706c_row8_col13, #T_d706c_row25_col4 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_d706c_row9_col4, #T_d706c_row10_col7, #T_d706c_row11_col8, #T_d706c_row19_col10 {
#   background-color: #6ec5a5;
#   color: #000000;
# }
# #T_d706c_row9_col6 {
#   background-color: #4e63ac;
#   color: #f1f1f1;
# }
# #T_d706c_row9_col9, #T_d706c_row13_col6, #T_d706c_row21_col8, #T_d706c_row26_col7 {
#   background-color: #4ba4b1;
#   color: #f1f1f1;
# }
# #T_d706c_row9_col13, #T_d706c_row23_col11 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_d706c_row10_col8, #T_d706c_row19_col7 {
#   background-color: #439bb5;
#   color: #f1f
# #### Y20-39
# <style type="text/css">
# #T_a8487_row0_col4, #T_a8487_row1_col4, #T_a8487_row2_col6, #T_a8487_row3_col8, #T_a8487_row3_col10, #T_a8487_row4_col7, #T_a8487_row5_col5, #T_a8487_row6_col10, #T_a8487_row7_col6, #T_a8487_row8_col7, #T_a8487_row9_col10, #T_a8487_row10_col10, #T_a8487_row11_col11, #T_a8487_row11_col12, #T_a8487_row12_col13, #T_a8487_row13_col13, #T_a8487_row14_col8, #T_a8487_row15_col13, #T_a8487_row16_col8, #T_a8487_row17_col13, #T_a8487_row18_col13, #T_a8487_row19_col13, #T_a8487_row20_col5, #T_a8487_row20_col13, #T_a8487_row21_col12, #T_a8487_row22_col8, #T_a8487_row23_col13, #T_a8487_row24_col13, #T_a8487_row25_col13, #T_a8487_row26_col13, #T_a8487_row27_col13, #T_a8487_row28_col13, #T_a8487_row29_col13, #T_a8487_row30_col13, #T_a8487_row31_col11, #T_a8487_row32_col13 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_a8487_row0_col5, #T_a8487_row15_col8 {
#   background-color: #eef8a4;
#   color: #000000;
# }
# #T_a8487_row0_col6, #T_a8487_row0_col11, #T_a8487_row28_col5 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_a8487_row0_col7 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_a8487_row0_col8, #T_a8487_row7_col10, #T_a8487_row22_col11 {
#   background-color: #d1ed9c;
#   color: #000000;
# }
# #T_a8487_row0_col9, #T_a8487_row5_col9 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_a8487_row0_col10 {
#   background-color: #fece7c;
#   color: #000000;
# }
# #T_a8487_row0_col12, #T_a8487_row1_col13, #T_a8487_row2_col13, #T_a8487_row3_col7, #T_a8487_row3_col9, #T_a8487_row4_col10, #T_a8487_row5_col8, #T_a8487_row6_col12, #T_a8487_row7_col4, #T_a8487_row8_col4, #T_a8487_row9_col5, #T_a8487_row10_col8, #T_a8487_row11_col4, #T_a8487_row12_col4, #T_a8487_row13_col4, #T_a8487_row14_col9, #T_a8487_row15_col10, #T_a8487_row16_col10, #T_a8487_row17_col4, #T_a8487_row18_col10, #T_a8487_row19_col4, #T_a8487_row20_col10, #T_a8487_row21_col10, #T_a8487_row22_col5, #T_a8487_row23_col4, #T_a8487_row24_col4, #T_a8487_row25_col10, #T_a8487_row26_col4, #T_a8487_row27_col4, #T_a8487_row28_col4, #T_a8487_row29_col4, #T_a8487_row30_col4, #T_a8487_row31_col7, #T_a8487_row32_col4, #T_a8487_row32_col11 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_a8487_row0_col13 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_a8487_row1_col5 {
#   background-color: #4471b2;
#   color: #f1f1f1;
# }
# #T_a8487_row1_col6, #T_a8487_row13_col8 {
#   background-color: #5956a5;
#   color: #f1f1f1;
# }
# #T_a8487_row1_col7, #T_a8487_row9_col13, #T_a8487_row22_col9 {
#   background-color: #3a7eb8;
#   color: #f1f1f1;
# }
# #T_a8487_row1_col8, #T_a8487_row23_col9 {
#   background-color: #54aead;
#   color: #f1f1f1;
# }
# #T_a8487_row1_col9, #T_a8487_row7_col12 {
#   background-color: #f9fcb5;
#   color: #000000;
# }
# #T_a8487_row1_col10 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_a8487_row1_col11, #T_a8487_row21_col6 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_a8487_row1_col12 {
#   background-color: #f06744;
#   color: #f1f1f1;
# }
# #T_a8487_row2_col4, #T_a8487_row14_col10 {
#   background-color: #ecf7a1;
#   color: #000000;
# }
# #T_a8487_row2_col5 {
#   background-color: #486cb0;
#   color: #f1f1f1;
# }
# #T_a8487_row2_col7, #T_a8487_row7_col8, #T_a8487_row15_col9, #T_a8487_row16_col5, #T_a8487_row19_col8, #T_a8487_row22_col10 {
#   background-color: #8cd1a4;
#   color: #000000;
# }
# #T_a8487_row2_col8, #T_a8487_row16_col7, #T_a8487_row29_col9 {
#   background-color: #81cda5;
#   color: #000000;
# }
# #T_a8487_row2_col9, #T_a8487_row26_col12 {
#   background-color: #50a9af;
#   color: #f1f1f1;
# }
# #T_a8487_row2_col10, #T_a8487_row25_col4 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_a8487_row2_col11, #T_a8487_row5_col6, #T_a8487_row5_col7, #T_a8487_row31_col5, #T_a8487_row31_col12 {
#   background-color: #e95c47;
#   color: #f1f1f1;
# }
# #T_a8487_row2_col12, #T_a8487_row13_col5, #T_a8487_row23_col8, #T_a8487_row26_col10 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_a8487_row3_col4, #T_a8487_row3_col6 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_a8487_row3_col5, #T_a8487_row12_col12, #T_a8487_row28_col9 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_a8487_row3_col11, #T_a8487_row3_col13 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_a8487_row3_col12, #T_a8487_row5_col10, #T_a8487_row5_col12, #T_a8487_row27_col12, #T_a8487_row31_col4, #T_a8487_row31_col13 {
#   background-color: #bfe5a0;
#   color: #000000;
# }
# #T_a8487_row4_col4, #T_a8487_row25_col11 {
#   background-color: #a4daa4;
#   color: #000000;
# }
# #T_a8487_row4_col5, #T_a8487_row28_col11 {
#   background-color: #84cea5;
#   color: #000000;
# }
# #T_a8487_row4_col6 {
#   background-color: #dc484c;
#   color: #f1f1f1;
# }
# #T_a8487_row4_col8, #T_a8487_row19_col6 {
#   background-color: #fcfeba;
#   color: #000000;
# }
# #T_a8487_row4_col9, #T_a8487_row4_col12 {
#   background-color: #f6fbb0;
#   color: #000000;
# }
# #T_a8487_row4_col11 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_a8487_row4_col13, #T_a8487_row17_col7, #T_a8487_row18_col8 {
#   background-color: #feeda1;
#   color: #000000;
# }
# #T_a8487_row5_col4, #T_a8487_row19_col10 {
#   background-color: #dff299;
#   color: #000000;
# }
# #T_a8487_row5_col11, #T_a8487_row30_col6 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_a8487_row5_col13, #T_a8487_row6_col5, #T_a8487_row6_col7, #T_a8487_row27_col8 {
#   background-color: #ffffbe;
#   color: #000000;
# }
# #T_a8487_row6_col4, #T_a8487_row24_col12, #T_a8487_row26_col7 {
#   background-color: #fbfdb8;
#   color: #000000;
# }
# #T_a8487_row6_col6, #T_a8487_row10_col4, #T_a8487_row11_col9 {
#   background-color: #66c2a5;
#   color: #000000;
# }
# #T_a8487_row6_col8 {
#   background-color: #fdfebb;
#   color: #000000;
# }
# #T_a8487_row6_col9, #T_a8487_row6_col13, #T_a8487_row15_col5 {
#   background-color: #f2faaa;
#   color: #000000;
# }
# #T_a8487_row6_col11 {
#   background-color: #6bc4a5;
#   color: #000000;
# }
# #T_a8487_row7_col5, #T_a8487_row22_col13 {
#   background-color: #71c6a5;
#   color: #000000;
# }
# #T_a8487_row7_col7 {
#   background-color: #94d4a4;
#   color: #000000;
# }
# #T_a8487_row7_col9, #T_a8487_row16_col12 {
#   background-color: #4b68ae;
#   color: #f1f1f1;
# }
# #T_a8487_row7_col11 {
#   background-color: #c1274a;
#   color: #f1f1f1;
# }
# #T_a8487_row7_col13 {
#   background-color: #3f97b7;
#   color: #f1f1f1;
# }
# #T_a8487_row8_col5, #T_a8487_row12_col8 {
#   background-color: #459eb4;
#   color: #f1f1f1;
# }
# #T_a8487_row8_col6, #T_a8487_row27_col7 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_a8487_row8_col8 {
#   background-color: #7ccaa5;
#   color: #000000;
# }
# #T_a8487_row8_col9, #T_a8487_row9_col11 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_a8487_row8_col10 {
#   background-color: #60bba8;
#   color: #000000;
# }
# #T_a8487_row8_col11, #T_a8487_row9_col8 {
#   background-color: #9cd7a4;
#   color: #000000;
# }
# #T_a8487_row8_col12, #T_a8487_row18_col12 {
#   background-color: #91d3a4;
#   color: #000000;
# }
# #T_a8487_row8_col13 {
#   background-color: #a2d9a4;
#   color: #000000;
# }
# #T_a8487_row9_col4 {
#   background-color: #49a2b2;
#   color: #f1f1f1;
# }
# #T_a8487_row9_col6 {
#   background-color: #74c7a5;
#   color: #000000;
# }
# #T_a8487_row9_col7, #T_a8487_row16_col9 {
#   background-color: #b5e1a2;
#   color: #000000;
# }
# #T_a8487_row9_col9 {
#   background-color: #c52c4b;
#   color: #f1f1f1;
# }
# #T_a8487_row9_col12 {
#   background-color: #c3e79f;
#   color: #000000;
# }
# #T_a8487_row10_col5 {
#   background-color: #daf09a;
#   color: #000000;
# }
# #T_a8487_row10_col6 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_a8487_row10_col7, #T_a8487_row20_col11 {
#   background-color: #62bda7;
#   color: #000000;
# }
# #T_a8487_row10_col9, #T_a8487_row15_col4 {
#   background-color: #f26944;
#   color: #f1f1f1;
# }
# #T_a8487_row10_col11 {
#   background-color: #99d6a4;
#   color: #000000;
# }
# #T_a8487_row10_col12 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_a8487_row10_col13 {
#   background-color: #5b53a4;
#   color: #f1f1f1;
# }
# #T_a8487_row11_col5 {
#   background-color: #cb334d;
#   color: #f1f1f1;
# }
# #T_a8487_row11_col6, #T_a8487_row13_col9 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_a8487_row11_col7, #T_a8487_row13_col11, #T_a8487_row17_col6 {
#   background-color: #ebf7a0;
#   color: #000000;
# #### Y40-59
# <style type="text/css">
# #T_f0fbf_row0_col4, #T_f0fbf_row0_col12, #T_f0fbf_row1_col12, #T_f0fbf_row2_col10, #T_f0fbf_row3_col4, #T_f0fbf_row4_col4, #T_f0fbf_row5_col9, #T_f0fbf_row6_col10, #T_f0fbf_row7_col9, #T_f0fbf_row8_col10, #T_f0fbf_row9_col4, #T_f0fbf_row10_col4, #T_f0fbf_row11_col10, #T_f0fbf_row12_col9, #T_f0fbf_row13_col9, #T_f0fbf_row14_col4, #T_f0fbf_row15_col10, #T_f0fbf_row16_col9, #T_f0fbf_row17_col4, #T_f0fbf_row18_col10, #T_f0fbf_row19_col10, #T_f0fbf_row20_col4, #T_f0fbf_row21_col4, #T_f0fbf_row22_col10, #T_f0fbf_row23_col4, #T_f0fbf_row24_col10, #T_f0fbf_row25_col10, #T_f0fbf_row26_col4, #T_f0fbf_row27_col4, #T_f0fbf_row28_col4, #T_f0fbf_row29_col4, #T_f0fbf_row30_col4, #T_f0fbf_row31_col4, #T_f0fbf_row32_col9 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_f0fbf_row0_col5, #T_f0fbf_row19_col4 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_f0fbf_row0_col6 {
#   background-color: #b11747;
#   color: #f1f1f1;
# }
# #T_f0fbf_row0_col7, #T_f0fbf_row21_col5 {
#   background-color: #ef6645;
#   color: #f1f1f1;
# }
# #T_f0fbf_row0_col8, #T_f0fbf_row17_col7 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_f0fbf_row0_col9 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_f0fbf_row0_col10 {
#   background-color: #d8434e;
#   color: #f1f1f1;
# }
# #T_f0fbf_row0_col11, #T_f0fbf_row1_col5, #T_f0fbf_row2_col13, #T_f0fbf_row3_col8, #T_f0fbf_row4_col13, #T_f0fbf_row5_col13, #T_f0fbf_row6_col13, #T_f0fbf_row7_col13, #T_f0fbf_row8_col13, #T_f0fbf_row9_col13, #T_f0fbf_row10_col13, #T_f0fbf_row11_col12, #T_f0fbf_row12_col13, #T_f0fbf_row13_col13, #T_f0fbf_row14_col13, #T_f0fbf_row15_col12, #T_f0fbf_row16_col13, #T_f0fbf_row17_col13, #T_f0fbf_row18_col13, #T_f0fbf_row19_col12, #T_f0fbf_row20_col13, #T_f0fbf_row21_col13, #T_f0fbf_row22_col13, #T_f0fbf_row23_col13, #T_f0fbf_row24_col13, #T_f0fbf_row25_col13, #T_f0fbf_row26_col13, #T_f0fbf_row27_col13, #T_f0fbf_row28_col13, #T_f0fbf_row29_col13, #T_f0fbf_row30_col13, #T_f0fbf_row31_col13, #T_f0fbf_row32_col12 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_f0fbf_row0_col13, #T_f0fbf_row7_col7 {
#   background-color: #c52c4b;
#   color: #f1f1f1;
# }
# #T_f0fbf_row1_col4, #T_f0fbf_row14_col7 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_f0fbf_row1_col6, #T_f0fbf_row9_col8, #T_f0fbf_row17_col12 {
#   background-color: #7ecca5;
#   color: #000000;
# }
# #T_f0fbf_row1_col7, #T_f0fbf_row23_col12, #T_f0fbf_row29_col12 {
#   background-color: #97d5a4;
#   color: #000000;
# }
# #T_f0fbf_row1_col8, #T_f0fbf_row13_col11 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_f0fbf_row1_col9 {
#   background-color: #feeda1;
#   color: #000000;
# }
# #T_f0fbf_row1_col10, #T_f0fbf_row22_col9, #T_f0fbf_row30_col8 {
#   background-color: #edf8a3;
#   color: #000000;
# }
# #T_f0fbf_row1_col11 {
#   background-color: #fdfebb;
#   color: #000000;
# }
# #T_f0fbf_row1_col13, #T_f0fbf_row20_col8, #T_f0fbf_row21_col8 {
#   background-color: #a2d9a4;
#   color: #000000;
# }
# #T_f0fbf_row2_col4 {
#   background-color: #86cfa5;
#   color: #000000;
# }
# #T_f0fbf_row2_col5, #T_f0fbf_row27_col12 {
#   background-color: #4175b4;
#   color: #f1f1f1;
# }
# #T_f0fbf_row2_col6, #T_f0fbf_row11_col13 {
#   background-color: #545ca8;
#   color: #f1f1f1;
# }
# #T_f0fbf_row2_col7 {
#   background-color: #555aa7;
#   color: #f1f1f1;
# }
# #T_f0fbf_row2_col8, #T_f0fbf_row22_col12 {
#   background-color: #5b53a4;
#   color: #f1f1f1;
# }
# #T_f0fbf_row2_col9 {
#   background-color: #e9f69d;
#   color: #000000;
# }
# #T_f0fbf_row2_col11, #T_f0fbf_row6_col8, #T_f0fbf_row11_col11 {
#   background-color: #89d0a4;
#   color: #000000;
# }
# #T_f0fbf_row2_col12, #T_f0fbf_row10_col12 {
#   background-color: #3b92b9;
#   color: #f1f1f1;
# }
# #T_f0fbf_row3_col5 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_f0fbf_row3_col6, #T_f0fbf_row6_col6, #T_f0fbf_row8_col4 {
#   background-color: #b3e0a2;
#   color: #000000;
# }
# #T_f0fbf_row3_col7, #T_f0fbf_row15_col5 {
#   background-color: #cdeb9d;
#   color: #000000;
# }
# #T_f0fbf_row3_col9 {
#   background-color: #5eb9a9;
#   color: #f1f1f1;
# }
# #T_f0fbf_row3_col10, #T_f0fbf_row4_col12, #T_f0fbf_row31_col12 {
#   background-color: #496aaf;
#   color: #f1f1f1;
# }
# #T_f0fbf_row3_col11, #T_f0fbf_row13_col5, #T_f0fbf_row19_col6, #T_f0fbf_row27_col9 {
#   background-color: #fece7c;
#   color: #000000;
# }
# #T_f0fbf_row3_col12, #T_f0fbf_row24_col9 {
#   background-color: #aedea3;
#   color: #000000;
# }
# #T_f0fbf_row3_col13 {
#   background-color: #4199b6;
#   color: #f1f1f1;
# }
# #T_f0fbf_row4_col5, #T_f0fbf_row8_col9, #T_f0fbf_row12_col7 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_f0fbf_row4_col6 {
#   background-color: #4b68ae;
#   color: #f1f1f1;
# }
# #T_f0fbf_row4_col7, #T_f0fbf_row30_col10 {
#   background-color: #d3ed9c;
#   color: #000000;
# }
# #T_f0fbf_row4_col8, #T_f0fbf_row8_col7 {
#   background-color: #4e63ac;
#   color: #f1f1f1;
# }
# #T_f0fbf_row4_col9, #T_f0fbf_row16_col6 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_f0fbf_row4_col10, #T_f0fbf_row12_col10 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_f0fbf_row4_col11, #T_f0fbf_row18_col6 {
#   background-color: #c8e99e;
#   color: #000000;
# }
# #T_f0fbf_row5_col4 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_f0fbf_row5_col5, #T_f0fbf_row13_col8, #T_f0fbf_row28_col9 {
#   background-color: #f8fcb4;
#   color: #000000;
# }
# #T_f0fbf_row5_col6, #T_f0fbf_row20_col7, #T_f0fbf_row25_col7, #T_f0fbf_row31_col6 {
#   background-color: #f4faad;
#   color: #000000;
# }
# #T_f0fbf_row5_col7, #T_f0fbf_row6_col9, #T_f0fbf_row6_col11, #T_f0fbf_row12_col8, #T_f0fbf_row24_col11, #T_f0fbf_row26_col10 {
#   background-color: #eff9a6;
#   color: #000000;
# }
# #T_f0fbf_row5_col8, #T_f0fbf_row13_col12 {
#   background-color: #acdda4;
#   color: #000000;
# }
# #T_f0fbf_row5_col10, #T_f0fbf_row17_col6, #T_f0fbf_row30_col6 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_f0fbf_row5_col11, #T_f0fbf_row21_col9 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_f0fbf_row5_col12 {
#   background-color: #71c6a5;
#   color: #000000;
# }
# #T_f0fbf_row6_col4 {
#   background-color: #f9fcb5;
#   color: #000000;
# }
# #T_f0fbf_row6_col5, #T_f0fbf_row18_col9 {
#   background-color: #cfec9d;
#   color: #000000;
# }
# #T_f0fbf_row6_col7, #T_f0fbf_row15_col6 {
#   background-color: #7ccaa5;
#   color: #000000;
# }
# #T_f0fbf_row6_col12, #T_f0fbf_row30_col12 {
#   background-color: #5ab4ab;
#   color: #f1f1f1;
# }
# #T_f0fbf_row7_col4, #T_f0fbf_row14_col6, #T_f0fbf_row27_col7 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_f0fbf_row7_col5 {
#   background-color: #dd4a4c;
#   color: #f1f1f1;
# }
# #T_f0fbf_row7_col6 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_f0fbf_row7_col8, #T_f0fbf_row25_col9, #T_f0fbf_row29_col6 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_f0fbf_row7_col10, #T_f0fbf_row27_col10 {
#   background-color: #a70b44;
#   color: #f1f1f1;
# }
# #T_f0fbf_row7_col11, #T_f0fbf_row27_col11 {
#   background-color: #e1f399;
#   color: #000000;
# }
# #T_f0fbf_row7_col12 {
#   background-color: #94d4a4;
#   color: #000000;
# }
# #T_f0fbf_row8_col5, #T_f0fbf_row12_col12 {
#   background-color: #74c7a5;
#   color: #000000;
# }
# #T_f0fbf_row8_col6, #T_f0fbf_row11_col5, #T_f0fbf_row22_col11 {
#   background-color: #9cd7a4;
#   color: #000000;
# }
# #T_f0fbf_row8_col8, #T_f0fbf_row32_col11 {
#   background-color: #60bba8;
#   color: #000000;
# }
# #T_f0fbf_row8_col11, #T_f0fbf_row20_col10, #T_f0fbf_row25_col11, #T_f0fbf_row30_col9 {
#   background-color: #daf09a;
#   color: #000000;
# }
# #T_f0fbf_row8_col12, #T_f0fbf_row11_col9, #T_f0fbf_row22_col5 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_f0fbf_row9_col5 {
#   background-color: #e2514a;
#   color: #f1f1f1;
# }
# #T_f0fbf_row9_col6, #T_f0fbf_row10_col6, #T_f0fbf_row19_col8 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_f0fbf_row9_col7 {
#   background-color: #f6fbb0;
#   color: #000000;
# }
# #T_f0fbf_row9_col9, #T_f0fbf_row23_col9 {
#   background-color: #fbfdb8;
#   color: #000000;
# }
# #T_f0fbf_row9_col10 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_f0fbf_row9_col11 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_f0fbf_row9_col12 {
#   background-color: #378ebb;
#   color: #f1f1f1;
# }
# #T_f0fbf_row10_col5 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_f0fbf_row10_
# #### Y60-79
# <style type="text/css">
# #T_23b44_row0_col4, #T_23b44_row1_col5, #T_23b44_row2_col5, #T_23b44_row3_col5, #T_23b44_row4_col5, #T_23b44_row5_col11, #T_23b44_row6_col5, #T_23b44_row7_col5, #T_23b44_row8_col5, #T_23b44_row9_col4, #T_23b44_row10_col8, #T_23b44_row11_col5, #T_23b44_row12_col6, #T_23b44_row13_col5, #T_23b44_row14_col5, #T_23b44_row15_col5, #T_23b44_row15_col6, #T_23b44_row16_col5, #T_23b44_row17_col7, #T_23b44_row18_col8, #T_23b44_row19_col5, #T_23b44_row20_col5, #T_23b44_row21_col5, #T_23b44_row22_col8, #T_23b44_row23_col12, #T_23b44_row24_col8, #T_23b44_row25_col12, #T_23b44_row26_col13, #T_23b44_row27_col12, #T_23b44_row28_col13, #T_23b44_row29_col13, #T_23b44_row30_col13, #T_23b44_row31_col13, #T_23b44_row32_col13 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_23b44_row0_col5, #T_23b44_row18_col4, #T_23b44_row27_col5 {
#   background-color: #c6e89f;
#   color: #000000;
# }
# #T_23b44_row0_col6 {
#   background-color: #3b92b9;
#   color: #f1f1f1;
# }
# #T_23b44_row0_col7, #T_23b44_row6_col8, #T_23b44_row14_col4, #T_23b44_row17_col6 {
#   background-color: #60bba8;
#   color: #000000;
# }
# #T_23b44_row0_col8, #T_23b44_row6_col7, #T_23b44_row32_col12 {
#   background-color: #56b0ad;
#   color: #f1f1f1;
# }
# #T_23b44_row0_col9 {
#   background-color: #e8f69b;
#   color: #000000;
# }
# #T_23b44_row0_col10 {
#   background-color: #fcfeba;
#   color: #000000;
# }
# #T_23b44_row0_col11, #T_23b44_row1_col11, #T_23b44_row2_col11, #T_23b44_row3_col10, #T_23b44_row4_col11, #T_23b44_row5_col9, #T_23b44_row6_col10, #T_23b44_row7_col9, #T_23b44_row8_col10, #T_23b44_row9_col12, #T_23b44_row10_col9, #T_23b44_row11_col10, #T_23b44_row12_col10, #T_23b44_row13_col6, #T_23b44_row14_col9, #T_23b44_row15_col11, #T_23b44_row16_col10, #T_23b44_row17_col10, #T_23b44_row18_col10, #T_23b44_row19_col9, #T_23b44_row20_col10, #T_23b44_row21_col10, #T_23b44_row22_col10, #T_23b44_row23_col10, #T_23b44_row24_col4, #T_23b44_row25_col10, #T_23b44_row26_col10, #T_23b44_row27_col10, #T_23b44_row28_col9, #T_23b44_row29_col10, #T_23b44_row30_col9, #T_23b44_row31_col10, #T_23b44_row32_col10 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_23b44_row0_col12, #T_23b44_row13_col13 {
#   background-color: #fece7c;
#   color: #000000;
# }
# #T_23b44_row0_col13, #T_23b44_row3_col11 {
#   background-color: #d8434e;
#   color: #f1f1f1;
# }
# #T_23b44_row1_col4 {
#   background-color: #91d3a4;
#   color: #000000;
# }
# #T_23b44_row1_col6, #T_23b44_row8_col7 {
#   background-color: #8fd2a4;
#   color: #000000;
# }
# #T_23b44_row1_col7, #T_23b44_row11_col9, #T_23b44_row19_col8, #T_23b44_row29_col11 {
#   background-color: #e4f498;
#   color: #000000;
# }
# #T_23b44_row1_col8 {
#   background-color: #ddf19a;
#   color: #000000;
# }
# #T_23b44_row1_col9 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_23b44_row1_col10 {
#   background-color: #a00343;
#   color: #f1f1f1;
# }
# #T_23b44_row1_col12 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_23b44_row1_col13 {
#   background-color: #a40844;
#   color: #f1f1f1;
# }
# #T_23b44_row2_col4, #T_23b44_row3_col4, #T_23b44_row11_col4 {
#   background-color: #466eb1;
#   color: #f1f1f1;
# }
# #T_23b44_row2_col6, #T_23b44_row20_col6 {
#   background-color: #3682ba;
#   color: #f1f1f1;
# }
# #T_23b44_row2_col7, #T_23b44_row18_col11, #T_23b44_row20_col8, #T_23b44_row21_col12, #T_23b44_row30_col12 {
#   background-color: #50a9af;
#   color: #f1f1f1;
# }
# #T_23b44_row2_col8, #T_23b44_row8_col6 {
#   background-color: #62bda7;
#   color: #000000;
# }
# #T_23b44_row2_col9 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_23b44_row2_col10 {
#   background-color: #c9314c;
#   color: #f1f1f1;
# }
# #T_23b44_row2_col12, #T_23b44_row5_col10, #T_23b44_row12_col11 {
#   background-color: #ed6246;
#   color: #f1f1f1;
# }
# #T_23b44_row2_col13, #T_23b44_row5_col8, #T_23b44_row13_col10 {
#   background-color: #e45549;
#   color: #f1f1f1;
# }
# #T_23b44_row3_col6, #T_23b44_row4_col4, #T_23b44_row26_col12 {
#   background-color: #5c51a3;
#   color: #f1f1f1;
# }
# #T_23b44_row3_col7, #T_23b44_row12_col7, #T_23b44_row30_col7 {
#   background-color: #58b2ac;
#   color: #f1f1f1;
# }
# #T_23b44_row3_col8, #T_23b44_row23_col5, #T_23b44_row24_col13 {
#   background-color: #47a0b3;
#   color: #f1f1f1;
# }
# #T_23b44_row3_col9 {
#   background-color: #e75948;
#   color: #f1f1f1;
# }
# #T_23b44_row3_col12 {
#   background-color: #d9444d;
#   color: #f1f1f1;
# }
# #T_23b44_row3_col13 {
#   background-color: #da464d;
#   color: #f1f1f1;
# }
# #T_23b44_row4_col6, #T_23b44_row9_col8 {
#   background-color: #4175b4;
#   color: #f1f1f1;
# }
# #T_23b44_row4_col7, #T_23b44_row20_col7 {
#   background-color: #54aead;
#   color: #f1f1f1;
# }
# #T_23b44_row4_col8, #T_23b44_row18_col6 {
#   background-color: #76c8a5;
#   color: #000000;
# }
# #T_23b44_row4_col9, #T_23b44_row8_col8 {
#   background-color: #bce4a0;
#   color: #000000;
# }
# #T_23b44_row4_col10, #T_23b44_row29_col4 {
#   background-color: #fdfebb;
#   color: #000000;
# }
# #T_23b44_row4_col12 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_23b44_row4_col13 {
#   background-color: #ea5e47;
#   color: #f1f1f1;
# }
# #T_23b44_row5_col4, #T_23b44_row15_col12 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_23b44_row5_col5 {
#   background-color: #af1446;
#   color: #f1f1f1;
# }
# #T_23b44_row5_col6, #T_23b44_row5_col7 {
#   background-color: #e2514a;
#   color: #f1f1f1;
# }
# #T_23b44_row5_col12, #T_23b44_row25_col9 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_23b44_row5_col13 {
#   background-color: #b41947;
#   color: #f1f1f1;
# }
# #T_23b44_row6_col4, #T_23b44_row11_col6, #T_23b44_row20_col13, #T_23b44_row26_col6, #T_23b44_row26_col8 {
#   background-color: #4471b2;
#   color: #f1f1f1;
# }
# #T_23b44_row6_col6, #T_23b44_row22_col4 {
#   background-color: #3b7cb7;
#   color: #f1f1f1;
# }
# #T_23b44_row6_col9 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_23b44_row6_col11 {
#   background-color: #ffffbe;
#   color: #000000;
# }
# #T_23b44_row6_col12, #T_23b44_row17_col13, #T_23b44_row20_col11, #T_23b44_row26_col11 {
#   background-color: #b8e2a1;
#   color: #000000;
# }
# #T_23b44_row6_col13, #T_23b44_row14_col7 {
#   background-color: #b5e1a2;
#   color: #000000;
# }
# #T_23b44_row7_col4 {
#   background-color: #6ec5a5;
#   color: #000000;
# }
# #T_23b44_row7_col6, #T_23b44_row10_col5 {
#   background-color: #5758a6;
#   color: #f1f1f1;
# }
# #T_23b44_row7_col7, #T_23b44_row26_col4, #T_23b44_row27_col13 {
#   background-color: #3585bb;
#   color: #f1f1f1;
# }
# #T_23b44_row7_col8, #T_23b44_row11_col8 {
#   background-color: #358bbc;
#   color: #f1f1f1;
# }
# #T_23b44_row7_col10 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_23b44_row7_col11 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_23b44_row7_col12 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_23b44_row7_col13 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_23b44_row8_col4, #T_23b44_row11_col12 {
#   background-color: #66c2a5;
#   color: #000000;
# }
# #T_23b44_row8_col9 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_23b44_row8_col11 {
#   background-color: #be254a;
#   color: #f1f1f1;
# }
# #T_23b44_row8_col12, #T_23b44_row30_col4 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_23b44_row8_col13, #T_23b44_row19_col4 {
#   background-color: #fbfdb8;
#   color: #000000;
# }
# #T_23b44_row9_col5, #T_23b44_row22_col13 {
#   background-color: #4b68ae;
#   color: #f1f1f1;
# }
# #T_23b44_row9_col6 {
#   background-color: #3a7eb8;
#   color: #f1f1f1;
# }
# #T_23b44_row9_col7 {
#   background-color: #3387bc;
#   color: #f1f1f1;
# }
# #T_23b44_row9_col9, #T_23b44_row15_col7 {
#   background-color: #b3e0a2;
#   color: #000000;
# }
# #T_23b44_row9_col10, #T_23b44_row25_col11 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_23b44_row9_col11 {
#   background-color: #cb334d;
#   color: #f1f1f1;
# }
# #T_23b44_row9_col13 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_23b44_row10_col4, #T_23b44_row15_col13, #T_23b44_row19_col7 {
#   background-color: #86cfa5;
#   color: #000000;
# }
# #T_23b44_row10_col6 {
#   background-color: #496aaf;
#   color: #f1f1f1;
# }
# #T_23b44_row10_col7, #T_23b44_row20_col4, #T_23b44_row29_col12, #T_23b44_row30_col8 {
#   background-color: #3880b9;
#   color: #f1f1f1;
# }
# #T_23b44_row10_col10 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_23b44_row10_col11 {
#   background-color: #fdb
# #### Y_GE80
# <style type="text/css">
# #T_81045_row0_col4, #T_81045_row31_col5 {
#   background-color: #89d0a4;
#   color: #000000;
# }
# #T_81045_row0_col5, #T_81045_row1_col5, #T_81045_row2_col5, #T_81045_row3_col5, #T_81045_row4_col5, #T_81045_row5_col5, #T_81045_row6_col5, #T_81045_row7_col11, #T_81045_row8_col5, #T_81045_row9_col5, #T_81045_row10_col4, #T_81045_row11_col4, #T_81045_row12_col10, #T_81045_row13_col5, #T_81045_row14_col5, #T_81045_row15_col8, #T_81045_row16_col5, #T_81045_row17_col5, #T_81045_row18_col5, #T_81045_row19_col5, #T_81045_row20_col5, #T_81045_row21_col5, #T_81045_row22_col8, #T_81045_row23_col5, #T_81045_row24_col5, #T_81045_row25_col5, #T_81045_row26_col5, #T_81045_row27_col5, #T_81045_row27_col8, #T_81045_row28_col13, #T_81045_row29_col12, #T_81045_row30_col12, #T_81045_row31_col13, #T_81045_row32_col13 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_81045_row0_col6, #T_81045_row3_col4 {
#   background-color: #bae3a1;
#   color: #000000;
# }
# #T_81045_row0_col7, #T_81045_row21_col9 {
#   background-color: #eaf79e;
#   color: #000000;
# }
# #T_81045_row0_col8 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_81045_row0_col9, #T_81045_row0_col11, #T_81045_row1_col11, #T_81045_row2_col9, #T_81045_row3_col11, #T_81045_row4_col9, #T_81045_row5_col9, #T_81045_row6_col11, #T_81045_row7_col9, #T_81045_row8_col9, #T_81045_row9_col11, #T_81045_row10_col10, #T_81045_row11_col11, #T_81045_row12_col11, #T_81045_row13_col9, #T_81045_row14_col11, #T_81045_row15_col11, #T_81045_row16_col9, #T_81045_row17_col9, #T_81045_row18_col9, #T_81045_row19_col9, #T_81045_row20_col9, #T_81045_row21_col10, #T_81045_row22_col9, #T_81045_row23_col10, #T_81045_row24_col10, #T_81045_row25_col10, #T_81045_row26_col10, #T_81045_row27_col10, #T_81045_row28_col10, #T_81045_row29_col10, #T_81045_row30_col9, #T_81045_row31_col10, #T_81045_row32_col10 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_81045_row0_col10 {
#   background-color: #dc484c;
#   color: #f1f1f1;
# }
# #T_81045_row0_col12 {
#   background-color: #d9444d;
#   color: #f1f1f1;
# }
# #T_81045_row0_col13 {
#   background-color: #d43d4f;
#   color: #f1f1f1;
# }
# #T_81045_row1_col4, #T_81045_row6_col4, #T_81045_row12_col9, #T_81045_row23_col4 {
#   background-color: #3990ba;
#   color: #f1f1f1;
# }
# #T_81045_row1_col6, #T_81045_row6_col6, #T_81045_row25_col6 {
#   background-color: #54aead;
#   color: #f1f1f1;
# }
# #T_81045_row1_col7, #T_81045_row32_col5 {
#   background-color: #a7dba4;
#   color: #000000;
# }
# #T_81045_row1_col8, #T_81045_row13_col4, #T_81045_row26_col7 {
#   background-color: #9fd8a4;
#   color: #000000;
# }
# #T_81045_row1_col9, #T_81045_row7_col6 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_81045_row1_col10, #T_81045_row12_col13, #T_81045_row14_col9 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_81045_row1_col12 {
#   background-color: #f06744;
#   color: #f1f1f1;
# }
# #T_81045_row1_col13, #T_81045_row24_col11 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_81045_row2_col4 {
#   background-color: #466eb1;
#   color: #f1f1f1;
# }
# #T_81045_row2_col6, #T_81045_row19_col8 {
#   background-color: #3d95b8;
#   color: #f1f1f1;
# }
# #T_81045_row2_col7 {
#   background-color: #7ecca5;
#   color: #000000;
# }
# #T_81045_row2_col8, #T_81045_row19_col7, #T_81045_row28_col4, #T_81045_row32_col12 {
#   background-color: #5eb9a9;
#   color: #f1f1f1;
# }
# #T_81045_row2_col10, #T_81045_row16_col11 {
#   background-color: #f36b43;
#   color: #f1f1f1;
# }
# #T_81045_row2_col11 {
#   background-color: #eb6046;
#   color: #f1f1f1;
# }
# #T_81045_row2_col12 {
#   background-color: #e55749;
#   color: #f1f1f1;
# }
# #T_81045_row2_col13 {
#   background-color: #ad1246;
#   color: #f1f1f1;
# }
# #T_81045_row3_col6, #T_81045_row32_col6 {
#   background-color: #daf09a;
#   color: #000000;
# }
# #T_81045_row3_col7, #T_81045_row13_col6, #T_81045_row14_col4, #T_81045_row21_col7, #T_81045_row27_col4 {
#   background-color: #58b2ac;
#   color: #f1f1f1;
# }
# #T_81045_row3_col8 {
#   background-color: #fafdb7;
#   color: #000000;
# }
# #T_81045_row3_col9 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_81045_row3_col10 {
#   background-color: #e45549;
#   color: #f1f1f1;
# }
# #T_81045_row3_col12, #T_81045_row9_col13, #T_81045_row24_col9 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_81045_row3_col13 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_81045_row4_col4, #T_81045_row8_col4 {
#   background-color: #5956a5;
#   color: #f1f1f1;
# }
# #T_81045_row4_col6 {
#   background-color: #50a9af;
#   color: #f1f1f1;
# }
# #T_81045_row4_col7, #T_81045_row26_col12 {
#   background-color: #4ea7b0;
#   color: #f1f1f1;
# }
# #T_81045_row4_col8 {
#   background-color: #60bba8;
#   color: #000000;
# }
# #T_81045_row4_col10 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_81045_row4_col11 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_81045_row4_col12, #T_81045_row26_col4 {
#   background-color: #f0f9a7;
#   color: #000000;
# }
# #T_81045_row4_col13, #T_81045_row5_col8 {
#   background-color: #fbfdb8;
#   color: #000000;
# }
# #T_81045_row5_col4, #T_81045_row21_col13 {
#   background-color: #3880b9;
#   color: #f1f1f1;
# }
# #T_81045_row5_col6, #T_81045_row16_col4 {
#   background-color: #439bb5;
#   color: #f1f1f1;
# }
# #T_81045_row5_col7, #T_81045_row32_col7 {
#   background-color: #ecf7a1;
#   color: #000000;
# }
# #T_81045_row5_col10 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_81045_row5_col11 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_81045_row5_col12 {
#   background-color: #fdbd6d;
#   color: #000000;
# }
# #T_81045_row5_col13, #T_81045_row9_col10 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_81045_row6_col7 {
#   background-color: #e6f598;
#   color: #000000;
# }
# #T_81045_row6_col8, #T_81045_row24_col6 {
#   background-color: #74c7a5;
#   color: #000000;
# }
# #T_81045_row6_col9 {
#   background-color: #f8fcb4;
#   color: #000000;
# }
# #T_81045_row6_col10, #T_81045_row7_col5 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_81045_row6_col12 {
#   background-color: #cd364d;
#   color: #f1f1f1;
# }
# #T_81045_row6_col13, #T_81045_row8_col10, #T_81045_row20_col10 {
#   background-color: #d8434e;
#   color: #f1f1f1;
# }
# #T_81045_row7_col4 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_81045_row7_col7 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_81045_row7_col8 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_81045_row7_col10, #T_81045_row7_col12, #T_81045_row32_col9 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_81045_row7_col13 {
#   background-color: #ee6445;
#   color: #f1f1f1;
# }
# #T_81045_row8_col6, #T_81045_row27_col12 {
#   background-color: #555aa7;
#   color: #f1f1f1;
# }
# #T_81045_row8_col7 {
#   background-color: #8cd1a4;
#   color: #000000;
# }
# #T_81045_row8_col8, #T_81045_row28_col6 {
#   background-color: #79c9a5;
#   color: #000000;
# }
# #T_81045_row8_col11 {
#   background-color: #b11747;
#   color: #f1f1f1;
# }
# #T_81045_row8_col12, #T_81045_row21_col11 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_81045_row8_col13 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_81045_row9_col4 {
#   background-color: #aedea3;
#   color: #000000;
# }
# #T_81045_row9_col6, #T_81045_row9_col8, #T_81045_row18_col12, #T_81045_row23_col8 {
#   background-color: #71c6a5;
#   color: #000000;
# }
# #T_81045_row9_col7, #T_81045_row25_col8, #T_81045_row30_col4 {
#   background-color: #69c3a5;
#   color: #000000;
# }
# #T_81045_row9_col9 {
#   background-color: #d7414e;
#   color: #f1f1f1;
# }
# #T_81045_row9_col12 {
#   background-color: #f88950;
#   color: #f1f1f1;
# }
# #T_81045_row10_col5 {
#   background-color: #496aaf;
#   color: #f1f1f1;
# }
# #T_81045_row10_col6, #T_81045_row20_col7, #T_81045_row23_col6, #T_81045_row30_col7 {
#   background-color: #64c0a6;
#   color: #000000;
# }
# #T_81045_row10_col7, #T_81045_row17_col6, #T_81045_row18_col13 {
#   background-color: #97d5a4;
#   color: #000000;
# }
# #T_81045_row10_col8, #T_81045_row26_col8 {
#   background-color: #84cea5;
#   color: #000000;
# }
# #T_81045_row10_col9, #T_81045_row25_col9 {
#   background-color: #f5fbaf;
#   color: #000000;
# }
# #T_81045_row10_col11 {
#   background-color: #e85b48;
#   color: #f1f1f1;
# }
# #T_81045_row10_col12 {
#   background-color: #fcfeba;
#   color: #000000;
# }
# #T_81045_row10_col13, #T_81045_row13_col10,
# #### Y_LT20
# <style type="text/css">
# #T_dc56e_row0_col4, #T_dc56e_row18_col13, #T_dc56e_row23_col12 {
#   background-color: #5061aa;
#   color: #f1f1f1;
# }
# #T_dc56e_row0_col5, #T_dc56e_row1_col6, #T_dc56e_row1_col9, #T_dc56e_row2_col12, #T_dc56e_row3_col8, #T_dc56e_row4_col11, #T_dc56e_row5_col10, #T_dc56e_row6_col10, #T_dc56e_row6_col11, #T_dc56e_row7_col4, #T_dc56e_row8_col9, #T_dc56e_row9_col9, #T_dc56e_row10_col10, #T_dc56e_row11_col12, #T_dc56e_row12_col12, #T_dc56e_row13_col13, #T_dc56e_row14_col12, #T_dc56e_row15_col9, #T_dc56e_row16_col10, #T_dc56e_row17_col13, #T_dc56e_row18_col9, #T_dc56e_row19_col11, #T_dc56e_row20_col13, #T_dc56e_row21_col13, #T_dc56e_row22_col13, #T_dc56e_row23_col13, #T_dc56e_row24_col13, #T_dc56e_row25_col13, #T_dc56e_row26_col13, #T_dc56e_row27_col12, #T_dc56e_row28_col13, #T_dc56e_row29_col13, #T_dc56e_row30_col13, #T_dc56e_row31_col8, #T_dc56e_row31_col11, #T_dc56e_row32_col13 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_dc56e_row0_col6, #T_dc56e_row0_col7, #T_dc56e_row0_col10, #T_dc56e_row19_col12 {
#   background-color: #4273b3;
#   color: #f1f1f1;
# }
# #T_dc56e_row0_col8, #T_dc56e_row0_col11 {
#   background-color: #3387bc;
#   color: #f1f1f1;
# }
# #T_dc56e_row0_col9 {
#   background-color: #64c0a6;
#   color: #000000;
# }
# #T_dc56e_row0_col12 {
#   background-color: #3990ba;
#   color: #f1f1f1;
# }
# #T_dc56e_row0_col13, #T_dc56e_row1_col12, #T_dc56e_row2_col13, #T_dc56e_row3_col10, #T_dc56e_row4_col12, #T_dc56e_row5_col6, #T_dc56e_row6_col5, #T_dc56e_row7_col6, #T_dc56e_row8_col4, #T_dc56e_row9_col4, #T_dc56e_row10_col7, #T_dc56e_row11_col4, #T_dc56e_row12_col8, #T_dc56e_row13_col4, #T_dc56e_row14_col4, #T_dc56e_row15_col4, #T_dc56e_row16_col11, #T_dc56e_row17_col4, #T_dc56e_row18_col5, #T_dc56e_row19_col5, #T_dc56e_row20_col4, #T_dc56e_row21_col4, #T_dc56e_row22_col4, #T_dc56e_row23_col6, #T_dc56e_row24_col4, #T_dc56e_row25_col4, #T_dc56e_row26_col9, #T_dc56e_row27_col8, #T_dc56e_row28_col4, #T_dc56e_row29_col4, #T_dc56e_row30_col4, #T_dc56e_row31_col9, #T_dc56e_row32_col5 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_dc56e_row1_col4, #T_dc56e_row7_col11, #T_dc56e_row8_col10, #T_dc56e_row22_col10 {
#   background-color: #50a9af;
#   color: #f1f1f1;
# }
# #T_dc56e_row1_col5, #T_dc56e_row1_col10 {
#   background-color: #cfec9d;
#   color: #000000;
# }
# #T_dc56e_row1_col7 {
#   background-color: #f0f9a7;
#   color: #000000;
# }
# #T_dc56e_row1_col8, #T_dc56e_row4_col7, #T_dc56e_row16_col7 {
#   background-color: #3b92b9;
#   color: #f1f1f1;
# }
# #T_dc56e_row1_col11, #T_dc56e_row17_col5, #T_dc56e_row28_col5 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_dc56e_row1_col13, #T_dc56e_row12_col6 {
#   background-color: #e75948;
#   color: #f1f1f1;
# }
# #T_dc56e_row2_col4, #T_dc56e_row8_col13, #T_dc56e_row17_col11 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_dc56e_row2_col5 {
#   background-color: #b1dfa3;
#   color: #000000;
# }
# #T_dc56e_row2_col6, #T_dc56e_row2_col7 {
#   background-color: #f06744;
#   color: #f1f1f1;
# }
# #T_dc56e_row2_col8 {
#   background-color: #439bb5;
#   color: #f1f1f1;
# }
# #T_dc56e_row2_col9 {
#   background-color: #60bba8;
#   color: #000000;
# }
# #T_dc56e_row2_col10 {
#   background-color: #d1ed9c;
#   color: #000000;
# }
# #T_dc56e_row2_col11, #T_dc56e_row9_col10 {
#   background-color: #4175b4;
#   color: #f1f1f1;
# }
# #T_dc56e_row3_col4 {
#   background-color: #bc2249;
#   color: #f1f1f1;
# }
# #T_dc56e_row3_col5, #T_dc56e_row3_col11, #T_dc56e_row13_col11, #T_dc56e_row25_col11 {
#   background-color: #f1f9a9;
#   color: #000000;
# }
# #T_dc56e_row3_col6, #T_dc56e_row3_col9, #T_dc56e_row3_col13, #T_dc56e_row11_col8, #T_dc56e_row28_col6 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_dc56e_row3_col7, #T_dc56e_row9_col6 {
#   background-color: #feeda1;
#   color: #000000;
# }
# #T_dc56e_row3_col12 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_dc56e_row4_col4, #T_dc56e_row4_col8 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_dc56e_row4_col5 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_dc56e_row4_col6 {
#   background-color: #da464d;
#   color: #f1f1f1;
# }
# #T_dc56e_row4_col9, #T_dc56e_row7_col5 {
#   background-color: #7ecca5;
#   color: #000000;
# }
# #T_dc56e_row4_col10, #T_dc56e_row26_col8 {
#   background-color: #496aaf;
#   color: #f1f1f1;
# }
# #T_dc56e_row4_col13 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_dc56e_row5_col4, #T_dc56e_row22_col9 {
#   background-color: #4ea7b0;
#   color: #f1f1f1;
# }
# #T_dc56e_row5_col5, #T_dc56e_row28_col11 {
#   background-color: #a4daa4;
#   color: #000000;
# }
# #T_dc56e_row5_col7, #T_dc56e_row27_col9, #T_dc56e_row27_col11 {
#   background-color: #97d5a4;
#   color: #000000;
# }
# #T_dc56e_row5_col8, #T_dc56e_row10_col8, #T_dc56e_row10_col12 {
#   background-color: #f9fcb5;
#   color: #000000;
# }
# #T_dc56e_row5_col9, #T_dc56e_row11_col6 {
#   background-color: #e55749;
#   color: #f1f1f1;
# }
# #T_dc56e_row5_col11, #T_dc56e_row7_col8 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_dc56e_row5_col12, #T_dc56e_row9_col5 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_dc56e_row5_col13, #T_dc56e_row12_col10 {
#   background-color: #99d6a4;
#   color: #000000;
# }
# #T_dc56e_row6_col4 {
#   background-color: #e85b48;
#   color: #f1f1f1;
# }
# #T_dc56e_row6_col6 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_dc56e_row6_col7 {
#   background-color: #3b7cb7;
#   color: #f1f1f1;
# }
# #T_dc56e_row6_col8, #T_dc56e_row6_col9 {
#   background-color: #ed6246;
#   color: #f1f1f1;
# }
# #T_dc56e_row6_col12 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_dc56e_row6_col13 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_dc56e_row7_col7 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_dc56e_row7_col9, #T_dc56e_row14_col9, #T_dc56e_row19_col10 {
#   background-color: #6bc4a5;
#   color: #000000;
# }
# #T_dc56e_row7_col10, #T_dc56e_row28_col10 {
#   background-color: #d3ed9c;
#   color: #000000;
# }
# #T_dc56e_row7_col12, #T_dc56e_row8_col5 {
#   background-color: #ef6645;
#   color: #f1f1f1;
# }
# #T_dc56e_row7_col13 {
#   background-color: #3389bd;
#   color: #f1f1f1;
# }
# #T_dc56e_row8_col6, #T_dc56e_row14_col5, #T_dc56e_row24_col5 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_dc56e_row8_col7, #T_dc56e_row16_col5 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_dc56e_row8_col8, #T_dc56e_row11_col11 {
#   background-color: #cdeb9d;
#   color: #000000;
# }
# #T_dc56e_row8_col11, #T_dc56e_row15_col10, #T_dc56e_row23_col10, #T_dc56e_row24_col8, #T_dc56e_row26_col10 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_dc56e_row8_col12 {
#   background-color: #c3e79f;
#   color: #000000;
# }
# #T_dc56e_row9_col7, #T_dc56e_row15_col7, #T_dc56e_row25_col10 {
#   background-color: #f5fbaf;
#   color: #000000;
# }
# #T_dc56e_row9_col8, #T_dc56e_row20_col10 {
#   background-color: #f2faaa;
#   color: #000000;
# }
# #T_dc56e_row9_col11, #T_dc56e_row13_col5, #T_dc56e_row14_col6 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_dc56e_row9_col12, #T_dc56e_row13_col12 {
#   background-color: #8fd2a4;
#   color: #000000;
# }
# #T_dc56e_row9_col13, #T_dc56e_row16_col9, #T_dc56e_row16_col12 {
#   background-color: #b8e2a1;
#   color: #000000;
# }
# #T_dc56e_row10_col4, #T_dc56e_row22_col6, #T_dc56e_row30_col5 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_dc56e_row10_col5 {
#   background-color: #d9444d;
#   color: #f1f1f1;
# }
# #T_dc56e_row10_col6 {
#   background-color: #bce4a0;
#   color: #000000;
# }
# #T_dc56e_row10_col9 {
#   background-color: #3585bb;
#   color: #f1f1f1;
# }
# #T_dc56e_row10_col11, #T_dc56e_row18_col7, #T_dc56e_row30_col6 {
#   background-color: #f7fcb2;
#   color: #000000;
# }
# #T_dc56e_row10_col13, #T_dc56e_row16_col13 {
#   background-color: #49a2b2;
#   color: #f1f1f1;
# }
# #T_dc56e_row11_col5 {
#   background-color: #d23a4e;
#   color: #f1f1f1;
# }
# #T_dc56e_row11_col7, #T_dc56e_row21_col5, #T_dc56e_row21_col7, #T_dc56e_row27_col4 {
#   background-color: #ee6445;
#   color: #f1f1f1;
# }
# #T_dc56e_row11_col9 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_dc56e_row11_col10, #T_dc56e_row24_col7 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_dc56e_row11_col13, #T_dc56e_row17_col7 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_dc56e_row12_col4 {
#   background-color: #fba35c

# %%
display(MD('### HeatMap (of deaths and vaccines)'))

temp = cd[(cd['source']=='deaths') & (cd['filter']=='TOTAL') & (cd['value_type']=='normalized')]

temp = pd.pivot_table(
    data = temp,
    values = 'value',
    index = ['abbr','name','filter','value_type'],
    columns=['year'],
    aggfunc='mean',
)
temp.columns.name = 'index' 
temp = temp.reset_index()

temp = temp.set_index('name').reindex(sppd['name']).reset_index()
temp['average(2022-2024)'] = (temp[2022]+temp[2023]+ temp[2024])/3.0
temp = temp.sort_values(by='average(2022-2024)',ascending=False)

## vaccines in 2023
v2023 =cd[(cd['source']=='vaccine') & (cd['filter']=='All') & (cd['value_type']=='ratio (total_dose/pop.)') & (cd['year'] == 2023)]
v2023 = v2023[['name','source','filter','value_type','value']]

temp = pd.merge(temp,v2023, how='left',on='name')

years = [y for y in range(2015,2025,1)]

styled_df = temp.style.background_gradient(cmap=heatmapCM1, axis=1, subset=years) \
                      .background_gradient(cmap=heatmapCM2, axis=0, subset=['average(2022-2024)']) \
                      .background_gradient(cmap=heatmapCM3, axis=0, subset=['value'])

display(MD('* 2015-2024 are the deaths for those years'))
display(MD('* average(2022-2024) is how the table is sorted'))
display(MD('* value is the total_doses/pop. for 2023'))

display(styled_df)

display(MD('### Lets sort by the vaccines '))

temp = temp.sort_values(by='value',ascending=False)

styled_df = temp.style.background_gradient(cmap=heatmapCM1, axis=1, subset=years) \
                      .background_gradient(cmap=heatmapCM2, axis=0, subset=['average(2022-2024)']) \
                      .background_gradient(cmap=heatmapCM3, axis=0, subset=['value'])

display(styled_df)


dxv = temp.copy()
# Out:
# ### HeatMap (of deaths and vaccines)
# * 2015-2024 are the deaths for those years
# * average(2022-2024) is how the table is sorted
# * value is the total_doses/pop. for 2023
# <style type="text/css">
# #T_0ec5d_row0_col4, #T_0ec5d_row12_col8, #T_0ec5d_row13_col6, #T_0ec5d_row16_col4, #T_0ec5d_row22_col4 {
#   background-color: #7ccaa5;
#   color: #000000;
# }
# #T_0ec5d_row0_col5, #T_0ec5d_row1_col5, #T_0ec5d_row2_col4, #T_0ec5d_row3_col5, #T_0ec5d_row4_col4, #T_0ec5d_row5_col5, #T_0ec5d_row6_col5, #T_0ec5d_row7_col5, #T_0ec5d_row8_col6, #T_0ec5d_row9_col5, #T_0ec5d_row10_col5, #T_0ec5d_row11_col5, #T_0ec5d_row12_col5, #T_0ec5d_row13_col5, #T_0ec5d_row14_col5, #T_0ec5d_row15_col6, #T_0ec5d_row16_col5, #T_0ec5d_row17_col5, #T_0ec5d_row18_col5, #T_0ec5d_row19_col5, #T_0ec5d_row20_col5, #T_0ec5d_row21_col5, #T_0ec5d_row22_col5, #T_0ec5d_row23_col13, #T_0ec5d_row24_col5, #T_0ec5d_row24_col13, #T_0ec5d_row25_col8, #T_0ec5d_row26_col13, #T_0ec5d_row27_col13, #T_0ec5d_row28_col13, #T_0ec5d_row29_col13, #T_0ec5d_row30_col12, #T_0ec5d_row31_col13, #T_0ec5d_row32_col12 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_0ec5d_row0_col6, #T_0ec5d_row13_col13, #T_0ec5d_row27_col5, #T_0ec5d_row32_col6 {
#   background-color: #97d5a4;
#   color: #000000;
# }
# #T_0ec5d_row0_col7, #T_0ec5d_row25_col12 {
#   background-color: #e6f598;
#   color: #000000;
# }
# #T_0ec5d_row0_col8, #T_0ec5d_row22_col11 {
#   background-color: #e9f69d;
#   color: #000000;
# }
# #T_0ec5d_row0_col9, #T_0ec5d_row4_col12, #T_0ec5d_row8_col10 {
#   background-color: #c72e4c;
#   color: #f1f1f1;
# }
# #T_0ec5d_row0_col10, #T_0ec5d_row8_col11 {
#   background-color: #cd364d;
#   color: #f1f1f1;
# }
# #T_0ec5d_row0_col11, #T_0ec5d_row1_col10, #T_0ec5d_row2_col11, #T_0ec5d_row3_col9, #T_0ec5d_row4_col11, #T_0ec5d_row5_col11, #T_0ec5d_row6_col11, #T_0ec5d_row7_col11, #T_0ec5d_row8_col9, #T_0ec5d_row9_col9, #T_0ec5d_row10_col11, #T_0ec5d_row11_col9, #T_0ec5d_row12_col9, #T_0ec5d_row13_col10, #T_0ec5d_row14_col9, #T_0ec5d_row15_col9, #T_0ec5d_row16_col9, #T_0ec5d_row17_col10, #T_0ec5d_row18_col10, #T_0ec5d_row19_col10, #T_0ec5d_row20_col10, #T_0ec5d_row21_col9, #T_0ec5d_row22_col9, #T_0ec5d_row23_col10, #T_0ec5d_row24_col10, #T_0ec5d_row25_col9, #T_0ec5d_row26_col10, #T_0ec5d_row27_col10, #T_0ec5d_row28_col10, #T_0ec5d_row29_col10, #T_0ec5d_row30_col10, #T_0ec5d_row31_col10, #T_0ec5d_row32_col9 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_0ec5d_row0_col12 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_0ec5d_row0_col13 {
#   background-color: #df4e4b;
#   color: #f1f1f1;
# }
# #T_0ec5d_row0_col14 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_0ec5d_row0_col18 {
#   background-color: #58c765;
#   color: #000000;
# }
# #T_0ec5d_row1_col4 {
#   background-color: #acdda4;
#   color: #000000;
# }
# #T_0ec5d_row1_col6, #T_0ec5d_row16_col13 {
#   background-color: #b5e1a2;
#   color: #000000;
# }
# #T_0ec5d_row1_col7 {
#   background-color: #64c0a6;
#   color: #000000;
# }
# #T_0ec5d_row1_col8 {
#   background-color: #eff9a6;
#   color: #000000;
# }
# #T_0ec5d_row1_col9 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_0ec5d_row1_col11 {
#   background-color: #a00343;
#   color: #f1f1f1;
# }
# #T_0ec5d_row1_col12 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_0ec5d_row1_col13 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_0ec5d_row1_col14 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_0ec5d_row1_col18 {
#   background-color: #75d054;
#   color: #000000;
# }
# #T_0ec5d_row2_col5, #T_0ec5d_row12_col4, #T_0ec5d_row15_col8, #T_0ec5d_row16_col6, #T_0ec5d_row30_col8 {
#   background-color: #4ea7b0;
#   color: #f1f1f1;
# }
# #T_0ec5d_row2_col6, #T_0ec5d_row10_col8, #T_0ec5d_row28_col12, #T_0ec5d_row29_col12 {
#   background-color: #5758a6;
#   color: #f1f1f1;
# }
# #T_0ec5d_row2_col7, #T_0ec5d_row10_col7, #T_0ec5d_row19_col13, #T_0ec5d_row23_col4, #T_0ec5d_row26_col12, #T_0ec5d_row29_col8 {
#   background-color: #466eb1;
#   color: #f1f1f1;
# }
# #T_0ec5d_row2_col8, #T_0ec5d_row8_col4, #T_0ec5d_row22_col6 {
#   background-color: #3a7eb8;
#   color: #f1f1f1;
# }
# #T_0ec5d_row2_col9, #T_0ec5d_row21_col12, #T_0ec5d_row23_col11 {
#   background-color: #8fd2a4;
#   color: #000000;
# }
# #T_0ec5d_row2_col10, #T_0ec5d_row15_col10, #T_0ec5d_row21_col6 {
#   background-color: #86cfa5;
#   color: #000000;
# }
# #T_0ec5d_row2_col12 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_0ec5d_row2_col13 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_0ec5d_row2_col14 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_0ec5d_row2_col18 {
#   background-color: #5cc863;
#   color: #000000;
# }
# #T_0ec5d_row3_col4, #T_0ec5d_row23_col7 {
#   background-color: #4273b3;
#   color: #f1f1f1;
# }
# #T_0ec5d_row3_col6 {
#   background-color: #4175b4;
#   color: #f1f1f1;
# }
# #T_0ec5d_row3_col7, #T_0ec5d_row13_col4, #T_0ec5d_row17_col12 {
#   background-color: #69c3a5;
#   color: #000000;
# }
# #T_0ec5d_row3_col8, #T_0ec5d_row21_col8, #T_0ec5d_row30_col5 {
#   background-color: #47a0b3;
#   color: #f1f1f1;
# }
# #T_0ec5d_row3_col10 {
#   background-color: #b81e48;
#   color: #f1f1f1;
# }
# #T_0ec5d_row3_col11 {
#   background-color: #d0384e;
#   color: #f1f1f1;
# }
# #T_0ec5d_row3_col12 {
#   background-color: #d7414e;
#   color: #f1f1f1;
# }
# #T_0ec5d_row3_col13, #T_0ec5d_row6_col9, #T_0ec5d_row32_col10 {
#   background-color: #ad1246;
#   color: #f1f1f1;
# }
# #T_0ec5d_row3_col14 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_0ec5d_row3_col18 {
#   background-color: #69cd5b;
#   color: #000000;
# }
# #T_0ec5d_row4_col5, #T_0ec5d_row8_col5, #T_0ec5d_row22_col8, #T_0ec5d_row23_col5 {
#   background-color: #4b68ae;
#   color: #f1f1f1;
# }
# #T_0ec5d_row4_col6 {
#   background-color: #545ca8;
#   color: #f1f1f1;
# }
# #T_0ec5d_row4_col7, #T_0ec5d_row15_col4 {
#   background-color: #4199b6;
#   color: #f1f1f1;
# }
# #T_0ec5d_row4_col8, #T_0ec5d_row17_col4, #T_0ec5d_row17_col6 {
#   background-color: #486cb0;
#   color: #f1f1f1;
# }
# #T_0ec5d_row4_col9, #T_0ec5d_row19_col11 {
#   background-color: #c8e99e;
#   color: #000000;
# }
# #T_0ec5d_row4_col10, #T_0ec5d_row8_col13 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_0ec5d_row4_col13, #T_0ec5d_row25_col4 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_0ec5d_row4_col14 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_0ec5d_row4_col18 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_0ec5d_row5_col4 {
#   background-color: #71c6a5;
#   color: #000000;
# }
# #T_0ec5d_row5_col6, #T_0ec5d_row9_col4, #T_0ec5d_row28_col5 {
#   background-color: #49a2b2;
#   color: #f1f1f1;
# }
# #T_0ec5d_row5_col7, #T_0ec5d_row10_col10 {
#   background-color: #a4daa4;
#   color: #000000;
# }
# #T_0ec5d_row5_col8, #T_0ec5d_row6_col6, #T_0ec5d_row12_col7, #T_0ec5d_row16_col7, #T_0ec5d_row28_col6 {
#   background-color: #62bda7;
#   color: #000000;
# }
# #T_0ec5d_row5_col9, #T_0ec5d_row6_col13, #T_0ec5d_row10_col12 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_0ec5d_row5_col10 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_0ec5d_row5_col12, #T_0ec5d_row18_col9 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_0ec5d_row5_col13, #T_0ec5d_row7_col13 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_0ec5d_row5_col14 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_0ec5d_row5_col18, #T_0ec5d_row6_col18 {
#   background-color: #65cb5e;
#   color: #000000;
# }
# #T_0ec5d_row6_col4 {
#   background-color: #b8e2a1;
#   color: #000000;
# }
# #T_0ec5d_row6_col7, #T_0ec5d_row13_col8, #T_0ec5d_row28_col4 {
#   background-color: #89d0a4;
#   color: #000000;
# }
# #T_0ec5d_row6_col8, #T_0ec5d_row8_col7, #T_0ec5d_row10_col4, #T_0ec5d_row22_col10 {
#   background-color: #6ec5a5;
#   color: #000000;
# }
# #T_0ec5d_row6_col10, #T_0ec5d_row14_col11 {
#   background-color: #e75948;
#   color: #f1f1f1;
# }
# #T_0ec5d_row6_col12, #T_0ec5d_row9_col11 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_0ec5d_row6_col14 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_0ec5d_row7_col4, #T_0ec5d_row11_col4, #T_0ec5d_row19_col4, #T_0ec5d_row21_col13 {
#   background-color: #3f97b7;
#   color: #f1f1f1;
# }
# #T_0ec5d_row7_col6, #T_0ec5d_row19_col6 {
#   background-color: #3d79b6;
#   color: #f1f1f1;
# }
# #T_0ec5d_row7_col7, #T_0ec5d_row13_col12, #T_0ec5d_row23_col9 {
#   background-color: #d6ee9b;
#   color: #000000;
# }
# #T_0ec5d_row7_col8, #T_0ec5d_row14_col6, #T_0ec5d_row31_col12 {
#   background-color: #5cb7aa;
#   color: #f1f1f1;
# }
# #T_0ec5d_row7_col9, #T_0ec5
# ### Lets sort by the vaccines
# <style type="text/css">
# #T_41f60_row0_col4, #T_41f60_row1_col5, #T_41f60_row2_col6, #T_41f60_row3_col5, #T_41f60_row4_col8, #T_41f60_row5_col5, #T_41f60_row6_col5, #T_41f60_row7_col5, #T_41f60_row8_col5, #T_41f60_row9_col5, #T_41f60_row10_col5, #T_41f60_row11_col13, #T_41f60_row12_col4, #T_41f60_row13_col5, #T_41f60_row14_col5, #T_41f60_row15_col5, #T_41f60_row16_col5, #T_41f60_row17_col5, #T_41f60_row18_col5, #T_41f60_row19_col6, #T_41f60_row20_col5, #T_41f60_row21_col5, #T_41f60_row21_col13, #T_41f60_row22_col5, #T_41f60_row23_col13, #T_41f60_row24_col13, #T_41f60_row25_col5, #T_41f60_row26_col5, #T_41f60_row27_col13, #T_41f60_row28_col13, #T_41f60_row29_col5, #T_41f60_row30_col13, #T_41f60_row31_col12, #T_41f60_row32_col12 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_41f60_row0_col5, #T_41f60_row2_col5, #T_41f60_row8_col8, #T_41f60_row30_col5 {
#   background-color: #4b68ae;
#   color: #f1f1f1;
# }
# #T_41f60_row0_col6 {
#   background-color: #545ca8;
#   color: #f1f1f1;
# }
# #T_41f60_row0_col7, #T_41f60_row19_col4 {
#   background-color: #4199b6;
#   color: #f1f1f1;
# }
# #T_41f60_row0_col8, #T_41f60_row22_col4, #T_41f60_row22_col6 {
#   background-color: #486cb0;
#   color: #f1f1f1;
# }
# #T_41f60_row0_col9, #T_41f60_row26_col11 {
#   background-color: #c8e99e;
#   color: #000000;
# }
# #T_41f60_row0_col10, #T_41f60_row2_col13 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_41f60_row0_col11, #T_41f60_row1_col9, #T_41f60_row2_col9, #T_41f60_row3_col9, #T_41f60_row4_col9, #T_41f60_row5_col10, #T_41f60_row6_col10, #T_41f60_row7_col11, #T_41f60_row8_col9, #T_41f60_row9_col9, #T_41f60_row10_col11, #T_41f60_row11_col10, #T_41f60_row12_col11, #T_41f60_row13_col11, #T_41f60_row14_col11, #T_41f60_row15_col11, #T_41f60_row16_col9, #T_41f60_row17_col10, #T_41f60_row18_col9, #T_41f60_row19_col9, #T_41f60_row20_col10, #T_41f60_row21_col10, #T_41f60_row22_col10, #T_41f60_row23_col10, #T_41f60_row24_col10, #T_41f60_row25_col9, #T_41f60_row26_col10, #T_41f60_row27_col10, #T_41f60_row28_col10, #T_41f60_row29_col9, #T_41f60_row30_col10, #T_41f60_row31_col10, #T_41f60_row32_col9 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_41f60_row0_col12, #T_41f60_row2_col10, #T_41f60_row10_col9 {
#   background-color: #c72e4c;
#   color: #f1f1f1;
# }
# #T_41f60_row0_col13, #T_41f60_row4_col4 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_41f60_row0_col14 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_41f60_row0_col18 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_41f60_row1_col4, #T_41f60_row9_col6, #T_41f60_row12_col5, #T_41f60_row19_col8, #T_41f60_row31_col8 {
#   background-color: #4ea7b0;
#   color: #f1f1f1;
# }
# #T_41f60_row1_col6, #T_41f60_row13_col9, #T_41f60_row20_col8, #T_41f60_row21_col7 {
#   background-color: #4ba4b1;
#   color: #f1f1f1;
# }
# #T_41f60_row1_col7, #T_41f60_row9_col7, #T_41f60_row14_col6, #T_41f60_row15_col8, #T_41f60_row28_col6 {
#   background-color: #62bda7;
#   color: #000000;
# }
# #T_41f60_row1_col8, #T_41f60_row5_col6, #T_41f60_row8_col4, #T_41f60_row9_col4, #T_41f60_row10_col4 {
#   background-color: #7ccaa5;
#   color: #000000;
# }
# #T_41f60_row1_col10 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_41f60_row1_col11 {
#   background-color: #c1274a;
#   color: #f1f1f1;
# }
# #T_41f60_row1_col12 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_41f60_row1_col13, #T_41f60_row29_col10 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_41f60_row1_col14 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_41f60_row1_col18 {
#   background-color: #297b8e;
#   color: #f1f1f1;
# }
# #T_41f60_row2_col4, #T_41f60_row8_col6, #T_41f60_row12_col8 {
#   background-color: #3a7eb8;
#   color: #f1f1f1;
# }
# #T_41f60_row2_col7, #T_41f60_row8_col10, #T_41f60_row13_col4, #T_41f60_row14_col8 {
#   background-color: #6ec5a5;
#   color: #000000;
# }
# #T_41f60_row2_col8, #T_41f60_row8_col7 {
#   background-color: #439bb5;
#   color: #f1f1f1;
# }
# #T_41f60_row2_col11, #T_41f60_row10_col10 {
#   background-color: #cd364d;
#   color: #f1f1f1;
# }
# #T_41f60_row2_col12, #T_41f60_row19_col13, #T_41f60_row28_col9 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_41f60_row2_col14, #T_41f60_row18_col14 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_41f60_row2_col18 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_41f60_row3_col4, #T_41f60_row32_col4 {
#   background-color: #bfe5a0;
#   color: #000000;
# }
# #T_41f60_row3_col6, #T_41f60_row12_col10, #T_41f60_row19_col10 {
#   background-color: #86cfa5;
#   color: #000000;
# }
# #T_41f60_row3_col7, #T_41f60_row20_col13, #T_41f60_row32_col7, #T_41f60_row32_col8 {
#   background-color: #3990ba;
#   color: #f1f1f1;
# }
# #T_41f60_row3_col8, #T_41f60_row16_col8, #T_41f60_row31_col5 {
#   background-color: #47a0b3;
#   color: #f1f1f1;
# }
# #T_41f60_row3_col10 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_41f60_row3_col11, #T_41f60_row13_col13 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_41f60_row3_col12, #T_41f60_row12_col9, #T_41f60_row30_col11 {
#   background-color: #8fd2a4;
#   color: #000000;
# }
# #T_41f60_row3_col13, #T_41f60_row7_col4, #T_41f60_row25_col4, #T_41f60_row26_col4 {
#   background-color: #3f97b7;
#   color: #f1f1f1;
# }
# #T_41f60_row3_col14 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_41f60_row3_col18 {
#   background-color: #1e9d89;
#   color: #f1f1f1;
# }
# #T_41f60_row4_col5, #T_41f60_row24_col6 {
#   background-color: #7ecca5;
#   color: #000000;
# }
# #T_41f60_row4_col6, #T_41f60_row4_col7 {
#   background-color: #b3e0a2;
#   color: #000000;
# }
# #T_41f60_row4_col10, #T_41f60_row11_col6, #T_41f60_row22_col9, #T_41f60_row31_col11 {
#   background-color: #81cda5;
#   color: #000000;
# }
# #T_41f60_row4_col11, #T_41f60_row9_col10 {
#   background-color: #f2faaa;
#   color: #000000;
# }
# #T_41f60_row4_col12, #T_41f60_row10_col7 {
#   background-color: #e6f598;
#   color: #000000;
# }
# #T_41f60_row4_col13 {
#   background-color: #358bbc;
#   color: #f1f1f1;
# }
# #T_41f60_row4_col14 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_41f60_row4_col18 {
#   background-color: #25ac82;
#   color: #f1f1f1;
# }
# #T_41f60_row5_col4, #T_41f60_row16_col7, #T_41f60_row22_col12 {
#   background-color: #69c3a5;
#   color: #000000;
# }
# #T_41f60_row5_col7, #T_41f60_row24_col5, #T_41f60_row30_col6 {
#   background-color: #3f77b5;
#   color: #f1f1f1;
# }
# #T_41f60_row5_col8, #T_41f60_row14_col7, #T_41f60_row28_col4 {
#   background-color: #89d0a4;
#   color: #000000;
# }
# #T_41f60_row5_col9 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_41f60_row5_col11 {
#   background-color: #de4c4b;
#   color: #f1f1f1;
# }
# #T_41f60_row5_col12, #T_41f60_row7_col7, #T_41f60_row30_col9 {
#   background-color: #d6ee9b;
#   color: #000000;
# }
# #T_41f60_row5_col13, #T_41f60_row10_col6, #T_41f60_row23_col5, #T_41f60_row32_col6 {
#   background-color: #97d5a4;
#   color: #000000;
# }
# #T_41f60_row5_col14 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_41f60_row5_col18 {
#   background-color: #27ad81;
#   color: #f1f1f1;
# }
# #T_41f60_row6_col4 {
#   background-color: #378ebb;
#   color: #f1f1f1;
# }
# #T_41f60_row6_col6, #T_41f60_row20_col6, #T_41f60_row22_col7 {
#   background-color: #3b92b9;
#   color: #f1f1f1;
# }
# #T_41f60_row6_col7, #T_41f60_row11_col7, #T_41f60_row20_col4 {
#   background-color: #5eb9a9;
#   color: #f1f1f1;
# }
# #T_41f60_row6_col8, #T_41f60_row6_col12, #T_41f60_row20_col12, #T_41f60_row31_col7 {
#   background-color: #50a9af;
#   color: #f1f1f1;
# }
# #T_41f60_row6_col9, #T_41f60_row15_col12 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_41f60_row6_col11 {
#   background-color: #f4faad;
#   color: #000000;
# }
# #T_41f60_row6_col13 {
#   background-color: #3d95b8;
#   color: #f1f1f1;
# }
# #T_41f60_row6_col14 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_41f60_row6_col18 {
#   background-color: #31b57b;
#   color: #f1f1f1;
# }
# #T_41f60_row7_col6, #T_41f60_row26_col6 {
#   background-color: #3d79b6;
#   color: #f1f1f1;
# }
# #T_41f60_row7_col8, #T_41f60_row27_col12, #T_41f60_row29_col6 {
#   background-color: #5cb7aa;
#   color: #f1f1f1;
# }
# #T_41f60_row7_col9, #T_41f60_row27_col11 {
#   background-color: #eef8a4;
#   color: #000000;
# }
# #T_41f60_row7_col10 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_41f60_row7_col12 {
#   back

# %%
# deaths values with out the NA
d = dxv.copy().dropna(subset=['value'])
d = d.sort_values(by='average(2022-2024)',ascending=True)
d = d.reset_index()

# vaccines values with out the NA
v = dxv.copy().dropna(subset=['value'])
v = v.sort_values(by='value',ascending=True)
v = v.reset_index()
v['rank'] = v['value'].rank()

# making sure the lists have the same values
d = d[d.abbr.isin(v.abbr)]
d = d.reset_index(drop=True)

# display(d)
# display(v)

# Create a plot
fig, ax = plt.subplots(figsize=(14, 7))

ydistance = 0.95

# Plot points for the first dataframe
for i, row in d.iterrows():
    ax.scatter(0, i * ydistance, label=row['name'], color='blue')
    ax.text(-0.025, i * ydistance, row['name'] + ': ' + f"{row['average(2022-2024)']:.2f}", ha='right', va='center', color='blue')

# Plot points for the second dataframe
for i, row in v.iterrows():
    ax.scatter(1, i * ydistance, label=row['name'], color='red')
    ax.text(1.025, i * ydistance, row['name'] + ': ' + f"{row['value']:.2f}", ha='left', va='center', color='red')


ax.text(-0.025 - 1.0, len(v) * ydistance, 'most deaths')
ax.text(-0.025 - 1.0, 0 * ydistance, 'least deaths')

ax.text(1.025 + 1.0, len(v) * ydistance, 'most vaccines')
ax.text(1.025 + 1.0, 0 * ydistance, 'least vaccines')

# Create a colormap
colormap = plt.get_cmap('magma')
norm = Normalize(vmin=-np.pi, vmax=np.pi)

# Draw lines connecting matching abbr values
for name in d['name']:
    if name in v['name'].values:
        idx1 = d[d['name'] == name].index[0] * ydistance
        idx2 = v[v['name'] == name].index[0] * ydistance
        ax.plot([0, 1], [idx1, idx2], color='gray', linestyle='-')
        vertical_diff = idx2 - idx1
        horizontal_diff = 1  # The horizontal distance between the columns
        angle = np.arctan2(vertical_diff, horizontal_diff)  # Calculate the angle

        # normalized_angle = (angle + 2 * np.pi) / (2 * np.pi )  # Normalize angle to [0, 1]
        normalized_angle = pow ( abs(angle / np.pi)/0.5, 3) # custom normalized angle for better colors
        # print(normalized_angle)

        color = colormap(normalized_angle)  # Map normalized angle to a color
        ax.plot([0, 1], [idx1, idx2], color=color, linestyle='-')

# Formatting
ax.set_xlim(-0.5, 1.5)
ax.set_ylim(-1, max(len(d), len(v)))
ax.set_xticks([0, 1])
ax.set_xticklabels(['deaths average(2022-2024)', 'vaccines ratio (total_dose/pop.)'])
ax.set_yticks([])
ax.set_title('Mapping Between deaths and vaccines\n High values at the top, Low values at the bottom')
ax.grid(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Spearman and Kendall

# %%
# create a ranked list for deaths - average(2022-2024)
d = dxv.copy().reset_index(drop=True)
d = d.sort_values(by='average(2022-2024)',ascending=False) #most deaths to least deaths
d = d[['name','abbr','average(2022-2024)']]
d['rank'] = d['average(2022-2024)'].rank()

# create a ranked list for vaccines - ratio (total_dose/pop.)
v = dxv.copy().reset_index(drop=True)
v = v.sort_values(by='value',ascending=True) #least vaccine to most vaccines
v = v[['name','abbr','value']]
v['rank'] = v['value'].rank()

# make sure the have the same countries
d = d[d.abbr.isin(v.abbr)]

for i, row in v.iterrows():
    d.loc[d['abbr']==row['abbr'], 'rank'] = row['rank']

# no NAN values
d = d[~d['rank'].isna()]
v = v[~v['rank'].isna()]

display(MD(
'''### Output Interpretation

| Value     | Effect                      | Description/Correlation-Suggestion                         |
|-----------|-----------------------------|------------------------------------------------------------|
| **1.0**   | Positive effect             | Suggests more vaccines will lead to fewer deaths.          |
| **0.5**   | Slightly positive effect    | Slightly suggests more vaccines will lead to fewer deaths. |
| **0.0**   | Null/No effect              | Vaccines do not change the number of deaths.               |
| **-0.5**  | Slightly negative effect    | Slightly suggests more vaccines will lead to more deaths.  |
| **-1.0**  | Negative effect             | Suggests more vaccines will lead to more deaths.           |

'''
))




# Calculate Spearman's Rank Correlation
spearman_corr, _ = spearmanr(d['rank'], v['rank'])
display(MD(f"### Spearman's Rank Correlation: {spearman_corr}"))

display(bar(((spearman_corr+1.0)/2.0)*100,length=100))
display('-1'+' '*48 + '0' + ' '*50 + '1')

# Calculate Kendall's Tau
kendall_corr, _ = kendalltau(d['rank'], v['rank'])
display(MD(f"### Kendall's Tau: {kendall_corr}"))

display(bar(((kendall_corr+1.0)/2.0)*100,length=100))
display('-1'+' '*48 + '0' + ' '*50 + '1')

# display(d)
# display(v)
# Out:
# ### Output Interpretation
#
# | Value     | Effect                      | Description/Correlation-Suggestion                         |
# |-----------|-----------------------------|------------------------------------------------------------|
# | **1.0**   | Positive effect             | Suggests more vaccines will lead to fewer deaths.          |
# | **0.5**   | Slightly positive effect    | Slightly suggests more vaccines will lead to fewer deaths. |
# | **0.0**   | Null/No effect              | Vaccines do not change the number of deaths.               |
# | **-0.5**  | Slightly negative effect    | Slightly suggests more vaccines will lead to more deaths.  |
# | **-1.0**  | Negative effect             | Suggests more vaccines will lead to more deaths.           |
# ### Spearman's Rank Correlation: -0.33990147783251223
# '[#################################___________________________________________________________________]'
# '-1                                                0                                                  1'
# ### Kendall's Tau: -0.24630541871921177
# '[#####################################_______________________________________________________________]'
# '-1                                                0                                                  1'

# %% [markdown]
# ### Other death x vaccine charts

# %%
temp = dxv[dxv.value < 14]
temp = temp.dropna(subset=['value'])

g = sns.jointplot(
    data=temp,
    x="value", 
    y="average(2022-2024)", 
    kind="kde",
    fill=True,
    cmap=heatmapCM
)
g.set_axis_labels( "Vaccines (ratio (total_dose/pop.))","Deaths (average(2022-2024))")

g.figure.suptitle("Kde Plot : DxV", fontsize=14)

# Add a title
plt.title("<-- hypothetical 0 vaccines", fontsize=10,x=0.35,y=0.25)

# Add vertical and horizontal lines
plt.axvline(x=0.0, color='black', linestyle='--', linewidth=1)  # Vertical line at x=20
plt.axhline(y=1.0, color='black', linestyle='--', linewidth=1)  # Horizontal line at y=3

# display(vdravg)
plt.show()

# %%
title = 'Scatter Chart - DxV'
display(MD(f'### {title}'))

fig = px.scatter(
        dxv,
        x="value",      
        y="average(2022-2024)",       
        color="name",      
        hover_name="name",
        title=title,
        labels={
            "value": "Vaccines (ratio total_dose/pop.)",  # Custom X-axis label
            "average(2022-2024)": "Deaths average(2022-2024)"           # Custom Y-axis label
        },
        height=750
    )
fig.update_layout(template="plotly_dark")

fig.add_shape(
    type="line",
    x0=0, x1=dxv.value.max(),
    y0=1, y1=1, # Start and end y-coordinates
    line=dict(color="Red", width=2, dash="dash"),  # Line style
    xref="x", yref="y"          # Reference axes
)


fig.show()
# Out:
# ### Scatter Chart - DxV

# %% [markdown]
# ### Bad-Batch Theory
# #### There seems to be to be an unusual grouping/cluster
# Where countries that have a vaccine (ratio total_dose/pop.) between 4.0-6.0, have an unusually high Deaths average(2022-2024) above 1.1.
#
# #### Bad-Batch Theory (by Dr Vibeke Manniche)
# A study in European Journal of Clinical Investigation found significant batch-dependent variations in adverse event reports for the Pfizer-BioNTech COVID-19 vaccine in Denmark (2020–2022), suggesting some batches had higher reported risks. Further investigation is needed.
#
# * The Paper
#     * [Batch-dependent safety of the BNT162b2 mRNA COVID-19 vaccine - by Dr Vibeke Manniche ](https://onlinelibrary.wiley.com/doi/10.1111/eci.13998)
# * An Interview
#     * [Excess deaths, the silence - Dr John Campbell and Dr Vibeke Manniche (Youtube)](https://www.youtube.com/watch?v=nD--4tLmb3w)
#
# * <img src='./docs/chrome_vTKng4rNsY.png' alt="." height="500px"/>
# * <img src='./chrome_vTKng4rNsY.png' alt="." style="height: 500px; width: auto;"/>
# * <img src='./docs/eci13998-fig-0001-m.jpg' alt="." height="350px"/>
# * <img src='./eci13998-fig-0001-m.jpg' alt="." style="height: 350px; width: auto;"/>
#
# #### my 2 cents
# This is not suprising, the vaccine was created in a rushed manner ... and as a rule of thumb, `Haste Makes Waste`
# * Ford Pinto (1971-1980)
# * Windows Vista
# * Samsung Galaxy Note 7
# * Boeing 737 MAX
# * ... and so many more

# %% [markdown]
# ## Lets look at some of the Causes of Death

# %%
title = 'Line Chart - normalized causes of death in Europe (by year)'
display(MD(f'### {title}'))

temp = cd[(cd['source']=='cause_of_death') & (~(cd['filter']=='TOTAL')) & (cd['value_type']=='normalized')]

temp = pd.pivot_table(
        data = temp,
        values = 'value',
        index = ['filter'],
        columns=['year'],
        aggfunc='mean',
    )
temp = temp.reset_index()

# temp['average(2021-2022)'] = (temp[2021]+temp[2022])/2.0
years = [i for i in range(2015,2023)]

# temp['stdev'] = temp[[2020,2021,2022]].std(axis=1)
# temp = temp.sort_values(by='stdev', ascending=False)

temp = temp.sort_values(by=2022, ascending=False)
display(temp.style.background_gradient(cmap=heatmapCM,axis=1,subset=years))
# Out:
# ### Line Chart - normalized causes of death in Europe (by year)
# <style type="text/css">
# #T_cdea4_row0_col1 {
#   background-color: #5758a6;
#   color: #f1f1f1;
# }
# #T_cdea4_row0_col2, #T_cdea4_row2_col1, #T_cdea4_row31_col2, #T_cdea4_row53_col6 {
#   background-color: #5956a5;
#   color: #f1f1f1;
# }
# #T_cdea4_row0_col3, #T_cdea4_row1_col1, #T_cdea4_row2_col2, #T_cdea4_row3_col1, #T_cdea4_row4_col2, #T_cdea4_row5_col1, #T_cdea4_row6_col3, #T_cdea4_row7_col1, #T_cdea4_row8_col2, #T_cdea4_row9_col2, #T_cdea4_row10_col1, #T_cdea4_row11_col1, #T_cdea4_row12_col2, #T_cdea4_row13_col6, #T_cdea4_row14_col2, #T_cdea4_row15_col5, #T_cdea4_row16_col5, #T_cdea4_row17_col5, #T_cdea4_row18_col5, #T_cdea4_row19_col1, #T_cdea4_row20_col2, #T_cdea4_row21_col2, #T_cdea4_row22_col6, #T_cdea4_row23_col1, #T_cdea4_row24_col6, #T_cdea4_row25_col5, #T_cdea4_row26_col5, #T_cdea4_row27_col5, #T_cdea4_row28_col2, #T_cdea4_row29_col5, #T_cdea4_row30_col2, #T_cdea4_row31_col5, #T_cdea4_row32_col5, #T_cdea4_row33_col5, #T_cdea4_row34_col7, #T_cdea4_row35_col8, #T_cdea4_row36_col8, #T_cdea4_row37_col8, #T_cdea4_row38_col5, #T_cdea4_row39_col8, #T_cdea4_row40_col6, #T_cdea4_row41_col8, #T_cdea4_row42_col8, #T_cdea4_row43_col5, #T_cdea4_row44_col8, #T_cdea4_row45_col7, #T_cdea4_row46_col5, #T_cdea4_row47_col7, #T_cdea4_row48_col7, #T_cdea4_row49_col8, #T_cdea4_row50_col8, #T_cdea4_row51_col5, #T_cdea4_row52_col8, #T_cdea4_row53_col5, #T_cdea4_row54_col8, #T_cdea4_row55_col8, #T_cdea4_row56_col7, #T_cdea4_row57_col8, #T_cdea4_row58_col8 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_cdea4_row0_col4, #T_cdea4_row15_col1, #T_cdea4_row27_col1, #T_cdea4_row41_col7, #T_cdea4_row57_col5 {
#   background-color: #6ec5a5;
#   color: #000000;
# }
# #T_cdea4_row0_col5, #T_cdea4_row29_col1, #T_cdea4_row31_col4, #T_cdea4_row48_col8 {
#   background-color: #b3e0a2;
#   color: #000000;
# }
# #T_cdea4_row0_col6, #T_cdea4_row23_col2, #T_cdea4_row29_col3, #T_cdea4_row44_col3 {
#   background-color: #e4f498;
#   color: #000000;
# }
# #T_cdea4_row0_col7, #T_cdea4_row25_col3 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_cdea4_row0_col8, #T_cdea4_row1_col8, #T_cdea4_row2_col6, #T_cdea4_row3_col4, #T_cdea4_row3_col7, #T_cdea4_row4_col7, #T_cdea4_row5_col8, #T_cdea4_row6_col8, #T_cdea4_row7_col8, #T_cdea4_row8_col8, #T_cdea4_row9_col7, #T_cdea4_row10_col4, #T_cdea4_row11_col7, #T_cdea4_row12_col8, #T_cdea4_row13_col8, #T_cdea4_row14_col8, #T_cdea4_row15_col8, #T_cdea4_row16_col7, #T_cdea4_row17_col8, #T_cdea4_row18_col8, #T_cdea4_row19_col7, #T_cdea4_row20_col8, #T_cdea4_row21_col7, #T_cdea4_row22_col4, #T_cdea4_row23_col7, #T_cdea4_row24_col2, #T_cdea4_row25_col8, #T_cdea4_row26_col4, #T_cdea4_row27_col3, #T_cdea4_row28_col6, #T_cdea4_row29_col7, #T_cdea4_row30_col5, #T_cdea4_row31_col7, #T_cdea4_row32_col2, #T_cdea4_row33_col4, #T_cdea4_row34_col4, #T_cdea4_row35_col1, #T_cdea4_row36_col4, #T_cdea4_row37_col1, #T_cdea4_row38_col1, #T_cdea4_row39_col3, #T_cdea4_row40_col3, #T_cdea4_row41_col3, #T_cdea4_row42_col4, #T_cdea4_row43_col1, #T_cdea4_row43_col4, #T_cdea4_row44_col2, #T_cdea4_row45_col3, #T_cdea4_row46_col4, #T_cdea4_row47_col3, #T_cdea4_row48_col1, #T_cdea4_row49_col2, #T_cdea4_row50_col1, #T_cdea4_row51_col1, #T_cdea4_row52_col1, #T_cdea4_row53_col1, #T_cdea4_row54_col1, #T_cdea4_row55_col3, #T_cdea4_row56_col1, #T_cdea4_row57_col1, #T_cdea4_row58_col1 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_cdea4_row1_col2, #T_cdea4_row13_col2 {
#   background-color: #4b68ae;
#   color: #f1f1f1;
# }
# #T_cdea4_row1_col3, #T_cdea4_row15_col2, #T_cdea4_row22_col5, #T_cdea4_row51_col8 {
#   background-color: #486cb0;
#   color: #f1f1f1;
# }
# #T_cdea4_row1_col4 {
#   background-color: #4d65ad;
#   color: #f1f1f1;
# }
# #T_cdea4_row1_col5 {
#   background-color: #74c7a5;
#   color: #000000;
# }
# #T_cdea4_row1_col6, #T_cdea4_row23_col3 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_cdea4_row1_col7, #T_cdea4_row2_col8, #T_cdea4_row40_col1 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_cdea4_row2_col3, #T_cdea4_row6_col1 {
#   background-color: #4273b3;
#   color: #f1f1f1;
# }
# #T_cdea4_row2_col4, #T_cdea4_row5_col2, #T_cdea4_row8_col5, #T_cdea4_row30_col1 {
#   background-color: #5cb7aa;
#   color: #f1f1f1;
# }
# #T_cdea4_row2_col5, #T_cdea4_row6_col4, #T_cdea4_row45_col2, #T_cdea4_row47_col2 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_cdea4_row2_col7, #T_cdea4_row10_col7 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_cdea4_row3_col2, #T_cdea4_row21_col8, #T_cdea4_row27_col4, #T_cdea4_row49_col3 {
#   background-color: #d0384e;
#   color: #f1f1f1;
# }
# #T_cdea4_row3_col3, #T_cdea4_row15_col6 {
#   background-color: #496aaf;
#   color: #f1f1f1;
# }
# #T_cdea4_row3_col5, #T_cdea4_row6_col5, #T_cdea4_row18_col3 {
#   background-color: #e55749;
#   color: #f1f1f1;
# }
# #T_cdea4_row3_col6, #T_cdea4_row20_col6, #T_cdea4_row46_col1 {
#   background-color: #b11747;
#   color: #f1f1f1;
# }
# #T_cdea4_row3_col8, #T_cdea4_row39_col2 {
#   background-color: #a00343;
#   color: #f1f1f1;
# }
# #T_cdea4_row4_col1, #T_cdea4_row13_col1, #T_cdea4_row54_col7 {
#   background-color: #54aead;
#   color: #f1f1f1;
# }
# #T_cdea4_row4_col3, #T_cdea4_row9_col3 {
#   background-color: #4199b6;
#   color: #f1f1f1;
# }
# #T_cdea4_row4_col4, #T_cdea4_row4_col5, #T_cdea4_row33_col7, #T_cdea4_row33_col8, #T_cdea4_row36_col3, #T_cdea4_row47_col6 {
#   background-color: #84cea5;
#   color: #000000;
# }
# #T_cdea4_row4_col6 {
#   background-color: #e6f598;
#   color: #000000;
# }
# #T_cdea4_row4_col8, #T_cdea4_row28_col8, #T_cdea4_row39_col4 {
#   background-color: #ab0f45;
#   color: #f1f1f1;
# }
# #T_cdea4_row5_col3, #T_cdea4_row52_col5 {
#   background-color: #aedea3;
#   color: #000000;
# }
# #T_cdea4_row5_col4, #T_cdea4_row24_col7 {
#   background-color: #fafdb7;
#   color: #000000;
# }
# #T_cdea4_row5_col5 {
#   background-color: #d1ed9c;
#   color: #000000;
# }
# #T_cdea4_row5_col6, #T_cdea4_row50_col4 {
#   background-color: #dd4a4c;
#   color: #f1f1f1;
# }
# #T_cdea4_row5_col7, #T_cdea4_row37_col3 {
#   background-color: #e2514a;
#   color: #f1f1f1;
# }
# #T_cdea4_row6_col2, #T_cdea4_row18_col2, #T_cdea4_row32_col6 {
#   background-color: #358bbc;
#   color: #f1f1f1;
# }
# #T_cdea4_row6_col6 {
#   background-color: #da464d;
#   color: #f1f1f1;
# }
# #T_cdea4_row6_col7, #T_cdea4_row11_col4, #T_cdea4_row43_col2, #T_cdea4_row51_col3 {
#   background-color: #f99153;
#   color: #000000;
# }
# #T_cdea4_row7_col2 {
#   background-color: #4e63ac;
#   color: #f1f1f1;
# }
# #T_cdea4_row7_col3 {
#   background-color: #4175b4;
#   color: #f1f1f1;
# }
# #T_cdea4_row7_col4, #T_cdea4_row17_col1 {
#   background-color: #94d4a4;
#   color: #000000;
# }
# #T_cdea4_row7_col5 {
#   background-color: #50a9af;
#   color: #f1f1f1;
# }
# #T_cdea4_row7_col6 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_cdea4_row7_col7 {
#   background-color: #ea5e47;
#   color: #f1f1f1;
# }
# #T_cdea4_row8_col1, #T_cdea4_row19_col2 {
#   background-color: #5b53a4;
#   color: #f1f1f1;
# }
# #T_cdea4_row8_col3, #T_cdea4_row40_col7, #T_cdea4_row53_col8 {
#   background-color: #9fd8a4;
#   color: #000000;
# }
# #T_cdea4_row8_col4, #T_cdea4_row14_col5, #T_cdea4_row49_col7 {
#   background-color: #a4daa4;
#   color: #000000;
# }
# #T_cdea4_row8_col6, #T_cdea4_row47_col8 {
#   background-color: #99d6a4;
#   color: #000000;
# }
# #T_cdea4_row8_col7, #T_cdea4_row41_col5 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_cdea4_row9_col1, #T_cdea4_row9_col4, #T_cdea4_row30_col7 {
#   background-color: #3585bb;
#   color: #f1f1f1;
# }
# #T_cdea4_row9_col5 {
#   background-color: #47a0b3;
#   color: #f1f1f1;
# }
# #T_cdea4_row9_col6, #T_cdea4_row22_col3 {
#   background-color: #fcfeba;
#   color: #000000;
# }
# #T_cdea4_row9_col8, #T_cdea4_row26_col7, #T_cdea4_row58_col4 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_cdea4_row10_col2, #T_cdea4_row56_col3 {
#   background-color: #ad1246;
#   color: #f1f1f1;
# }
# #T_cdea4_row10_col3 {
#   background-color: #545ca8;
#   color: #f1f1f1;
# }
# #T_cdea4_row10_col5, #T_cdea4_row51_col4, #T_cdea4_row54_col4 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_cdea4_row10_col6 {
#   background-color: #d8434e;
#   color: #f1f1f1;
# }
# #T_cdea4_row10_col8 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_cdea4_row11_col2, #T_cdea4_row25_col1 {
#   background-color: #3682b

# %%
# # we'll copy the earlier dataframe
# dvcod = dxv.copy()
# dvcod = dvcod.rename(columns={'value': 'vaccines | ratio (total_dose/pop.)'})
# dvcod = dvcod.rename(columns={'average(2022-2024)': 'deaths | average(2022-2024)'})
# dvcod = dvcod[['name','abbr','deaths | average(2022-2024)','vaccines | ratio (total_dose/pop.)']]

# # display(dvcod)

# # codn 
# blood_related = [
#     'Diseases of the blood and blood-forming organs and certain disorders involving the immune mechanism',
#     'Hodgkin disease and lymphomas',
#     'Other malignant neoplasms of lymphoid, haematopoietic, and related tissue',
#     'Leukaemia',
#     'Diabetes mellitus',
# ]
# cancer_related = [
#     "Malignant neoplasm of lip, oral cavity, pharynx",
#     "Malignant neoplasm of colon, rectosigmoid junction, rectum, anus, and anal canal",
#     "Malignant neoplasm of trachea, bronchus, and lung",
#     "Malignant neoplasm of other parts of uterus",
#     "Malignant neoplasm of brain and central nervous system",
#     "Hodgkin disease and lymphomas",
#     "Other malignant neoplasm of lymphoid, haematopoietic, and related tissue",
#     "Leukaemia",
#     "Other malignant neoplasms (remainder of C00-C97)",
#     "Non-malignant neoplasms (benign and uncertain)"
# ]
# heart_related = [
#     "Ischaemic heart diseases",
#     "Acute myocardial infarction including subsequent myocardial infarction",
#     "Other ischaemic heart diseases",
#     "Other heart diseases",
#     "Cerebrovascular diseases",
#     "Other diseases of the circulatory system (remainder of I00-I99)"
# ]
# unknown_related = [
#     "Ill-defined and unknown causes of mortality",
#     "Other symptoms, signs and abnormal clinical and laboratory findings (remainder of R00-R99)",
#     "Event of undetermined intent"
# ]
# br = cd[(cd['source']=='cause_of_death') & (cd['filter'].isin(blood_related))   & (cd['value_type']=='normalized') & (cd['year'] >= 2022) & (cd['value'] > 0.0)]
# cr = cd[(cd['source']=='cause_of_death') & (cd['filter'].isin(cancer_related))  & (cd['value_type']=='normalized') & (cd['year'] >= 2022) & (cd['value'] > 0.0)]
# hr = cd[(cd['source']=='cause_of_death') & (cd['filter'].isin(heart_related))   & (cd['value_type']=='normalized') & (cd['year'] >= 2022) & (cd['value'] > 0.0)]
# ur = cd[(cd['source']=='cause_of_death') & (cd['filter'].isin(unknown_related)) & (cd['value_type']=='normalized') & (cd['year'] >= 2022) & (cd['value'] > 0.0)]

# codlist = [
#     {"df":br,"desc":'blood_related'},
#     {"df":cr,"desc":'cancer_related'},
#     {"df":hr,"desc":'heart_related'},
#     {"df":ur,"desc":'unknown_related'}
# ]

# for y in range(2015,2025,1):
#     try:
#         dvcod = dvcod.rename(columns={y:f"{y}_deaths"})
#     except:
#         pass

# for i in codlist:
#     temp = pd.pivot_table(
#         data = i['df'],
#         values = 'value',
#         index = ['name'],
#         columns=['year'],
#         aggfunc='mean',
#         # aggfunc='sum',
#     )
#     temp = temp.rename(columns={'value':i['desc']})
#     dvcod = pd.merge(dvcod,temp, how='left',on='name')
    
#     for y in range(2015,2025,1):
#         try:
#             dvcod = dvcod.rename(columns={y:f"{y}_{i['desc']}"})
#         except:
#             pass 

#     # display(dvcod)


# # display(dvcod)

# dvcod = dvcod.sort_values(by='vaccines | ratio (total_dose/pop.)',ascending=False)
# # dvcod = dvcod.sort_values(by='2022_cancer_related',ascending=False)
# # dvcod = dvcod.sort_values(by='2022_heart_related',ascending=False)

# viridis_r = sns.color_palette("viridis_r", as_cmap=True)
# spectral_r = sns.color_palette("Spectral_r", as_cmap=True)

# styled_df = dvcod.style.background_gradient(cmap=heatmapCM2, axis=0, subset=['deaths | average(2022-2024)']) \
#                         .background_gradient(cmap=spectral_r, axis=0, subset=['vaccines | ratio (total_dose/pop.)']) \
#                         .background_gradient(cmap=viridis_r, axis=0, subset=['2022_blood_related','2023_blood_related']) \
#                         .background_gradient(cmap=viridis_r, axis=0, subset=['2022_cancer_related','2023_cancer_related']) \
#                         .background_gradient(cmap=viridis_r, axis=0, subset=['2022_heart_related','2023_heart_related']) \
#                         .background_gradient(cmap=viridis_r, axis=0, subset=['2022_unknown_related','2023_unknown_related']) 

# # styled_df = dvcod.style.background_gradient(cmap=heatmapCM2, axis=0, subset=['deaths | average(2022-2024)']) \
# #                         .background_gradient(cmap=spectral_r, axis=0, subset=['vaccines | ratio (total_dose/pop.)']) \
# #                         .background_gradient(cmap=viridis_r, axis=0, subset=['2022_blood_related']) \
# #                         .background_gradient(cmap=viridis_r, axis=0, subset=['2022_cancer_related']) \
# #                         .background_gradient(cmap=viridis_r, axis=0, subset=['2022_heart_related']) \
# #                         .background_gradient(cmap=viridis_r, axis=0, subset=['2022_unknown_related']) 

# display(styled_df)

# %% [markdown]
# #### Spearman and Kendall ... (again)

# %%
# create a ranked list for vaccines - ratio (total_dose/pop.)

v = dxv.copy().reset_index(drop=True)
v = v.rename(columns={'value': 'vaccines | ratio (total_dose/pop.)'})
v = v[~v['vaccines | ratio (total_dose/pop.)'].isna()]
v = v.sort_values(by='vaccines | ratio (total_dose/pop.)',ascending=True) #least vaccine to most vaccines
v = v[['name','abbr','vaccines | ratio (total_dose/pop.)']]
v['rank'] = v['vaccines | ratio (total_dose/pop.)'].rank()
# display(v)

cods = cd[(cd.source == 'cause_of_death') & (cd.value_type == 'normalized') & (cd['year'] == 2022) & (~cd.value.isna()) & (~(cd['filter'] == 'Total')) ]['filter'].drop_duplicates().to_list()


result = []
for c in cods:
    # print(c)

    temp = pd.pivot_table(
        data = cd[(cd['filter'] == c) & (cd.value_type == 'normalized') & (cd['year'] == 2022)],
        values = 'value',
        index = ['name','abbr'],
        columns=['year'],
        aggfunc='mean',
    )
    temp = temp.reset_index()

    temp = temp.sort_values(by=2022,ascending=False) #most deaths to least deaths
    temp['rank'] = temp[2022].rank()
    # display(temp)

    temp = temp[temp.abbr.isin(v.abbr)]
    vtemp = v[v.abbr.isin(temp.abbr)]

    for i, row in vtemp.iterrows():
        temp.loc[temp['abbr']==row['abbr'], 'rank'] = row['rank']

    result.append(
        {
            'cause_of_death': c,
            'Spearman_Rank': spearmanr(temp['rank'], vtemp['rank'])[0],
            'Kendall_Tau': kendalltau(temp['rank'], vtemp['rank'])[0]
        }
    )

    # display(temp)
    # display(vtemp)

    # display(MD(f"## {c} x Vaccines"))
    # # Calculate Spearman's Rank Correlation
    # spearman_corr, _ = spearmanr(temp['rank'], vtemp['rank'])
    # display(MD(f"### Spearman's Rank Correlation: {spearman_corr}"))

    # display(bar(((spearman_corr+1.0)/2.0)*100,length=100))
    # display('-1'+' '*48 + '0' + ' '*50 + '1')

    # # Calculate Kendall's Tau
    # kendall_corr, _ = kendalltau(temp['rank'], v['rank'])
    # display(MD(f"### Kendall's Tau: {kendall_corr}"))

    # display( bar(((kendall_corr+1.0)/2.0)*100,length=100))
    # display('-1'+' '*48 + '0' + ' '*50 + '1')

display(MD(
'''### Output Interpretation

| Value     | Effect                      | Description/Correlation-Suggestion                                   |
|-----------|-----------------------------|----------------------------------------------------------------------|
| **1.0**   | Positive effect             | Suggests more vaccines will lead to fewer [cause of death].          |
| **0.5**   | Slightly positive effect    | Slightly suggests more vaccines will lead to fewer [cause of death]. |
| **0.0**   | Null/No effect              | Vaccines do not change the number of [cause of death].               |
| **-0.5**  | Slightly negative effect    | Slightly suggests more vaccines will lead to more [cause of death].  |
| **-1.0**  | Negative effect             | Suggests more vaccines will lead to more [cause of death].           |

'''
))

result = pd.DataFrame(result)
result = result.sort_values(by='Spearman_Rank')
result = result.reset_index(drop=True)
display(result.style.background_gradient(cmap=heatmapCM))#,vmax=1.0,vmin=-1.0))
# Out:
# ### Output Interpretation
#
# | Value     | Effect                      | Description/Correlation-Suggestion                                   |
# |-----------|-----------------------------|----------------------------------------------------------------------|
# | **1.0**   | Positive effect             | Suggests more vaccines will lead to fewer [cause of death].          |
# | **0.5**   | Slightly positive effect    | Slightly suggests more vaccines will lead to fewer [cause of death]. |
# | **0.0**   | Null/No effect              | Vaccines do not change the number of [cause of death].               |
# | **-0.5**  | Slightly negative effect    | Slightly suggests more vaccines will lead to more [cause of death].  |
# | **-1.0**  | Negative effect             | Suggests more vaccines will lead to more [cause of death].           |
# <style type="text/css">
# #T_5eac8_row0_col1, #T_5eac8_row0_col2 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_5eac8_row1_col1 {
#   background-color: #5758a6;
#   color: #f1f1f1;
# }
# #T_5eac8_row1_col2 {
#   background-color: #5c51a3;
#   color: #f1f1f1;
# }
# #T_5eac8_row2_col1 {
#   background-color: #4d65ad;
#   color: #f1f1f1;
# }
# #T_5eac8_row2_col2 {
#   background-color: #5956a5;
#   color: #f1f1f1;
# }
# #T_5eac8_row3_col1 {
#   background-color: #496aaf;
#   color: #f1f1f1;
# }
# #T_5eac8_row3_col2, #T_5eac8_row4_col2 {
#   background-color: #4e63ac;
#   color: #f1f1f1;
# }
# #T_5eac8_row4_col1 {
#   background-color: #3880b9;
#   color: #f1f1f1;
# }
# #T_5eac8_row5_col1 {
#   background-color: #459eb4;
#   color: #f1f1f1;
# }
# #T_5eac8_row5_col2 {
#   background-color: #52abae;
#   color: #f1f1f1;
# }
# #T_5eac8_row6_col1, #T_5eac8_row7_col1 {
#   background-color: #47a0b3;
#   color: #f1f1f1;
# }
# #T_5eac8_row6_col2 {
#   background-color: #3d95b8;
#   color: #f1f1f1;
# }
# #T_5eac8_row7_col2 {
#   background-color: #4ea7b0;
#   color: #f1f1f1;
# }
# #T_5eac8_row8_col1 {
#   background-color: #54aead;
#   color: #f1f1f1;
# }
# #T_5eac8_row8_col2, #T_5eac8_row10_col1 {
#   background-color: #5cb7aa;
#   color: #f1f1f1;
# }
# #T_5eac8_row9_col1 {
#   background-color: #56b0ad;
#   color: #f1f1f1;
# }
# #T_5eac8_row9_col2 {
#   background-color: #439bb5;
#   color: #f1f1f1;
# }
# #T_5eac8_row10_col2 {
#   background-color: #49a2b2;
#   color: #f1f1f1;
# }
# #T_5eac8_row11_col1, #T_5eac8_row11_col2 {
#   background-color: #84cea5;
#   color: #000000;
# }
# #T_5eac8_row12_col1, #T_5eac8_row14_col2 {
#   background-color: #99d6a4;
#   color: #000000;
# }
# #T_5eac8_row12_col2 {
#   background-color: #7ccaa5;
#   color: #000000;
# }
# #T_5eac8_row13_col1 {
#   background-color: #9cd7a4;
#   color: #000000;
# }
# #T_5eac8_row13_col2, #T_5eac8_row16_col2 {
#   background-color: #89d0a4;
#   color: #000000;
# }
# #T_5eac8_row14_col1 {
#   background-color: #9fd8a4;
#   color: #000000;
# }
# #T_5eac8_row15_col1 {
#   background-color: #a2d9a4;
#   color: #000000;
# }
# #T_5eac8_row15_col2, #T_5eac8_row18_col2, #T_5eac8_row20_col2, #T_5eac8_row21_col2 {
#   background-color: #aadca4;
#   color: #000000;
# }
# #T_5eac8_row16_col1 {
#   background-color: #acdda4;
#   color: #000000;
# }
# #T_5eac8_row17_col1 {
#   background-color: #aedea3;
#   color: #000000;
# }
# #T_5eac8_row17_col2, #T_5eac8_row19_col2 {
#   background-color: #94d4a4;
#   color: #000000;
# }
# #T_5eac8_row18_col1 {
#   background-color: #b1dfa3;
#   color: #000000;
# }
# #T_5eac8_row19_col1 {
#   background-color: #b3e0a2;
#   color: #000000;
# }
# #T_5eac8_row20_col1, #T_5eac8_row21_col1 {
#   background-color: #b5e1a2;
#   color: #000000;
# }
# #T_5eac8_row22_col1 {
#   background-color: #bae3a1;
#   color: #000000;
# }
# #T_5eac8_row22_col2, #T_5eac8_row24_col2 {
#   background-color: #bce4a0;
#   color: #000000;
# }
# #T_5eac8_row23_col1 {
#   background-color: #c1e6a0;
#   color: #000000;
# }
# #T_5eac8_row23_col2 {
#   background-color: #a4daa4;
#   color: #000000;
# }
# #T_5eac8_row24_col1, #T_5eac8_row25_col2 {
#   background-color: #c8e99e;
#   color: #000000;
# }
# #T_5eac8_row25_col1, #T_5eac8_row28_col2 {
#   background-color: #cdeb9d;
#   color: #000000;
# }
# #T_5eac8_row26_col1, #T_5eac8_row30_col2 {
#   background-color: #d1ed9c;
#   color: #000000;
# }
# #T_5eac8_row26_col2, #T_5eac8_row29_col2 {
#   background-color: #bfe5a0;
#   color: #000000;
# }
# #T_5eac8_row27_col1 {
#   background-color: #d3ed9c;
#   color: #000000;
# }
# #T_5eac8_row27_col2, #T_5eac8_row31_col1, #T_5eac8_row33_col2, #T_5eac8_row34_col2 {
#   background-color: #e4f498;
#   color: #000000;
# }
# #T_5eac8_row28_col1 {
#   background-color: #d6ee9b;
#   color: #000000;
# }
# #T_5eac8_row29_col1 {
#   background-color: #d8ef9b;
#   color: #000000;
# }
# #T_5eac8_row30_col1 {
#   background-color: #ddf19a;
#   color: #000000;
# }
# #T_5eac8_row31_col2 {
#   background-color: #c3e79f;
#   color: #000000;
# }
# #T_5eac8_row32_col1 {
#   background-color: #e6f598;
#   color: #000000;
# }
# #T_5eac8_row32_col2 {
#   background-color: #dff299;
#   color: #000000;
# }
# #T_5eac8_row33_col1, #T_5eac8_row35_col2 {
#   background-color: #e9f69d;
#   color: #000000;
# }
# #T_5eac8_row34_col1 {
#   background-color: #ecf7a1;
#   color: #000000;
# }
# #T_5eac8_row35_col1, #T_5eac8_row39_col2 {
#   background-color: #eff9a6;
#   color: #000000;
# }
# #T_5eac8_row36_col1 {
#   background-color: #f2faaa;
#   color: #000000;
# }
# #T_5eac8_row36_col2 {
#   background-color: #e7f59a;
#   color: #000000;
# }
# #T_5eac8_row37_col1 {
#   background-color: #f3faac;
#   color: #000000;
# }
# #T_5eac8_row37_col2 {
#   background-color: #f5fbaf;
#   color: #000000;
# }
# #T_5eac8_row38_col1 {
#   background-color: #f4faad;
#   color: #000000;
# }
# #T_5eac8_row38_col2 {
#   background-color: #ebf7a0;
#   color: #000000;
# }
# #T_5eac8_row39_col1 {
#   background-color: #f7fcb2;
#   color: #000000;
# }
# #T_5eac8_row40_col1 {
#   background-color: #fefebd;
#   color: #000000;
# }
# #T_5eac8_row40_col2, #T_5eac8_row42_col2 {
#   background-color: #f9fcb5;
#   color: #000000;
# }
# #T_5eac8_row41_col1 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_5eac8_row41_col2 {
#   background-color: #fbfdb8;
#   color: #000000;
# }
# #T_5eac8_row42_col1, #T_5eac8_row43_col2 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_5eac8_row43_col1 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_5eac8_row44_col1, #T_5eac8_row45_col1 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_5eac8_row44_col2, #T_5eac8_row47_col2 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_5eac8_row45_col2 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_5eac8_row46_col1 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_5eac8_row46_col2 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_5eac8_row47_col1 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_5eac8_row48_col1, #T_5eac8_row49_col2 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_5eac8_row48_col2 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_5eac8_row49_col1 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_5eac8_row50_col1 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_5eac8_row50_col2 {
#   background-color: #fdbd6d;
#   color: #000000;
# }
# #T_5eac8_row51_col1 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_5eac8_row51_col2, #T_5eac8_row52_col2 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_5eac8_row52_col1 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_5eac8_row53_col1 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_5eac8_row53_col2 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_5eac8_row54_col1 {
#   background-color: #eb6046;
#   color: #f1f1f1;
# }
# #T_5eac8_row54_col2 {
#   background-color: #f06744;
#   color: #f1f1f1;
# }
# #T_5eac8_row55_col1 {
#   background-color: #e1504b;
#   color: #f1f1f1;
# }
# #T_5eac8_row55_col2 {
#   background-color: #e95c47;
#   color: #f1f1f1;
# }
# #T_5eac8_row56_col1 {
#   background-color: #d8434e;
#   color: #f1f1f1;
# }
# #T_5eac8_row56_col2 {
#   background-color: #d9444d;
#   color: #f1f1f1;
# }
# #T_5eac8_row57_col1, #T_5eac8_row57_col2 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5eac8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5eac8_level0_col0" class="col_heading level0 col0" >cause_of_death</th>
#       <th id="T_5eac8_level0_col1" class="col_heading level0 col1" >Spearman_Rank</th>
#       <th id="T_5eac8_level0_col2" class="col_heading level0 col2" >Kendall_Tau</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5eac8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5eac8_row0_col0" class="data row0 col0" >Intentional self-harm</td>
#       <td id="T_5eac8_row0_col1" class="data row0 col1" >-0.497537</td>
#       <td id="T_5eac8_row0_col2" class="data row0 col2" >-0.325123</td>
#     </tr>
#     <tr>
#       <th id="T_5eac8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5eac8_row1_col0" class="data row1 col0" >Other accidents (W20-W64, W75-X39, X50-X59, Y86)</td>
#       <td id="T_5eac8_row1_col1" class="data row1 col1" >-0.480788</td>
#       <td id="T_5eac8_row1_col2" class="data row1 col2" >-0.320197</td>
#     </tr>
#     <tr>
#       <th id="T_5eac8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5eac8_row2_col0" class="data row2 col0" >Neoplasms</td>

# %%
# create a ranked list for blood deaths (2022)
d_blood = dvcod.copy().reset_index(drop=True)
d_blood = d_blood.sort_values(by='2022_blood_related',ascending=False) #most deaths to least deaths
d_blood = d_blood[['name','abbr','2022_blood_related']]
d_blood['rank'] = d_blood['2022_blood_related'].rank()

# create a ranked list for cancer deaths (2022)
d_cancer = dvcod.copy().reset_index(drop=True)
d_cancer = d_cancer.sort_values(by='2022_cancer_related',ascending=False) #most deaths to least deaths
d_cancer = d_cancer[['name','abbr','2022_cancer_related']]
d_cancer['rank'] = d_cancer['2022_cancer_related'].rank()

# create a ranked list for heart deaths (2022)
d_heart = dvcod.copy().reset_index(drop=True)
d_heart = d_heart.sort_values(by='2022_heart_related',ascending=False) #most deaths to least deaths
d_heart = d_heart[['name','abbr','2022_heart_related']]
d_heart['rank'] = d_heart['2022_heart_related'].rank()

# create a ranked list for unknown deaths (2022)
d_unknown = dvcod.copy().reset_index(drop=True)
d_unknown = d_unknown.sort_values(by='2022_unknown_related',ascending=False) #most deaths to least deaths
d_unknown = d_unknown[['name','abbr','2022_unknown_related']]
d_unknown['rank'] = d_unknown['2022_unknown_related'].rank()

deaths = [
    {"df":d_blood,"desc":'blood_related'},
    {"df":d_cancer,"desc":'cancer_related'},
    {"df":d_heart,"desc":'heart_related'},
    {"df":d_unknown,"desc":'unknown_related'}
]

# create a ranked list for vaccines - ratio (total_dose/pop.)
v = dvcod.copy().reset_index(drop=True)
v = v.sort_values(by='vaccines | ratio (total_dose/pop.)',ascending=True) #least vaccine to most vaccines
v = v[['name','abbr','vaccines | ratio (total_dose/pop.)']]
v['rank'] = v['vaccines | ratio (total_dose/pop.)'].rank()

display(MD(
'''### Output Interpretation

| Value     | Effect                      | Description/Correlation-Suggestion                         |
|-----------|-----------------------------|------------------------------------------------------------|
| **1.0**   | Positive effect             | Suggests more vaccines will lead to fewer deaths.          |
| **0.5**   | Slightly positive effect    | Slightly suggests more vaccines will lead to fewer deaths. |
| **0.0**   | Null/No effect              | Vaccines do not change the number of deaths.               |
| **-0.5**  | Slightly negative effect    | Slightly suggests more vaccines will lead to more deaths.  |
| **-1.0**  | Negative effect             | Suggests more vaccines will lead to more deaths.           |

'''
))

for d in deaths:
    # make sure the have the same countries
    d['df'] = d['df'][d['df'].abbr.isin(v.abbr)]

    for i, row in v.iterrows():
        d['df'].loc[d['df']['abbr']==row['abbr'], 'rank'] = row['rank']

    # no NAN values
    d['df'] = d['df'][~d['df']['rank'].isna()]
    v = v[~v['rank'].isna()]

    display(MD(f"## {d['desc']} x Vaccines"))

    # Calculate Spearman's Rank Correlation
    spearman_corr, _ = spearmanr(d['df']['rank'], v['rank'])
    display(MD(f"### Spearman's Rank Correlation: {spearman_corr}"))

    display(bar(((spearman_corr+1.0)/2.0)*100,length=100))
    display('-1'+' '*48 + '0' + ' '*50 + '1')

    # Calculate Kendall's Tau
    kendall_corr, _ = kendalltau(d['df']['rank'], v['rank'])
    display(MD(f"### Kendall's Tau: {kendall_corr}"))

    display( bar(((kendall_corr+1.0)/2.0)*100,length=100))
    display('-1'+' '*48 + '0' + ' '*50 + '1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 # create a ranked list for blood deaths (2022)
# ----> 2 d_blood = dvcod.copy().reset_index(drop=True)
#       3 d_blood = d_blood.sort_values(by='2022_blood_related',ascending=False) #most deaths to least deaths
#       4 d_blood = d_blood[['name','abbr','2022_blood_related']]
#
# NameError: name 'dvcod' is not defined

# %%
# Out:
# Certain infectious and parasitic diseases (A00-B99)
# ## Certain infectious and parasitic diseases (A00-B99) x Vaccines
# ### Spearman's Rank Correlation: -0.06453201970443348
# '[##############################################______________________________________________________]'
# '-1                                                0                                                  1'
# Tuberculosis
# ## Tuberculosis x Vaccines
# ### Spearman's Rank Correlation: -0.08155446086480568
# '[#############################################_______________________________________________________]'
# '-1                                                0                                                  1'
# Viral hepatitis and sequelae of viral hepatitis
# ## Viral hepatitis and sequelae of viral hepatitis x Vaccines
# ### Spearman's Rank Correlation: 0.20886699507389156
# '[############################################################________________________________________]'
# '-1                                                0                                                  1'
# Chronic viral hepatitis B and C
# ## Chronic viral hepatitis B and C x Vaccines
# ### Spearman's Rank Correlation: 0.10968379446640317
# '[#######################################################_____________________________________________]'
# '-1                                                0                                                  1'
# Human immunodeficiency virus [HIV] disease
# ## Human immunodeficiency virus [HIV] disease x Vaccines
# ### Spearman's Rank Correlation: 0.16666666666666663
# '[##########################################################__________________________________________]'
# '-1                                                0                                                  1'
# Other infectious and parasitic diseases (remainder of A00-B99)
# ## Other infectious and parasitic diseases (remainder of A00-B99) x Vaccines
# ### Spearman's Rank Correlation: 0.011822660098522165
# '[##################################################__________________________________________________]'
# '-1                                                0                                                  1'
# Neoplasms
# ## Neoplasms x Vaccines
# ### Spearman's Rank Correlation: -0.45812807881773393
# '[###########################_________________________________________________________________________]'
# '-1                                                0                                                  1'
# Malignant neoplasm of lip, oral cavity, pharynx
# ## Malignant neoplasm of lip, oral cavity, pharynx x Vaccines
# ### Spearman's Rank Correlation: -0.16403940886699503
# '[#########################################___________________________________________________________]'
# '-1                                                0                                                  1'
# Malignant neoplasm of colon, rectosigmoid junction, rectum, anus and anal canal
# ## Malignant neoplasm of colon, rectosigmoid junction, rectum, anus and anal canal x Vaccines
# ### Spearman's Rank Correlation: -0.14679802955665022
# '[##########################################__________________________________________________________]'
# '-1                                                0                                                  1'
# Malignant neoplasm of trachea, bronchus and lung
# ## Malignant neoplasm of trachea, bronchus and lung x Vaccines
# ### Spearman's Rank Correlation: -0.4522167487684728
# '[###########################_________________________________________________________________________]'
# '-1                                                0                                                  1'
# Malignant neoplasm of other parts of uterus
# ## Malignant neoplasm of other parts of uterus x Vaccines
# ### Spearman's Rank Correlation: -0.20541871921182261
# '[#######################################_____________________________________________________________]'
# '-1                                                0                                                  1'
# Malignant neoplasm of brain and central nervous system
# ## Malignant neoplasm of brain and central nervous system x Vaccines
# ### Spearman's Rank Correlation: -0.4147783251231526
# '[#############################_______________________________________________________________________]'
# '-1                                                0                                                  1'
# Hodgkin disease and lymphomas
# ## Hodgkin disease and lymphomas x Vaccines
# ### Spearman's Rank Correlation: -0.27192118226600975
# '[####################################________________________________________________________________]'
# '-1                                                0                                                  1'
# Other malignant neoplasm of lymphoid, haematopoietic and related tissue
# ## Other malignant neoplasm of lymphoid, haematopoietic and related tissue x Vaccines
# ### Spearman's Rank Correlation: -0.15418719211822657
# '[##########################################__________________________________________________________]'
# '-1                                                0                                                  1'
# Leukaemia
# ## Leukaemia x Vaccines
# ### Spearman's Rank Correlation: -0.34285714285714275
# '[################################____________________________________________________________________]'
# '-1                                                0                                                  1'
# Other malignant neoplasms (remainder of C00-C97)
# ## Other malignant neoplasms (remainder of C00-C97) x Vaccines
# ### Spearman's Rank Correlation: -0.3660098522167487
# '[###############################_____________________________________________________________________]'
# '-1                                                0                                                  1'
# Non-malignant neoplasms (benign and uncertain)
# ## Non-malignant neoplasms (benign and uncertain) x Vaccines
# ### Spearman's Rank Correlation: 0.30295566502463045
# '[#################################################################___________________________________]'
# '-1                                                0                                                  1'
# Diseases of the blood and blood-forming organs and certain disorders involving the immune mechanism
# ## Diseases of the blood and blood-forming organs and certain disorders involving the immune mechanism x Vaccines
# ### Spearman's Rank Correlation: -0.0167487684729064
# '[#################################################___________________________________________________]'
# '-1                                                0                                                  1'
# Diabetes mellitus
# ## Diabetes mellitus x Vaccines
# ### Spearman's Rank Correlation: 0.03557744937055282
# '[###################################################_________________________________________________]'
# '-1                                                0                                                  1'
# Other endocrine, nutritional and metabolic diseases (remainder of E00-E90)
# ## Other endocrine, nutritional and metabolic diseases (remainder of E00-E90) x Vaccines
# ### Spearman's Rank Correlation: -0.2073891625615763
# '[#######################################_____________________________________________________________]'
# '-1                                                0                                                  1'
# Dementia
# ## Dementia x Vaccines
# ### Spearman's Rank Correlation: 0.0293040293040293
# '[###################################################_________________________________________________]'
# '-1                                                0                                                  1'
# Drug dependence, toxicomania (F11-F16, F18-F19)
# ## Drug dependence, toxicomania (F11-F16, F18-F19) x Vaccines
# ### Spearman's Rank Correlation: -0.1842364532019704
# '[########################################____________________________________________________________]'
# '-1                                                0                                                  1'
# Other mental and behavioural disorders (remainder of F00-F99)
# ## Other mental and behavioural disorders (remainder of F00-F99) x Vaccines
# ### Spearman's Rank Correlation: -0.19458128078817727
# '[########################################____________________________________________________________]'
# '-1                                                0                                                  1'
# Diseases of the nervous system and the sense organs (G00-H95)
# ## Diseases of the nervous system and the sense organs (G00-H95) x Vaccines
# ### Spearman's Rank Correlation: -0.07980295566502461
# '[##############################################______________________________________________________]'
# '-1                                                0                                                  1'
# Other diseases of the nervous system and the sense organs (remainder of G00-H95)
# ## Other diseases of the nervous system and the sense organs (remainder of G00-H95) x Vaccines
# ### Spearman's Rank Correlation: -0.15862068965517237
# '[##########################################__________________________________________________________]'
# '-1                                                0                                                  1'
# Ischaemic heart diseases
# ## Ischaemic heart diseases x Vaccines
# ### Spearman's Rank Correlation: 0.13054187192118222
# '[########################################################____________________________________________]'
# '-1                                                0                                                  1'
# Acute myocardial infarction including subsequent myocardial infarction
# ## Acute myocardial infarction including subsequent myocardial infarction x Vaccines
# ### Spearman's Rank Correlation: 0.3266009852216748
# '[##################################################################__________________________________]'
# '-1                                                0                                                  1'
# Other ischaemic heart diseases
# ## Other ischaemic heart diseases x Vaccines
# ### Spearman's Rank Correlation: -0.13990147783251228
# '[###########################################_________________________________________________________]'
# '-1                                                0                                                  1'
# Other heart diseases
# ## Other heart diseases x Vaccines
# ### Spearman's Rank Correlation: 0.18078817733990143
# '[###########################################################_________________________________________]'
# '-1                                                0                                                  1'
# Cerebrovascular diseases
# ## Cerebrovascular diseases x Vaccines
# ### Spearman's Rank Correlation: -0.030049261083743836
# '[################################################____________________________________________________]'
# '-1                                                0                                                  1'
# Other diseases of the circulatory system (remainder of I00-I99)
# ## Other diseases of the circulatory system (remainder of I00-I99) x Vaccines
# ### Spearman's Rank Correlation: -0.10492610837438422
# '[############################################________________________________________________________]'
# '-1                                                0                                                  1'
# Influenza (including swine flu)
# ## Influenza (including swine flu) x Vaccines
# ### Spearman's Rank Correlation: -0.11477832512315268
# '[############################################________________________________________________________]'
# '-1                                                0                                                  1'
# Pneumonia
# ## Pneumonia x Vaccines
# ### Spearman's Rank Correlation: 0.4310344827586206
# '[#######################################################################_____________________________]'
# '-1                                                0                                                  1'
# Chronic lower respiratory diseases
# ## Chronic lower respiratory diseases x Vaccines
# ### Spearman's Rank Correlation: -0.2162561576354679
# '[#######################################_____________________________________________________________]'
# '-1                                                0                                                  1'
# Asthma and status asthmaticus
# ## Asthma and status asthmaticus x Vaccines
# ### Spearman's Rank Correlation: -0.03793103448275861
# '[################################################____________________________________________________]'
# '-1                                                0                                                  1'
# Other lower respiratory diseases
# ## Other lower respiratory diseases x Vaccines
# ### Spearman's Rank Correlation: -0.21379310344827585
# '[#######################################_____________________________________________________________]'
# '-1                                                0                                                  1'
# Other diseases of the respiratory system (remainder of J00-J99)
# ## Other diseases of the respiratory system (remainder of J00-J99) x Vaccines
# ### Spearman's Rank Correlation: -0.07339901477832511
# '[##############################################______________________________________________________]'
# '-1                                                0                                                  1'
# Ulcer of stomach, duodenum and jejunum
# ## Ulcer of stomach, duodenum and jejunum x Vaccines
# ### Spearman's Rank Correlation: 0.05467980295566501
# '[####################################################________________________________________________]'
# '-1                                                0                                                  1'
# Chronic liver disease
# ## Chronic liver disease x Vaccines
# ### Spearman's Rank Correlation: 0.2684729064039408
# '[###############################################################_____________________________________]'
# '-1                                                0                                                  1'
# Chronic liver disease (excluding alcoholic and toxic liver disease)
# ## Chronic liver disease (excluding alcoholic and toxic liver disease) x Vaccines
# ### Spearman's Rank Correlation: 0.07826086956521738
# '[#####################################################_______________________________________________]'
# '-1                                                0                                                  1'
# Other diseases of the digestive system (remainder of K00-K93)
# ## Other diseases of the digestive system (remainder of K00-K93) x Vaccines
# ### Spearman's Rank Correlation: -0.3270935960591132
# '[#################################___________________________________________________________________]'
# '-1                                                0                                                  1'
# Rheumatoid arthritis and arthrosis (M05-M06,M15-M19)
# ## Rheumatoid arthritis and arthrosis (M05-M06,M15-M19) x Vaccines
# ### Spearman's Rank Correlation: -0.09462759462759461
# '[#############################################_______________________________________________________]'
# '-1                                                0                                                  1'
# Other diseases of the musculoskeletal system and connective tissue (remainder of M00-M99)
# ## Other diseases of the musculoskeletal system and connective tissue (remainder of M00-M99) x Vaccines
# ### Spearman's Rank Correlation: -0.15024630541871917
# '[##########################################__________________________________________________________]'
# '-1                                                0                                                  1'
# Diseases of kidney and ureter
# ## Diseases of kidney and ureter x Vaccines
# ### Spearman's Rank Correlation: -0.23990147783251226
# '[######################################______________________________________________________________]'
# '-1                                                0                                                  1'
# Other diseases of the genitourinary system (remainder of N00-N99)
# ## Other diseases of the genitourinary system (remainder of N00-N99) x Vaccines
# ### Spearman's Rank Correlation: -0.20049261083743838
# '[#######################################_____________________________________________________________]'
# '-1                                                0                                                  1'
# Ill-defined and unknown causes of mortality
# ## Ill-defined and unknown causes of mortality x Vaccines
# ### Spearman's Rank Correlation: -0.12857142857142856
# '[###########################################_________________________________________________________]'
# '-1                                                0                                                  1'
# Other symptoms, signs and abnormal clinical and laboratory findings (remainder of R00-R99)
# ## Other symptoms, signs and abnormal clinical and laboratory findings (remainder of R00-R99) x Vaccines
# ### Spearman's Rank Correlation: -0.12534209085933223
# '[###########################################_________________________________________________________]'
# '-1                                                0                                                  1'
# External causes of morbidity and mortality (V01-Y89)
# ## External causes of morbidity and mortality (V01-Y89) x Vaccines
# ### Spearman's Rank Correlation: -0.36354679802955653
# '[###############################_____________________________________________________________________]'
# '-1                                                0                                                  1'
# Accidents (V01-X59, Y85, Y86)
# ## Accidents (V01-X59, Y85, Y86) x Vaccines
# ### Spearman's Rank Correlation: -0.3684729064039408
# '[###############################_____________________________________________________________________]'
# '-1                                                0                                                  1'
# Transport accidents (V01-V99, Y85)
# ## Transport accidents (V01-V99, Y85) x Vaccines
# ### Spearman's Rank Correlation: -0.20197044334975364
# '[#######################################_____________________________________________________________]'
# '-1                                                0                                                  1'
# Other accidents (W20-W64, W75-X39, X50-X59, Y86)
# ## Other accidents (W20-W64, W75-X39, X50-X59, Y86) x Vaccines
# ### Spearman's Rank Correlation: -0.48078817733990137
# '[#########################___________________________________________________________________________]'
# '-1                                                0                                                  1'
# Falls
# ## Falls x Vaccines
# ### Spearman's Rank Correlation: -0.17142857142857137
# '[#########################################___________________________________________________________]'
# '-1                                                0                                                  1'
# Accidental drowning and submersion
# ## Accidental drowning and submersion x Vaccines
# ### Spearman's Rank Correlation: -0.24083196496989598
# '[#####################################_______________________________________________________________]'
# '-1                                                0                                                  1'
# Intentional self-harm
# ## Intentional self-harm x Vaccines
# ### Spearman's Rank Correlation: -0.4975369458128077
# '[#########################___________________________________________________________________________]'
# '-1                                                0                                                  1'
# Accidental poisoning by and exposure to noxious substances
# ## Accidental poisoning by and exposure to noxious substances x Vaccines
# ### Spearman's Rank Correlation: -0.2348111658456486
# '[######################################______________________________________________________________]'
# '-1                                                0                                                  1'
# Assault
# ## Assault x Vaccines
# ### Spearman's Rank Correlation: -0.3393541324575807
# '[#################################___________________________________________________________________]'
# '-1                                                0                                                  1'
# Event of undetermined intent
# ## Event of undetermined intent x Vaccines
# ### Spearman's Rank Correlation: 0.031135531135531136
# '[###################################################_________________________________________________]'
# '-1                                                0                                                  1'
# Other external causes of morbidity and mortality (remainder of V01-Y89)
# ## Other external causes of morbidity and mortality (remainder of V01-Y89) x Vaccines
# ### Spearman's Rank Correlation: -0.23097974822112752
# '[######################################______________________________________________________________]'
# '-1                                                0                                                  1'

# %% [markdown]
# # BookMark

# %%
# display(MD('### HeatMap (of deaths based on age groups)'))


## this is how we will sort 
sums = pd.pivot_table(
cd[(cd['source']=='deaths') & (cd['filter']=='TOTAL') & (cd['value_type']=='normalized') & (cd['year'] > 2023)], # totals only 
values = 'value',
index = ['abbr','name'],
aggfunc='sum',
)
sums = sums.reset_index()
sums = sums.sort_values(by='value',ascending=False)

heads = sums.head(10)
tails = sums.tail(10)

tempD = cd[(cd['source']=='deaths') & (cd['filter']=='TOTAL') & (cd['value_type']=='normalized')]
tempD_head = tempD[tempD.name.isin(heads.name)]
tempD_tail = tempD[tempD.name.isin(tails.name)]


tempV = cd[(cd['source']=='vaccine') & (cd['filter']=='All') & (cd['value_type']=='ratio (total_dose/pop.)')]
tempV_head = tempV[tempV.name.isin(heads.name)]
tempV_tail = tempV[tempV.name.isin(tails.name)]


# Create the figure
fig = go.Figure()

names = tempD_head.name.drop_duplicates().to_list()
for n in names:
    fig.add_trace(go.Scatter(
        x=tempD_head[tempD_head.name == n]['year'], 
        y=tempD_head[tempD_head.name == n]['value'], 
        mode='lines', 
        name=f"{n} deaths",
        legendgroup="group1",
        yaxis='y1'
        )
        )

names = tempD_tail.name.drop_duplicates().to_list()
for n in names:
    fig.add_trace(go.Scatter(
        x=tempD_tail[tempD_tail.name == n]['year'], 
        y=tempD_tail[tempD_tail.name == n]['value'], 
        mode='lines', 
        name=f"{n} deaths",
        legendgroup="group2",
        yaxis='y1'
        )
        )

names = tempV_head.name.drop_duplicates().to_list()
for n in names:
    fig.add_trace(go.Scatter(
        x=tempV_head[tempV_head.name == n]['year'], 
        y=tempV_head[tempV_head.name == n]['value'], 
        mode='lines', 
        name=f"{n} vaccines",
        legendgroup="group3",
        yaxis='y2'
        )
        )
    
names = tempV_tail.name.drop_duplicates().to_list()
for n in names:
    fig.add_trace(go.Scatter(
        x=tempV_tail[tempV_tail.name == n]['year'], 
        y=tempV_tail[tempV_tail.name == n]['value'], 
        mode='lines', 
        name=f"{n} vaccines",
        legendgroup="group4",
        yaxis='y2'
        )
        )

# Show the figure
fig.update_layout(
    template="plotly_dark",
    title="Plot with Two Y-Axes",
    xaxis=dict(title="X Axis"),
    yaxis=dict(title="Primary Y Axis", side="left", showgrid=False),
    yaxis2=dict(
        title="Secondary Y Axis",
        overlaying="y",
        side="right",
        showgrid=False
    ),
    height=750
    )
fig.show()

# %% [markdown]
# ### Specific Examples
# here i want to focus on a few notable findings

# %% [markdown]
# # bookmark

# %%
## this will order by high to low deaths after 2023 (pre-pandemic)
sums = pd.pivot_table(
    ddn[ddn.agegrp == 'TOTAL'][ddn.year >= 2023], # totals only 
    values = 'deaths_norm',
    index = ['abbr','name'],
    aggfunc='sum',
)
sums = sums.reset_index()
sums = sums.sort_values(by='deaths_norm',ascending=False)
# display(sums)

display(MD('### HeatMap (based on Year)'))
temp = pd.pivot_table(
    ddn[ddn.agegrp == 'TOTAL'], # totals only 
    values = 'deaths_norm',
    index = ['abbr','name'],
    columns=['year'],
    aggfunc='mean',
)
temp.columns.name = 'index' 

# temp = temp.sort_values(by=2024,ascending=False)
temp = temp.reset_index()
temp = temp.set_index('name').reindex(sums['name']).reset_index()

display(temp.style.background_gradient(cmap=heatmapCM,axis=1))
# Out:
# C:\Users\JGarza\AppData\Local\Temp\ipykernel_51112\151973392.py:3: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
# ### HeatMap (based on Year)
# <style type="text/css">
# #T_30213_row0_col2, #T_30213_row14_col6, #T_30213_row16_col2, #T_30213_row17_col4, #T_30213_row20_col2 {
#   background-color: #7ccaa5;
#   color: #000000;
# }
# #T_30213_row0_col3, #T_30213_row1_col2, #T_30213_row2_col3, #T_30213_row3_col3, #T_30213_row4_col4, #T_30213_row5_col2, #T_30213_row6_col3, #T_30213_row7_col3, #T_30213_row8_col3, #T_30213_row9_col3, #T_30213_row10_col4, #T_30213_row11_col3, #T_30213_row12_col4, #T_30213_row13_col3, #T_30213_row14_col3, #T_30213_row15_col3, #T_30213_row16_col3, #T_30213_row17_col3, #T_30213_row18_col3, #T_30213_row19_col3, #T_30213_row20_col3, #T_30213_row21_col3, #T_30213_row22_col3, #T_30213_row23_col3, #T_30213_row24_col6, #T_30213_row25_col11, #T_30213_row26_col3, #T_30213_row26_col11, #T_30213_row27_col11, #T_30213_row28_col11, #T_30213_row29_col10, #T_30213_row30_col11, #T_30213_row31_col11, #T_30213_row32_col10, #T_30213_row33_col11 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_30213_row0_col4, #T_30213_row17_col11, #T_30213_row28_col3, #T_30213_row32_col4 {
#   background-color: #97d5a4;
#   color: #000000;
# }
# #T_30213_row0_col5, #T_30213_row24_col10 {
#   background-color: #e6f598;
#   color: #000000;
# }
# #T_30213_row0_col6, #T_30213_row20_col9 {
#   background-color: #e9f69d;
#   color: #000000;
# }
# #T_30213_row0_col7, #T_30213_row4_col11, #T_30213_row5_col10, #T_30213_row10_col8 {
#   background-color: #c72e4c;
#   color: #f1f1f1;
# }
# #T_30213_row0_col8, #T_30213_row10_col9 {
#   background-color: #cd364d;
#   color: #f1f1f1;
# }
# #T_30213_row0_col9, #T_30213_row1_col9, #T_30213_row2_col8, #T_30213_row3_col7, #T_30213_row4_col9, #T_30213_row5_col9, #T_30213_row6_col9, #T_30213_row7_col7, #T_30213_row8_col9, #T_30213_row9_col9, #T_30213_row10_col7, #T_30213_row11_col9, #T_30213_row12_col7, #T_30213_row13_col7, #T_30213_row14_col7, #T_30213_row15_col7, #T_30213_row16_col7, #T_30213_row17_col8, #T_30213_row18_col8, #T_30213_row19_col8, #T_30213_row20_col7, #T_30213_row21_col8, #T_30213_row22_col8, #T_30213_row23_col7, #T_30213_row24_col7, #T_30213_row25_col8, #T_30213_row26_col8, #T_30213_row27_col8, #T_30213_row28_col8, #T_30213_row29_col8, #T_30213_row30_col8, #T_30213_row31_col8, #T_30213_row32_col7, #T_30213_row33_col8 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_30213_row0_col10 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_30213_row0_col11 {
#   background-color: #df4e4b;
#   color: #f1f1f1;
# }
# #T_30213_row1_col3, #T_30213_row12_col6, #T_30213_row14_col2, #T_30213_row16_col4, #T_30213_row29_col6 {
#   background-color: #4ea7b0;
#   color: #f1f1f1;
# }
# #T_30213_row1_col4, #T_30213_row11_col6, #T_30213_row30_col10, #T_30213_row31_col10 {
#   background-color: #5758a6;
#   color: #f1f1f1;
# }
# #T_30213_row1_col5, #T_30213_row4_col6, #T_30213_row11_col5, #T_30213_row22_col11, #T_30213_row25_col2, #T_30213_row27_col10, #T_30213_row30_col6 {
#   background-color: #466eb1;
#   color: #f1f1f1;
# }
# #T_30213_row1_col6, #T_30213_row10_col2, #T_30213_row20_col4 {
#   background-color: #3a7eb8;
#   color: #f1f1f1;
# }
# #T_30213_row1_col7, #T_30213_row23_col10, #T_30213_row25_col9 {
#   background-color: #8fd2a4;
#   color: #000000;
# }
# #T_30213_row1_col8, #T_30213_row12_col8, #T_30213_row23_col4 {
#   background-color: #86cfa5;
#   color: #000000;
# }
# #T_30213_row1_col10 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_30213_row1_col11 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_30213_row2_col2 {
#   background-color: #acdda4;
#   color: #000000;
# }
# #T_30213_row2_col4, #T_30213_row16_col11 {
#   background-color: #b5e1a2;
#   color: #000000;
# }
# #T_30213_row2_col5 {
#   background-color: #64c0a6;
#   color: #000000;
# }
# #T_30213_row2_col6 {
#   background-color: #eff9a6;
#   color: #000000;
# }
# #T_30213_row2_col7 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_30213_row2_col9 {
#   background-color: #a00343;
#   color: #f1f1f1;
# }
# #T_30213_row2_col10 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_30213_row2_col11 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_30213_row3_col2, #T_30213_row25_col5 {
#   background-color: #4273b3;
#   color: #f1f1f1;
# }
# #T_30213_row3_col4 {
#   background-color: #4175b4;
#   color: #f1f1f1;
# }
# #T_30213_row3_col5, #T_30213_row17_col2, #T_30213_row18_col10 {
#   background-color: #69c3a5;
#   color: #000000;
# }
# #T_30213_row3_col6, #T_30213_row4_col5, #T_30213_row23_col6, #T_30213_row29_col3 {
#   background-color: #47a0b3;
#   color: #f1f1f1;
# }
# #T_30213_row3_col8 {
#   background-color: #b81e48;
#   color: #f1f1f1;
# }
# #T_30213_row3_col9 {
#   background-color: #d0384e;
#   color: #f1f1f1;
# }
# #T_30213_row3_col10 {
#   background-color: #d7414e;
#   color: #f1f1f1;
# }
# #T_30213_row3_col11, #T_30213_row9_col7, #T_30213_row32_col8 {
#   background-color: #ad1246;
#   color: #f1f1f1;
# }
# #T_30213_row4_col2 {
#   background-color: #3682ba;
#   color: #f1f1f1;
# }
# #T_30213_row4_col3 {
#   background-color: #525fa9;
#   color: #f1f1f1;
# }
# #T_30213_row4_col7, #T_30213_row5_col7, #T_30213_row22_col9 {
#   background-color: #c8e99e;
#   color: #000000;
# }
# #T_30213_row4_col8, #T_30213_row14_col8 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_30213_row4_col10 {
#   background-color: #a70b44;
#   color: #f1f1f1;
# }
# #T_30213_row5_col3, #T_30213_row10_col3, #T_30213_row20_col6, #T_30213_row25_col3 {
#   background-color: #4b68ae;
#   color: #f1f1f1;
# }
# #T_30213_row5_col4 {
#   background-color: #545ca8;
#   color: #f1f1f1;
# }
# #T_30213_row5_col5, #T_30213_row12_col2 {
#   background-color: #4199b6;
#   color: #f1f1f1;
# }
# #T_30213_row5_col6, #T_30213_row18_col2, #T_30213_row18_col4 {
#   background-color: #486cb0;
#   color: #f1f1f1;
# }
# #T_30213_row5_col8, #T_30213_row10_col11 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_30213_row5_col11, #T_30213_row24_col2 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_30213_row6_col2 {
#   background-color: #71c6a5;
#   color: #000000;
# }
# #T_30213_row6_col4, #T_30213_row7_col2, #T_30213_row31_col3 {
#   background-color: #49a2b2;
#   color: #f1f1f1;
# }
# #T_30213_row6_col5, #T_30213_row11_col8 {
#   background-color: #a4daa4;
#   color: #000000;
# }
# #T_30213_row6_col6, #T_30213_row9_col4, #T_30213_row14_col5, #T_30213_row16_col5, #T_30213_row31_col4 {
#   background-color: #62bda7;
#   color: #000000;
# }
# #T_30213_row6_col7, #T_30213_row9_col11, #T_30213_row11_col10 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_30213_row6_col8 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_30213_row6_col10, #T_30213_row19_col7 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_30213_row6_col11, #T_30213_row8_col11 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_30213_row7_col4 {
#   background-color: #edf8a3;
#   color: #000000;
# }
# #T_30213_row7_col5, #T_30213_row28_col9 {
#   background-color: #fefebd;
#   color: #000000;
# }
# #T_30213_row7_col6 {
#   background-color: #fafdb7;
#   color: #000000;
# }
# #T_30213_row7_col8 {
#   background-color: #f88950;
#   color: #f1f1f1;
# }
# #T_30213_row7_col9, #T_30213_row9_col10 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_30213_row7_col10 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_30213_row7_col11, #T_30213_row13_col8 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_30213_row8_col2, #T_30213_row13_col2, #T_30213_row22_col2, #T_30213_row23_col11 {
#   background-color: #3f97b7;
#   color: #f1f1f1;
# }
# #T_30213_row8_col4, #T_30213_row22_col4 {
#   background-color: #3d79b6;
#   color: #f1f1f1;
# }
# #T_30213_row8_col5, #T_30213_row17_col10, #T_30213_row25_col7 {
#   background-color: #d6ee9b;
#   color: #000000;
# }
# #T_30213_row8_col6, #T_30213_row15_col4, #T_30213_row33_col10 {
#   background-color: #5cb7aa;
#   color: #f1f1f1;
# }
# #T_30213_row8_col7, #T_30213_row33_col9 {
#   background-color: #eef8a4;
#   color: #000000;
# }
# #T_30213_row8_col8 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_30213_row8_col10 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_30213_row9_col2 {
#   background-color: #b8e2a1;
#   color: #000000;
# }
# #T_30213_row9_col5, #T_30213_row17_col6, #T_30213_row31_col2 {
#   background-color: #89d0a4;
#   color: #000000;
# }
# #T_30213_row9_col6, #T_30213_row10_col5, #T_30213_row11_col2, #T_30213_row20_col8 {
#   background-color: #6ec

# %%
## this will order by high to low deaths after 2023 (pre-pandemic)
sums = pd.pivot_table(
    ddn[ddn.agegrp == 'LT80'][ddn.year >= 2023], # totals only 
    values = 'deaths_norm',
    index = ['abbr','name'],
    aggfunc='sum',
)
sums = sums.reset_index()
sums = sums.sort_values(by='deaths_norm',ascending=False)
# display(sums)

display(MD('### HeatMap (based on Year, only where agegrp is LT80)'))
temp = pd.pivot_table(
    ddn[ddn.agegrp == 'LT80'], # totals only 
    values = 'deaths_norm',
    index = ['abbr','name'],
    columns=['year'],
    aggfunc='mean',
)
temp.columns.name = 'index' 

# temp = temp.sort_values(by=2024,ascending=False)
temp = temp.reset_index()
temp = temp.set_index('name').reindex(sums['name']).reset_index()

display(temp.style.background_gradient(cmap=heatmapCM,axis=1))
# Out:
# C:\Users\JGarza\AppData\Local\Temp\ipykernel_51112\3268976977.py:3: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
# ### HeatMap (based on Year, only where agegrp is LT80)
# <style type="text/css">
# #T_b14ab_row0_col2, #T_b14ab_row1_col3, #T_b14ab_row2_col4, #T_b14ab_row3_col3, #T_b14ab_row4_col3, #T_b14ab_row4_col4, #T_b14ab_row5_col3, #T_b14ab_row6_col6, #T_b14ab_row7_col3, #T_b14ab_row8_col3, #T_b14ab_row9_col3, #T_b14ab_row10_col9, #T_b14ab_row11_col3, #T_b14ab_row12_col3, #T_b14ab_row13_col6, #T_b14ab_row14_col6, #T_b14ab_row15_col11, #T_b14ab_row16_col3, #T_b14ab_row17_col5, #T_b14ab_row18_col3, #T_b14ab_row18_col11, #T_b14ab_row19_col11, #T_b14ab_row20_col11, #T_b14ab_row21_col10, #T_b14ab_row22_col6, #T_b14ab_row23_col11, #T_b14ab_row24_col11, #T_b14ab_row25_col11, #T_b14ab_row26_col11, #T_b14ab_row27_col11, #T_b14ab_row28_col6, #T_b14ab_row29_col10, #T_b14ab_row30_col11, #T_b14ab_row31_col11, #T_b14ab_row32_col10 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_b14ab_row0_col3, #T_b14ab_row13_col11 {
#   background-color: #7ecca5;
#   color: #000000;
# }
# #T_b14ab_row0_col4, #T_b14ab_row11_col10, #T_b14ab_row16_col10, #T_b14ab_row22_col11 {
#   background-color: #3b92b9;
#   color: #f1f1f1;
# }
# #T_b14ab_row0_col5, #T_b14ab_row13_col5, #T_b14ab_row30_col10 {
#   background-color: #5cb7aa;
#   color: #f1f1f1;
# }
# #T_b14ab_row0_col6, #T_b14ab_row20_col5, #T_b14ab_row28_col11 {
#   background-color: #50a9af;
#   color: #f1f1f1;
# }
# #T_b14ab_row0_col7 {
#   background-color: #f5fbaf;
#   color: #000000;
# }
# #T_b14ab_row0_col8, #T_b14ab_row32_col9 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_b14ab_row0_col9, #T_b14ab_row1_col9, #T_b14ab_row2_col8, #T_b14ab_row3_col8, #T_b14ab_row4_col9, #T_b14ab_row5_col9, #T_b14ab_row6_col10, #T_b14ab_row7_col7, #T_b14ab_row8_col7, #T_b14ab_row9_col8, #T_b14ab_row10_col7, #T_b14ab_row11_col8, #T_b14ab_row12_col7, #T_b14ab_row13_col8, #T_b14ab_row14_col7, #T_b14ab_row15_col9, #T_b14ab_row16_col8, #T_b14ab_row17_col8, #T_b14ab_row18_col7, #T_b14ab_row19_col8, #T_b14ab_row20_col8, #T_b14ab_row21_col8, #T_b14ab_row22_col8, #T_b14ab_row23_col2, #T_b14ab_row24_col7, #T_b14ab_row25_col8, #T_b14ab_row26_col7, #T_b14ab_row27_col8, #T_b14ab_row28_col7, #T_b14ab_row29_col8, #T_b14ab_row30_col8, #T_b14ab_row31_col8, #T_b14ab_row32_col8 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_b14ab_row0_col10 {
#   background-color: #f36b43;
#   color: #f1f1f1;
# }
# #T_b14ab_row0_col11, #T_b14ab_row10_col8 {
#   background-color: #dc484c;
#   color: #f1f1f1;
# }
# #T_b14ab_row1_col2, #T_b14ab_row12_col11, #T_b14ab_row31_col10 {
#   background-color: #6bc4a5;
#   color: #000000;
# }
# #T_b14ab_row1_col4, #T_b14ab_row22_col4 {
#   background-color: #66c2a5;
#   color: #000000;
# }
# #T_b14ab_row1_col5 {
#   background-color: #d8ef9b;
#   color: #000000;
# }
# #T_b14ab_row1_col6, #T_b14ab_row3_col6 {
#   background-color: #a4daa4;
#   color: #000000;
# }
# #T_b14ab_row1_col7 {
#   background-color: #ea5e47;
#   color: #f1f1f1;
# }
# #T_b14ab_row1_col8 {
#   background-color: #b61b48;
#   color: #f1f1f1;
# }
# #T_b14ab_row1_col10 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_b14ab_row1_col11 {
#   background-color: #ef6645;
#   color: #f1f1f1;
# }
# #T_b14ab_row2_col2, #T_b14ab_row4_col5, #T_b14ab_row5_col6, #T_b14ab_row6_col2, #T_b14ab_row11_col2, #T_b14ab_row16_col2, #T_b14ab_row20_col6 {
#   background-color: #358bbc;
#   color: #f1f1f1;
# }
# #T_b14ab_row2_col3 {
#   background-color: #5061aa;
#   color: #f1f1f1;
# }
# #T_b14ab_row2_col5, #T_b14ab_row9_col11, #T_b14ab_row16_col5, #T_b14ab_row21_col3 {
#   background-color: #459eb4;
#   color: #f1f1f1;
# }
# #T_b14ab_row2_col6, #T_b14ab_row12_col4, #T_b14ab_row20_col10, #T_b14ab_row21_col6, #T_b14ab_row28_col5 {
#   background-color: #3d79b6;
#   color: #f1f1f1;
# }
# #T_b14ab_row2_col7 {
#   background-color: #f06744;
#   color: #f1f1f1;
# }
# #T_b14ab_row2_col9 {
#   background-color: #df4e4b;
#   color: #f1f1f1;
# }
# #T_b14ab_row2_col10, #T_b14ab_row29_col2 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_b14ab_row2_col11, #T_b14ab_row4_col10, #T_b14ab_row23_col9 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_b14ab_row3_col2, #T_b14ab_row19_col6 {
#   background-color: #6ec5a5;
#   color: #000000;
# }
# #T_b14ab_row3_col4, #T_b14ab_row5_col2, #T_b14ab_row14_col3, #T_b14ab_row17_col11, #T_b14ab_row20_col4 {
#   background-color: #58b2ac;
#   color: #f1f1f1;
# }
# #T_b14ab_row3_col5 {
#   background-color: #60bba8;
#   color: #000000;
# }
# #T_b14ab_row3_col7, #T_b14ab_row15_col10, #T_b14ab_row16_col7 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_b14ab_row3_col9 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_b14ab_row3_col10, #T_b14ab_row24_col9 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_b14ab_row3_col11, #T_b14ab_row12_col10, #T_b14ab_row14_col11, #T_b14ab_row22_col3, #T_b14ab_row22_col9, #T_b14ab_row30_col3 {
#   background-color: #c8e99e;
#   color: #000000;
# }
# #T_b14ab_row4_col2, #T_b14ab_row29_col11 {
#   background-color: #4d65ad;
#   color: #f1f1f1;
# }
# #T_b14ab_row4_col6, #T_b14ab_row5_col5, #T_b14ab_row9_col5, #T_b14ab_row16_col6, #T_b14ab_row27_col10 {
#   background-color: #3f97b7;
#   color: #f1f1f1;
# }
# #T_b14ab_row4_col7, #T_b14ab_row7_col2 {
#   background-color: #8cd1a4;
#   color: #000000;
# }
# #T_b14ab_row4_col8, #T_b14ab_row13_col2, #T_b14ab_row17_col7, #T_b14ab_row30_col9 {
#   background-color: #d6ee9b;
#   color: #000000;
# }
# #T_b14ab_row4_col11, #T_b14ab_row13_col9, #T_b14ab_row24_col2 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_b14ab_row5_col4, #T_b14ab_row21_col5 {
#   background-color: #4273b3;
#   color: #f1f1f1;
# }
# #T_b14ab_row5_col7 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_b14ab_row5_col8 {
#   background-color: #d0384e;
#   color: #f1f1f1;
# }
# #T_b14ab_row5_col10, #T_b14ab_row7_col9 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_b14ab_row5_col11, #T_b14ab_row18_col2 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_b14ab_row6_col3, #T_b14ab_row9_col2, #T_b14ab_row9_col6 {
#   background-color: #378ebb;
#   color: #f1f1f1;
# }
# #T_b14ab_row6_col4, #T_b14ab_row29_col6 {
#   background-color: #3387bc;
#   color: #f1f1f1;
# }
# #T_b14ab_row6_col5, #T_b14ab_row11_col5 {
#   background-color: #3682ba;
#   color: #f1f1f1;
# }
# #T_b14ab_row6_col7 {
#   background-color: #c3e79f;
#   color: #000000;
# }
# #T_b14ab_row6_col8, #T_b14ab_row24_col10, #T_b14ab_row32_col6 {
#   background-color: #f8fcb4;
#   color: #000000;
# }
# #T_b14ab_row6_col9 {
#   background-color: #cb334d;
#   color: #f1f1f1;
# }
# #T_b14ab_row6_col11 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_b14ab_row7_col4 {
#   background-color: #5956a5;
#   color: #f1f1f1;
# }
# #T_b14ab_row7_col5 {
#   background-color: #3b7cb7;
#   color: #f1f1f1;
# }
# #T_b14ab_row7_col6 {
#   background-color: #4471b2;
#   color: #f1f1f1;
# }
# #T_b14ab_row7_col8 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_b14ab_row7_col10 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_b14ab_row7_col11, #T_b14ab_row25_col7, #T_b14ab_row31_col5 {
#   background-color: #f7fcb2;
#   color: #000000;
# }
# #T_b14ab_row8_col2 {
#   background-color: #8fd2a4;
#   color: #000000;
# }
# #T_b14ab_row8_col4, #T_b14ab_row10_col11 {
#   background-color: #a90d45;
#   color: #f1f1f1;
# }
# #T_b14ab_row8_col5 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_b14ab_row8_col6, #T_b14ab_row15_col7, #T_b14ab_row32_col5 {
#   background-color: #f6fbb0;
#   color: #000000;
# }
# #T_b14ab_row8_col8 {
#   background-color: #d9444d;
#   color: #f1f1f1;
# }
# #T_b14ab_row8_col9, #T_b14ab_row23_col7, #T_b14ab_row29_col3 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_b14ab_row8_col10, #T_b14ab_row14_col9 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_b14ab_row8_col11 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_b14ab_row9_col4, #T_b14ab_row11_col11, #T_b14ab_row21_col4 {
#   background-color: #466eb1;
#   color: #f1f1f1;
# }
# #T_b14ab_row9_col7, #T_b14ab_row17_col9, #T_b14ab_row27_col7 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_b14ab_row9_col9 {
#   background-color: #e8f69b;
#   color: #000000;
# }
# #T_b14ab_row9_col10, #T_b14ab_row22_col7 {
#   background-color: #54aead;
#   color: #f1f1f1;
# }
# #T_b14ab_row10_col2, #T_b14ab_row12_col9 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_b14ab_row10_col3 {
#   background-color: #a00343;
#   color: #f1f1f1;
# }
# #T_b14ab_row10_col4 {
#   background-color: #cd364d;

# %% [markdown]
# ## Conclusion
